# %% [markdown]
# ## Process Spreadsheet and Query LLM

# %%
import pandas as pd
from openai import OpenAI

# %%
n_formal=250
n_informal=1000
ground_truth='MCTD'
patient_nominal_gender='female'
patient_nominal_age=10
patient_nominal_weight=54
patient_nominal_height=46

# %%
xls = pd.ExcelFile('DiagnosisNumbersSpreadsheet.xlsx')

# %%
df1 = pd.read_excel(xls, ground_truth)

# %%
import random 

class Symptom:
    def __init__(self, name, pct, informal_descriptions):
        self.name = name
        self.pct = pct 
        self.informal = informal_descriptions
        
    def get_informal_symptom(self):
        if len(self.informal) <= 0 :
            return self.name
        else:
            return random.choice(self.informal)

# %%
import math
def process_dataframe_with_symptoms(df):
    current_textbook_symptom_name = None 
    current_textbook_symptom_percentage = None 
    current_informal_descriptions = []
    all_symptoms = [] 
    
    for row in df.iterrows():
        symptom_name = row[1][0]
        symptom_percentage = row[1][1]
        if not math.isnan(symptom_percentage):
            print(symptom_name, float(symptom_percentage)/100.0)
            if current_textbook_symptom_name != None:
                symp = Symptom(current_textbook_symptom_name, current_textbook_symptom_percentage, current_informal_descriptions)
                all_symptoms.append(symp)
            current_textbook_symptom_name = symptom_name
            current_textbook_symptom_percentage = symptom_percentage/100.0
            current_informal_descriptions = [] 
        else:
            assert current_textbook_symptom_name != None 
            current_informal_descriptions.append(symptom_name)
            print(f'\t {symptom_name}')
            
    if current_textbook_symptom_name != None:
        symp = Symptom(current_textbook_symptom_name, current_textbook_symptom_percentage, current_informal_descriptions)
        all_symptoms.append(symp)
    return all_symptoms

# %%
all_symptoms = process_dataframe_with_symptoms(df1)
# Out:
# Arthritis 0.93
# 	 Joint pain
# 	 Joint tenderness
# 	 Joint stiffness
# Raynaud's phenomenon 0.85
# 	 Fingers turning white
# 	 Finger turning blue
# 	 Cold hands
# Sclerodermatous skin 0.49
# 	 Tight skin
# 	 Hard skin
# 	 Shiny skin
# Malar rash 0.33
# 	 Rash on face
# 	 Rash on cheeks
# 	 Butterfly rash
# 	 Rosy cheeks
# Gottron's papules 0.33
# 	 Hand rash
# 	 rash on hands
# 	 rash on kncules
# Fever 0.41
# Abnormal esophageal motility 0.41
# 	 Trouble swallowing
# 	 Trouble swallowing liquids
# 	 Trouble swallowing solids
# 	 Food gets stuck in throat
# 	 Pills get stuck in throat
# Cardiac disease 0.3
# Pericarditis 0.27
# 	 Chest pain
# Muscle disease 0.61
# 	 Sore muscles
# 	 Muscular Weakness
# Sicca symptoms 0.36
# 	 Dry eyes
# 	 Dry mouth
# Central nervous system disease 0.23
# 	 Psychiatric issues
# 	 Encephalopathy
# 	 Cognitive issues
# 	 Meningitis
# Abnormal lung  diffusion 0.43
# Restrictive lung disese 0.14
# Hypertension 0.07
# Effusion 0.23
# Splenomegaly 0.29
# Hepatomegaly 0.28
# Renal disease 0.26

# %%
import random

def create_symptom_list(all_symptoms, informal=False):
    symptom_list = []
    for s in all_symptoms:
        r = random.random()
        if r <= s.pct:
            if informal:
                symptom_list.append(s.get_informal_symptom())
            else:
                symptom_list.append(s.name)
    return symptom_list

# %%
s0 = create_symptom_list(all_symptoms, informal=True)
print(s0)
# Out:
# ['Joint stiffness', 'Fingers turning white', 'Hard skin', 'Rash on cheeks', 'Hand rash', 'Fever', 'Chest pain', 'Abnormal lung  diffusion']

# %%
formal_symptom_list = [create_symptom_list(all_symptoms, informal=False) for i in range(n_formal)]

# %%
informal_symptom_list=[create_symptom_list(all_symptoms, informal=True) for i in range(n_informal)]

# %%
print(informal_symptom_list)
# Out:
# [['Joint tenderness', 'Fingers turning white', 'Fever', 'Cardiac disease', 'Chest pain', 'Abnormal lung  diffusion', 'Restrictive lung disese'], ['Joint tenderness', 'Cold hands', 'Tight skin', 'rash on kncules', 'Trouble swallowing solids', 'Chest pain', 'Dry mouth', 'Abnormal lung  diffusion', 'Restrictive lung disese', 'Hepatomegaly'], ['Joint tenderness', 'Finger turning blue', 'Fever', 'Food gets stuck in throat', 'Hepatomegaly', 'Renal disease'], ['Joint tenderness', 'Finger turning blue', 'Rosy cheeks', 'Trouble swallowing', 'Effusion'], ['Joint tenderness', 'Hard skin', 'Fever', 'Muscular Weakness', 'Effusion'], ['Joint pain', 'Cold hands', 'Rosy cheeks', 'Fever', 'Cardiac disease', 'Muscular Weakness', 'Dry mouth', 'Renal disease'], ['Cold hands', 'Shiny skin', 'Rosy cheeks', 'Trouble swallowing', 'Cardiac disease', 'Muscular Weakness', 'Restrictive lung disese', 'Splenomegaly', 'Renal disease'], ['Joint pain', 'Shiny skin', 'rash on kncules', 'Trouble swallowing liquids', 'Chest pain', 'Sore muscles', 'Dry eyes', 'Cognitive issues', 'Hepatomegaly'], ['Joint stiffness', 'Cold hands', 'Fever', 'Trouble swallowing liquids', 'Cardiac disease', 'Muscular Weakness', 'Abnormal lung  diffusion'], ['Joint stiffness', 'Fingers turning white', 'Hard skin', 'Rash on face', 'Fever', 'Sore muscles', 'Dry eyes', 'Psychiatric issues', 'Abnormal lung  diffusion', 'Hepatomegaly', 'Renal disease'], ['Joint stiffness', 'Cold hands', 'Dry eyes', 'Abnormal lung  diffusion'], ['Joint stiffness', 'Tight skin', 'Rosy cheeks', 'Fever', 'Trouble swallowing solids', 'Abnormal lung  diffusion', 'Effusion', 'Hepatomegaly', 'Renal disease'], ['Joint stiffness', 'Hard skin', 'Fever', 'Sore muscles', 'Abnormal lung  diffusion'], ['Joint tenderness', 'Finger turning blue', 'Rosy cheeks', 'Fever', 'Dry eyes', 'Encephalopathy', 'Restrictive lung disese', 'Splenomegaly', 'Hepatomegaly', 'Renal disease'], ['Joint stiffness', 'Rosy cheeks', 'Chest pain', 'Effusion', 'Splenomegaly', 'Renal disease'], ['Joint tenderness', 'Pills get stuck in throat ', 'Muscular Weakness', 'Dry mouth', 'Abnormal lung  diffusion'], ['Cold hands', 'Tight skin', 'Hand rash', 'Fever', 'Pills get stuck in throat ', 'Chest pain', 'Effusion', 'Hepatomegaly'], ['Joint pain', 'Fingers turning white', 'Shiny skin', 'Muscular Weakness'], ['Joint tenderness', 'Finger turning blue', 'Tight skin', 'Rash on cheeks', 'Sore muscles', 'Hypertension', 'Hepatomegaly'], ['Joint stiffness', 'Cold hands', 'Fever', 'Trouble swallowing solids'], ['Joint tenderness', 'Hand rash', 'Trouble swallowing', 'Muscular Weakness', 'Effusion'], ['Joint stiffness', 'rash on hands', 'Fever', 'Sore muscles', 'Abnormal lung  diffusion', 'Renal disease'], ['Fingers turning white', 'Tight skin', 'Rosy cheeks', 'Fever', 'Cardiac disease', 'Renal disease'], ['Joint tenderness', 'Fingers turning white', 'Tight skin'], ['Finger turning blue', 'rash on kncules', 'Chest pain', 'Sore muscles', 'Abnormal lung  diffusion', 'Hepatomegaly'], ['Hard skin', 'Fever', 'Abnormal lung  diffusion', 'Effusion', 'Splenomegaly'], ['Joint stiffness', 'Finger turning blue', 'Rash on face', 'Chest pain', 'Dry mouth', 'Abnormal lung  diffusion', 'Effusion', 'Hepatomegaly'], ['Joint pain', 'Finger turning blue', 'Tight skin', 'Fever', 'Trouble swallowing', 'Cardiac disease', 'Splenomegaly', 'Renal disease'], ['Joint tenderness', 'Muscular Weakness', 'Abnormal lung  diffusion', 'Restrictive lung disese'], ['Joint pain', 'Fingers turning white', 'rash on kncules', 'Fever', 'Cardiac disease', 'Chest pain', 'Dry mouth', 'Splenomegaly'], ['Joint stiffness', 'Cold hands', 'Shiny skin', 'Hand rash', 'Fever', 'Chest pain', 'Dry eyes', 'Psychiatric issues', 'Abnormal lung  diffusion', 'Effusion'], ['Joint tenderness', 'Finger turning blue', 'Tight skin', 'rash on hands', 'Trouble swallowing solids', 'Splenomegaly'], ['Joint stiffness', 'Tight skin', 'Butterfly rash', 'Fever', 'Trouble swallowing solids', 'Dry mouth'], ['Joint tenderness', 'Finger tur ...

# %%
def make_prompt(symptom_list, gender, age, weight, height):
    patient_descr = f'The patient is a {age} year old {gender} with a weight of {weight} lbs and height of {height} inches.'
    symptoms_str = 'The list of symptoms include '
    for (j, s) in enumerate(symptom_list):
        if j != len(symptom_list)-1:
            symptoms_str = symptoms_str + f' ({j+1}) {s}'
        else:
            symptoms_str = symptoms_str + f' and ({j+1}) {s}.'
    return patient_descr + ' ' + symptoms_str

# %%
p0 = make_prompt(s0, patient_nominal_gender, patient_nominal_age, patient_nominal_weight, patient_nominal_height)

# %%
print(p0)
# Out:
# The patient is a 10 year old female with a weight of 54 lbs and height of 46 inches. The list of symptoms include  (1) Joint stiffness (2) Fingers turning white (3) Hard skin (4) Rash on cheeks (5) Hand rash (6) Fever (7) Chest pain and (8) Abnormal lung  diffusion.

# %%
def prompt_open_ai(prompt_str, model="gpt-3.5-turbo"):
    client = OpenAI()
    response = client.chat.completions.create(
        model=model,
        messages=[
        {
        "role": "system",
        "content": """ I am taking care of a patient and would like your help generating a differential diagnosis.  I will provide details 
        about the patient and the symptoms below. Please output upto 5 conditions that are consistent with the symptoms sorted from the most likely to the least. Your 
        output must be in the format wherein each of the conditions must be in a separate line.
                        1. <name of condition/disease>, <probability of this disease as a percentage>, <brief rationale as to why the patient may have this disease>
                        2. <name of condition/disease>, <probability of this disease as a percentage>, <brief rationale as to why the patient may have this disease>
                        ...
                        5. <name of condition/disease>, <probability of this disease as a percentage>, <brief rationale as to why the patient may have this disease>
                        """
        },
        {
        "role": "user",
        "content": prompt_str
        }
        ],
        temperature=0.7,
        max_tokens=1024,
        top_p=1
    )
    #print(response)
    #print(response.choices[0].message.content)
    return response.choices[0].message.content

# %%
r0 = prompt_open_ai(p0)

# %%
print(r0)
# Out:
# 1. Juvenile Idiopathic Arthritis, 50%, Joint stiffness, fever, and hand rash are common symptoms of Juvenile Idiopathic Arthritis in children.
# 2. Systemic Lupus Erythematosus (SLE), 30%, Rash on cheeks (malar rash), joint stiffness, and abnormal lung diffusion can be seen in patients with SLE.
# 3. Systemic Sclerosis (Scleroderma), 15%, Hard skin, fingers turning white (Raynaud's phenomenon), and chest pain are consistent with systemic sclerosis.
# 4. Kawasaki Disease, 5%, Fever, rash on cheeks, and abnormal lung diffusion can be present in Kawasaki disease.
# 5. Rheumatic Fever, 5%, Joint stiffness, fever, and chest pain can be symptoms of Rheumatic Fever in children.

# %%
import re
def parse_response(response):
    lst_of_lines = response.split('\n')
    results = []
    for (j, line) in enumerate(lst_of_lines): 
        m = re.match(r"(\d+).\s*(.*)\s*,\s*(\d+)%,(.*)", line)
        if m != None:
            results.append((m.group(2), m.group(3), m.group(4)))
    return results

# %%
parsed_r0 = parse_response(r0)

# %%
print(parsed_r0)
# Out:
# [('Juvenile Idiopathic Arthritis', '50', ' Joint stiffness, fever, and hand rash are common symptoms of Juvenile Idiopathic Arthritis in children.'), ('Systemic Lupus Erythematosus (SLE)', '30', ' Rash on cheeks (malar rash), joint stiffness, and abnormal lung diffusion can be seen in patients with SLE.'), ('Systemic Sclerosis (Scleroderma)', '15', " Hard skin, fingers turning white (Raynaud's phenomenon), and chest pain are consistent with systemic sclerosis."), ('Kawasaki Disease', '5', ' Fever, rash on cheeks, and abnormal lung diffusion can be present in Kawasaki disease.'), ('Rheumatic Fever', '5', ' Joint stiffness, fever, and chest pain can be symptoms of Rheumatic Fever in children.')]

# %%
def run_symptoms_list_openai_and_parse_responses(symptoms_list_list, gender, age, weight, height, max_n=None):
    count = 0
    all_parsed_responses = []
    for symptoms_list in symptoms_list_list:
        p0 = make_prompt(symptoms_list, gender, age, weight, height)
        r0 = prompt_open_ai(p0)
        parsed_r0 = parse_response(r0)
        all_parsed_responses.append(parsed_r0)
        count = count + 1
        if max_n != None and count >= max_n:
            return all_parsed_responses
    return all_parsed_responses

# %%
all_parsed_responses_formal = run_symptoms_list_openai_and_parse_responses(formal_symptom_list, patient_nominal_gender, patient_nominal_age, patient_nominal_weight, patient_nominal_height, max_n=None)

# %%
print(all_parsed_responses_formal)
# Out:
# [[('Juvenile Idiopathic Arthritis', '40', ' The patient presents with arthritis which is common in Juvenile Idiopathic Arthritis. '), ('Juvenile Dermatomyositis', '30', " Gottron's papules and muscle weakness are characteristic features of Juvenile Dermatomyositis."), ('Eosinophilic Esophagitis', '15', ' Abnormal esophageal motility can be seen in Eosinophilic Esophagitis.'), ('Juvenile Rheumatic Heart Disease', '10', ' Cardiac disease can be associated with Juvenile Rheumatic Heart Disease.'), ('Duchenne Muscular Dystrophy', '5', ' Muscle weakness can be a symptom of Duchenne Muscular Dystrophy.')], [('Juvenile Idiopathic Arthritis', '60', " The patient's symptoms of arthritis along with fever and possibly cardiac disease suggest a possible diagnosis of Juvenile Idiopathic Arthritis."), ('Systemic Lupus Erythematosus (SLE)', '20', " The presence of Malar rash, Raynaud's phenomenon, and possibly arthritis in a young female patient raises suspicion for SLE."), ('Dermatomyositis', '10', " The presence of Gottron's papules, muscle disease, and possibly lung involvement points towards Dermatomyositis as a possible diagnosis."), ('Rheumatic Fever', '5', ' Fever along with cardiac disease in a young patient could be indicative of Rheumatic Fever.'), ('Scleroderma', '5', " Raynaud's phenomenon, abnormal lung diffusion, and possibly arthritis could be suggestive of Scleroderma.")], [('Juvenile Idiopathic Arthritis', '70', ' The patient presents with arthritis, fever, and potential cardiac involvement which are common features of Juvenile Idiopathic Arthritis.'), ('Systemic Sclerosis (Scleroderma)', '15', " The patient exhibits sclerodermatous skin, Raynaud's phenomenon, and abnormal esophageal motility which are consistent with Systemic Sclerosis."), ('Juvenile Dermatomyositis', '5', ' The combination of muscle disease, skin involvement, and potential cardiac issues suggest Juvenile Dermatomyositis as a possibility.'), ('Kawasaki Disease', '5', ' The presence of fever, cardiac involvement, and potential pericarditis might indicate Kawasaki Disease as a differential diagnosis.'), ('Systemic Lupus Erythematosus', '5', " The symptoms of fever, arthritis, Raynaud's phenomenon, and potential pericarditis could be seen in Systemic Lupus Erythematosus.")], [('Juvenile Idiopathic Arthritis', '80', ' The patient is a 10 year old female with arthritis, which is common in Juvenile Idiopathic Arthritis.'), ('Systemic Lupus Erythematosus (SLE)', '70', " The presence of Raynaud's phenomenon, malar rash, and pericarditis suggest a possible diagnosis of SLE."), ('Juvenile Dermatomyositis', '60', " The presence of Gottron's papules and abnormal lung diffusion are consistent with Juvenile Dermatomyositis."), ('Systemic Sclerosis', '40', " Raynaud's phenomenon and abnormal lung diffusion are common in Systemic Sclerosis."), ('Rheumatic Fever', '20', ' The presence of pericarditis and effusion could be indicative of Rheumatic Fever.')], [('Juvenile Idiopathic Arthritis', '50', ' The patient is a young female presenting with arthritis symptoms which is common in Juvenile Idiopathic Arthritis.'), ('Systemic Lupus Erythematosus', '20', " The patient has multiple symptoms like arthritis, Raynaud's phenomenon, fever, and cardiac involvement which are seen in systemic lupus erythematosus."), ('Juvenile Dermatomyositis', '15', ' Muscle weakness and arthritis are common in Juvenile Dermatomyositis which could explain the symptoms in this patient.'), ('Kawasaki disease', '10', ' Fever and cardiac involvement like pericarditis are seen in Kawasaki disease which could be a possibility in this case.'), ('Systemic Sclerosis', '5', " Raynaud's phenomenon along with arthritis and cardiac disease can be seen in systemic sclerosis which could be considered in the differential diagnosis.")], [('Juvenile Idiopathic Arthritis', '60', ' The patient presents with arthritis which is a common symptom in Juvenile Idiopathic Arthritis. Other symptoms such as fever, effusion, and  ...

# %%
def dump_responses_to_file(symptoms_list_list, all_parsed_responses, filename, gender, age, weight, height):
    filehandle = open(filename, 'w')
    count = 0
    for (symptoms_list, parsed_response) in zip(symptoms_list_list, all_parsed_responses):
        count = count + 1
        print(f'P: {count}, {gender}, {age}, {weight}, {height}', file=filehandle)
        for s in symptoms_list:
            print(f'S:{s}', file=filehandle)
        for (j, r) in enumerate(parsed_response):
            (disease_name, prob, descr) = r
            print(f'R: {j+1}, {disease_name}, {prob}, {descr}', file=filehandle)
    filehandle.close()

# %%
dump_responses_to_file(formal_symptom_list, all_parsed_responses_formal, f'{ground_truth}-formal-chatgpt-3.5.txt', patient_nominal_gender, patient_nominal_age, patient_nominal_weight, patient_nominal_height)

# %%
top_responses_formal = [resp[0][0] for resp in all_parsed_responses_formal]

# %%
def get_frequencies(lst_of_top_responses):
    lower_case_responses = [s.lower() for s in lst_of_top_responses]
    return {i:lower_case_responses.count(i) for i in set(lower_case_responses)}

# %%
print('Top Responses')
get_frequencies(top_responses_formal)
# Out:
# Top Responses
# {'juvenile systemic lupus erythematosus': 1,
#  'systemic lupus erythematosus': 1,
#  'systemic lupus erythematosus (sle)': 4,
#  'juvenile dermatomyositis': 34,
#  'juvenile systemic sclerosis': 6,
#  'juvenile idiopathic arthritis': 202,
#  'juvenile idiopathic arthritis (jia)': 2}

# %%
top_three_tmp = [[resp[0][0], resp[1][0], resp[2][0]] for resp in all_parsed_responses_formal]
top_three_responses_formal = [x for lst in top_three_tmp for x in lst]

# %%
print('Top three responses')
get_frequencies(top_three_responses_formal)
# Out:
# Top three responses
# {'eosinophilic esophagitis': 3,
#  "raynaud's phenomenon": 1,
#  'scleroderma': 6,
#  'duchenne muscular dystrophy': 5,
#  'pulmonary hypertension': 1,
#  'lupus nephritis': 1,
#  'juvenile idiopathic arthritis (jia)': 5,
#  'rheumatoid arthritis': 1,
#  "juvenile sjögren's syndrome": 1,
#  'rheumatic heart disease': 1,
#  'juvenile rheumatoid arthritis': 2,
#  'neurological disorder (e.g., multiple sclerosis)': 1,
#  'systemic lupus erythematosus': 94,
#  'juvenile dermatomyositis': 128,
#  'systemic sclerosis': 66,
#  'inflammatory myopathy': 1,
#  'lupus': 4,
#  'juvenile systemic lupus erythematosus': 7,
#  'mixed connective tissue disease': 7,
#  'systemic lupus erythematosus (sle)': 98,
#  'juvenile myositis': 1,
#  'esophageal dysmotility disorders': 1,
#  'juvenile systemic sclerosis': 12,
#  'rheumatic fever': 4,
#  'juvenile idiopathic arthritis': 211,
#  'muscular dystrophy': 2,
#  'systemic juvenile idiopathic arthritis': 2,
#  'dermatomyositis': 22,
#  'idiopathic pulmonary fibrosis': 1,
#  'juvenile systemic sclerosis (juvenile scleroderma)': 1,
#  'mixed connective tissue disease (mctd)': 3,
#  'systemic sclerosis (scleroderma)': 51,
#  "sjogren's syndrome": 6}

# %%
all_parsed_responses_informal = run_symptoms_list_openai_and_parse_responses(informal_symptom_list, patient_nominal_gender, patient_nominal_age, patient_nominal_weight, patient_nominal_height, max_n=None)

# %%
print(all_parsed_responses_informal)
# Out:
# [[('Juvenile Idiopathic Arthritis', '40', ' The patient presents with joint tenderness which is consistent with arthritis. This condition commonly affects children and can cause joint pain and tenderness.'), ("Raynaud's Phenomenon", '30', " The symptoms of fingers turning white suggest possible Raynaud's Phenomenon, a condition characterized by vasospasm of small arteries, leading to color changes in the fingers in response to cold or stress."), ('Systemic Lupus Erythematosus (SLE)', '15', ' Fever, joint tenderness, and cardiac disease can be seen in SLE, an autoimmune disease that can affect multiple organs.'), ('Myocarditis', '10', ' The presence of cardiac disease, chest pain, and fever raises concern for myocarditis, which is an inflammation of the heart muscle commonly caused by viral infections.'), ('Interstitial Lung Disease', '5', ' Abnormal lung diffusion and restrictive lung disease could be indicative of interstitial lung disease, a group of disorders that cause inflammation and scarring of the lungs leading to difficulty breathing.')], [('Juvenile Idiopathic Arthritis', '60', ' The patient presents with joint tenderness, rash on knuckles, and cold hands which are common symptoms of Juvenile Idiopathic Arthritis.'), ('Systemic Sclerosis', '20', ' Tight skin, rash on knuckles, and abnormal lung diffusion are consistent with systemic sclerosis which can also present with hepatomegaly.'), ('Eosinophilic Esophagitis', '10', ' Trouble swallowing solids and chest pain could be indicative of Eosinophilic Esophagitis, especially in a pediatric patient.'), ("Sjogren's Syndrome", '5', " Dry mouth along with joint tenderness and rash on knuckles may suggest Sjogren's Syndrome."), ('Congestive Heart Failure', '5', ' Chest pain, hepatomegaly, and restrictive lung disease could point towards congestive heart failure as a differential diagnosis.')], [('Juvenile idiopathic arthritis', '50', ' Joint tenderness and fever are common symptoms in juvenile idiopathic arthritis. '), ("Raynaud's phenomenon", '20', " Finger turning blue is a classic symptom of Raynaud's phenomenon."), ('Esophageal stricture', '15', ' Food getting stuck in the throat could be a sign of esophageal stricture.'), ('Infectious mononucleosis', '10', ' Fever and hepatomegaly are common symptoms in infectious mononucleosis.'), ('Systemic lupus erythematosus', '5', ' Joint tenderness, renal disease, and hepatomegaly can be seen in systemic lupus erythematosus.')], [('Juvenile idiopathic arthritis', '60', ' Joint tenderness, rosy cheeks, and effusion are all consistent with juvenile idiopathic arthritis, which can present with joint pain, swelling, and tenderness.'), ("Raynaud's phenomenon", '20', " Finger turning blue is a classic symptom of Raynaud's phenomenon, which causes vasospasms in the fingers in response to cold or stress."), ('Scarlet fever', '10', ' Rosy cheeks and trouble swallowing can be seen in scarlet fever, a bacterial infection caused by group A Streptococcus.'), ('Rheumatic fever', '5', ' Joint tenderness, rosy cheeks, and trouble swallowing can be seen in rheumatic fever, which is a complication of untreated streptococcal infections.'), ('Systemic lupus erythematosus', '5', ' Joint tenderness and effusion can be seen in systemic lupus erythematosus, an autoimmune disease that can affect multiple organs, including the joints.')], [('Juvenile Idiopathic Arthritis', '60', ' The patient presents with joint tenderness, fever, and effusion which are consistent with Juvenile Idiopathic Arthritis. '), ('Systemic Sclerosis (Scleroderma)', '20', ' Hard skin and muscular weakness could be indicative of systemic sclerosis.'), ('Juvenile Dermatomyositis', '10', ' The combination of muscular weakness, joint tenderness, and fever may suggest Juvenile Dermatomyositis.'), ('Rheumatic Fever', '5', ' Fever, joint tenderness, and muscular weakness can be seen in Rheumatic Fever.'), ('Juvenile Rheumatoid Arthritis', '5', ' Joint tenderness, fever, and effusion are co ...

# %%
dump_responses_to_file(informal_symptom_list, all_parsed_responses_informal, f'{ground_truth}-informal-chatgpt-3.5.txt', patient_nominal_gender, patient_nominal_age, patient_nominal_weight, patient_nominal_height)

# %%
print('Top Responses')
top_responses_informal = [resp[0][0] for resp in all_parsed_responses_informal if len(resp) >= 1] 
get_frequencies(top_responses_informal)
# Out:
# Top Responses
# {"raynaud's disease": 6,
#  "raynaud's phenomenon": 26,
#  'eosinophilic esophagitis': 2,
#  'tetralogy of fallot': 1,
#  'juvenile idiopathic arthritis (jia)': 1,
#  'juvenile rheumatoid arthritis': 9,
#  'systemic lupus erythematosus': 99,
#  'esophageal dysmotility': 1,
#  'juvenile dermatomyositis': 17,
#  'systemic sclerosis': 42,
#  'esophageal stricture': 1,
#  'systemic lupus erythematosus (sle)': 40,
#  'cystic fibrosis': 2,
#  'juvenile systemic sclerosis': 28,
#  'rheumatic fever': 5,
#  'juvenile idiopathic arthritis': 708,
#  'viral infection': 4,
#  'kawasaki disease': 4,
#  'renal disease': 1,
#  'systemic sclerosis (scleroderma)': 3}

# %%
top_three_tmp = [[resp[0][0], resp[1][0], resp[2][0]] for resp in all_parsed_responses_informal if len(resp) >= 3]
top_three_responses_informal = [x for lst in top_three_tmp for x in lst]
print('Top three responses')
get_frequencies(top_three_responses_informal)
# Out:
# Top three responses
# {"raynaud's disease": 40,
#  'scleroderma': 65,
#  'duchenne muscular dystrophy': 6,
#  'infectious hepatitis': 1,
#  'strep throat infection': 1,
#  'rheumatic heart disease': 2,
#  'eosinophilic granulomatosis with polyangiitis (egpa)': 1,
#  'myasthenia gravis': 15,
#  'vasculitis': 1,
#  'esophageal stricture': 18,
#  'type 1 diabetes': 1,
#  'eosinophilic granulomatosis with polyangiitis (churg-strauss syndrome)': 7,
#  'juvenile systemic lupus erythematosus': 28,
#  'mixed connective tissue disease': 6,
#  'systemic lupus erythematosus (sle)': 358,
#  'mitochondrial disease': 1,
#  'congestive heart failure': 1,
#  'juvenile idiopathic arthritis': 836,
#  'muscular dystrophy': 4,
#  'infectious disease (e.g. viral or bacterial infection)': 1,
#  'infective endocarditis': 2,
#  'juvenile scleroderma': 3,
#  'juvenile psychiatric disorder': 1,
#  'streptococcal pharyngitis': 1,
#  'viral infection': 7,
#  'cardiac condition (such as pericarditis)': 1,
#  'kawasaki disease': 124,
#  'renal disease': 1,
#  'cardiomyopathy': 2,
#  'systemic sclerosis (scleroderma)': 75,
#  "thromboangiitis obliterans (buerger's disease)": 1,
#  "sjogren's syndrome": 66,
#  "raynaud's phenomenon": 269,
#  'eosinophilic esophagitis': 82,
#  'henoch-schönlein purpura': 1,
#  'sickle cell anemia': 1,
#  'hepatitis': 2,
#  'streptococcal infection': 1,
#  'hyperthyroidism': 1,
#  'esophageal dysphagia': 2,
#  'infectious mononucleosis': 5,
#  'juvenile dermatomyositis': 168,
#  'systemic sclerosis': 230,
#  'lupus': 13,
#  "sjögren's syndrome": 4,
#  'viral infection (e.g., mononucleosis)': 1,
#  'dehydration': 1,
#  'costochondritis': 3,
#  'systemic juvenile idiopathic arthritis': 2,
#  'pulmonary fibrosis': 1,
#  'familial mediterranean fever': 1,
#  'chiari malformation': 1,
#  'tetralogy of fallot': 1,
#  'pulmonary hypertension': 4,
#  'juvenile idiopathic arthritis (jia)': 25,
#  'acute rheumatic fever': 1,
#  'pericarditis': 1,
#  'systemic lupus erythematosus': 264,
#  'dilated cardiomyopathy': 1,
#  'pneumonia': 1,
#  'diabetic ketoacidosis': 1,
#  'juvenile systemic lupus erythematosus (sle)': 2,
#  'tuberculosis meningitis': 1,
#  'juvenile systemic sclerosis': 56,
#  'rheumatic fever': 50,
#  'atopic dermatitis': 1,
#  'infection': 1,
#  'dermatomyositis': 22,
#  'viral hepatitis': 2,
#  'systemic juvenile idiopathic arthritis (sjia)': 1,
#  'myocarditis': 5,
#  'influenza': 2,
#  'scarlet fever': 5,
#  'congenital heart disease': 6,
#  'guillain-barre syndrome': 1,
#  'sickle cell disease': 2,
#  'viral myositis': 2,
#  'henoch-schonlein purpura': 1,
#  'infection (possibly bacterial)': 1,
#  'lupus nephritis': 4,
#  'rheumatoid arthritis': 2,
#  'juvenile rheumatoid arthritis': 14,
#  'pediatric autoimmune neuropsychiatric disorders associated with streptococcal infections (pandas)': 1,
#  'esophageal dysmotility': 2,
#  'cardiac disease': 1,
#  'juvenile myasthenia gravis': 1,
#  'mononucleosis': 1,
#  "juvenile sjogren's syndrome": 1,
#  'juvenile myositis': 8,
#  'myositis': 1,
#  'cystic fibrosis': 9,
#  "wilson's disease": 3,
#  'gastroesophageal reflux disease (gerd)': 4,
#  'meningitis': 2,
#  'viral infection (such as mononucleosis)': 1,
#  'eosinophilic fasciitis': 3,
#  'hypothyroidism': 8,
#  'tuberculosis': 1,
#  'mixed connective tissue disease (mctd)': 6,
#  'systemic vasculitis': 1}

# %%
print(p0)
# Out:
# The patient is a 10 year old female with a weight of 54 lbs and height of 46 inches. The list of symptoms include  (1) Joint stiffness (2) Fingers turning white (3) Hard skin (4) Rash on cheeks (5) Hand rash (6) Fever (7) Chest pain and (8) Abnormal lung  diffusion.

# %%
import anthropic


anthropic_client = anthropic.Anthropic(
    api_key="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",
)

message = anthropic_client.messages.create(
    model="claude-3-sonnet-20240229",
    max_tokens=1000,
    temperature=0,
    system="I am taking care of a patient and would like your help generating a differential diagnosis.  I will provide details \n        about the patient and the symptoms below. Please output upto 5 conditions that are consistent with the symptoms sorted from the most likely to the least. Your \n        output must be in the format wherein each of the conditions must be in a separate line.\n                        1. <name of condition/disease>, <probability of this disease as a percentage>, <brief rationale as to why the patient may have this disease>\n                        2. <name of condition/disease>, <probability of this disease as a percentage>, <brief rationale as to why the patient may have this disease>\n                        ...\n                        5. <name of condition/disease>, <probability of this disease as a percentage>, <brief rationale as to why the patient may have this disease>",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": f"{p0}"
                }
            ]
        }
    ]
)
print(message.content)
# Out:
# [TextBlock(text="1. Systemic Lupus Erythematosus (SLE), 40%, The combination of joint stiffness, rash on cheeks (malar rash), fever, and chest pain are common symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.\n\n2. Juvenile Idiopathic Arthritis (JIA), 30%, Joint stiffness, fever, and rash on the hands are common manifestations of JIA, a type of arthritis that occurs in children.\n\n3. Raynaud's Phenomenon, 20%, The symptom of fingers turning white could be indicative of Raynaud's phenomenon, a condition characterized by reduced blood flow to the extremities due to vasospasm.\n\n4. Scleroderma, 15%, The hard skin and Raynaud's phenomenon could suggest scleroderma, an autoimmune disorder that causes skin thickening and vasculopathy.\n\n5. Interstitial Lung Disease, 10%, The abnormal lung diffusion and chest pain could be indicative of an underlying interstitial lung disease, which can be associated with autoimmune disorders like SLE or scleroderma.", type='text')]

# %%
parse_response(message.content[0].text)
# Out:
# [('Systemic Lupus Erythematosus (SLE)',
#   '40',
#   ' The combination of joint stiffness, rash on cheeks (malar rash), fever, and chest pain are common symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.'),
#  ('Juvenile Idiopathic Arthritis (JIA)',
#   '30',
#   ' Joint stiffness, fever, and rash on the hands are common manifestations of JIA, a type of arthritis that occurs in children.'),
#  ("Raynaud's Phenomenon",
#   '20',
#   " The symptom of fingers turning white could be indicative of Raynaud's phenomenon, a condition characterized by reduced blood flow to the extremities due to vasospasm."),
#  ('Scleroderma',
#   '15',
#   " The hard skin and Raynaud's phenomenon could suggest scleroderma, an autoimmune disorder that causes skin thickening and vasculopathy."),
#  ('Interstitial Lung Disease',
#   '10',
#   ' The abnormal lung diffusion and chest pain could be indicative of an underlying interstitial lung disease, which can be associated with autoimmune disorders like SLE or scleroderma.')]

# %%
import anthropic


anthropic_client = anthropic.Anthropic(
    api_key="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",
)

def prompt_anthropic(prompt_str):
    message = anthropic_client.messages.create(
        model="claude-3-sonnet-20240229",
        max_tokens=1000,
        temperature=0,
        system="I am taking care of a patient and would like your help generating a differential diagnosis.  I will provide details \n        about the patient and the symptoms below. Please output upto 5 conditions that are consistent with the symptoms sorted from the most likely to the least. Your \n        output must be in the format wherein each of the conditions must be in a separate line.\n                        1. <name of condition/disease>, <probability of this disease as a percentage>, <brief rationale as to why the patient may have this disease>\n                        2. <name of condition/disease>, <probability of this disease as a percentage>, <brief rationale as to why the patient may have this disease>\n                        ...\n                        5. <name of condition/disease>, <probability of this disease as a percentage>, <brief rationale as to why the patient may have this disease>",
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": f"{prompt_str}"
                    }
                ]
            }
        ]
    )
    return message.content[0].text 

def run_symptoms_list_anthropic_and_parse_responses(symptoms_list_list, gender, age, weight, height, max_n=None):
    count = 0
    all_parsed_responses = []
    for symptoms_list in symptoms_list_list:
        p0 = make_prompt(symptoms_list, gender, age, weight, height)
        r0 = prompt_anthropic(p0)
        parsed_r0 = parse_response(r0)
        all_parsed_responses.append(parsed_r0)
        count = count + 1
        if max_n != None and count >= max_n:
            return all_parsed_responses
    return all_parsed_responses

# %%
claude_all_parsed_responses_formal = run_symptoms_list_anthropic_and_parse_responses(formal_symptom_list, patient_nominal_gender, patient_nominal_age, patient_nominal_weight, patient_nominal_height, max_n=None)

# %%
print(claude_all_parsed_responses_formal)
# Out:
# [[('Juvenile Dermatomyositis', '70', " The combination of arthritis, Gottron's papules (characteristic rash), abnormal esophageal motility, cardiac involvement, and muscle disease is highly suggestive of juvenile dermatomyositis, an autoimmune inflammatory disorder affecting muscles and skin."), ('Mixed Connective Tissue Disease', '15', ' The presence of arthritis, muscle disease, and potential cardiac involvement could indicate mixed connective tissue disease, an overlap syndrome with features of various autoimmune disorders.'), ('Systemic Lupus Erythematosus', '10', ' Arthritis, muscle disease, and potential cardiac involvement can also be seen in systemic lupus erythematosus, an autoimmune disorder that can affect multiple organ systems.'), ('Scleroderma', '3', ' Abnormal esophageal motility and potential cardiac involvement could suggest scleroderma, an autoimmune disorder characterized by excessive collagen deposition in various tissues.'), ('Inflammatory Myopathy', '2', ' The muscle disease and potential cardiac involvement could indicate an inflammatory myopathy, such as polymyositis or inclusion body myositis, which primarily affects skeletal muscles.')], [('Systemic Lupus Erythematosus (SLE)', '60', ' The combination of arthritis, malar rash, fever, and potential involvement of multiple organs (cardiac, muscle, and lung) is highly suggestive of SLE.'), ('Mixed Connective Tissue Disease (MCTD)', '20', " The presence of Raynaud's phenomenon, arthritis, and potential involvement of multiple organs could indicate MCTD, which is an overlap syndrome with features of SLE, scleroderma, and polymyositis."), ('Juvenile Dermatomyositis', '15', " The presence of Gottron's papules, muscle disease, and potential lung involvement could suggest juvenile dermatomyositis, an inflammatory myopathy."), ('Scleroderma', '3', " The presence of Raynaud's phenomenon and potential lung involvement could be indicative of scleroderma, although the other symptoms are less specific."), ('Rheumatoid Arthritis', '2', ' The arthritis could potentially be due to rheumatoid arthritis, but the other symptoms are not typical of this condition in a child.')], [('Systemic Lupus Erythematosus (SLE)', '60', " The combination of arthritis, Raynaud's phenomenon, fever, pericarditis, and muscle disease are common manifestations of SLE, particularly in children."), ('Juvenile Dermatomyositis', '25', " The presence of muscle disease, Raynaud's phenomenon, and sclerodermatous skin changes are characteristic of juvenile dermatomyositis, an autoimmune condition affecting children."), ('Mixed Connective Tissue Disease (MCTD)', '10', " The overlap of symptoms such as Raynaud's phenomenon, arthritis, sclerodermatous skin changes, and muscle disease can be seen in MCTD, which combines features of various autoimmune disorders."), ('Scleroderma', '3', " The sclerodermatous skin changes, Raynaud's phenomenon, and abnormal esophageal motility are consistent with scleroderma, although the other symptoms are less common in this condition."), ('Juvenile Idiopathic Arthritis (JIA)', '2', ' The presence of arthritis and fever could suggest JIA, but the other symptoms are not typically associated with this condition.')], [('Systemic Lupus Erythematosus (SLE)', '60', ' The combination of arthritis, malar rash, pericarditis, and abnormal lung diffusion are highly suggestive of SLE in a young female patient.'), ('Mixed Connective Tissue Disease (MCTD)', '20', " The presence of Raynaud's phenomenon, arthritis, and potential lung involvement could indicate MCTD, which can overlap with lupus and other autoimmune disorders."), ('Juvenile Dermatomyositis', '15', " The presence of Gottron's papules, which are characteristic skin manifestations, along with arthritis and potential lung involvement, could suggest juvenile dermatomyositis."), ('Rheumatoid Arthritis', '3', ' While arthritis is present, the other symptoms are not typical of rheumatoid arthritis, especially in a young female pat ...

# %%
dump_responses_to_file(formal_symptom_list, claude_all_parsed_responses_formal, f'{ground_truth}-formal-claude-3-opus.txt', patient_nominal_gender, patient_nominal_age, patient_nominal_weight, patient_nominal_height)

# %%
print('Top Responses')
top_responses_formal = [resp[0][0] for resp in claude_all_parsed_responses_formal]
get_frequencies(top_responses_formal)
# Out:
# Top Responses
# {'juvenile idiopathic arthritis (jia)': 9,
#  'systemic sclerosis (scleroderma)': 7,
#  'systemic lupus erythematosus (sle)': 159,
#  'juvenile dermatomyositis': 75}

# %%
top_three_tmp = [[resp[0][0], resp[1][0], resp[2][0]] for resp in claude_all_parsed_responses_formal]
top_three_responses_formal = [x for lst in top_three_tmp for x in lst]
print('Top three responses')
get_frequencies(top_three_responses_formal)
# Out:
# Top three responses
# {'mixed connective tissue disease': 25,
#  'systemic lupus erythematosus': 23,
#  'systemic lupus erythematosus (sle)': 219,
#  'juvenile dermatomyositis': 209,
#  'scleroderma': 2,
#  'scleroderma (systemic sclerosis)': 5,
#  'mixed connective tissue disease (mctd)': 214,
#  'juvenile idiopathic arthritis (jia)': 41,
#  'systemic sclerosis (scleroderma)': 10,
#  "sjogren's syndrome": 2}

# %%
claude_all_parsed_responses_informal = run_symptoms_list_anthropic_and_parse_responses(informal_symptom_list, patient_nominal_gender, patient_nominal_age, patient_nominal_weight, patient_nominal_height, max_n=None)

# %%
print(claude_all_parsed_responses_informal)
# Out:
# [[('Systemic Lupus Erythematosus (SLE)', '40', ' Joint tenderness, fever, cardiac disease, and restrictive lung disease are common manifestations of SLE in children.'), ('Mixed Connective Tissue Disease (MCTD)', '30', " MCTD can present with joint pain, Raynaud's phenomenon (fingers turning white), fever, and lung involvement."), ('Juvenile Idiopathic Arthritis (JIA)', '20', ' Joint tenderness, fever, and restrictive lung disease can be seen in JIA, particularly the systemic onset type.'), ('Scleroderma', '15', " Raynaud's phenomenon, restrictive lung disease, and cardiac involvement can occur in juvenile scleroderma."), ('Vasculitis', '10', " Vasculitis can cause joint pain, fever, Raynaud's phenomenon, and lung involvement, although less common in children.")], [('Systemic Sclerosis (Scleroderma)', '70', " The combination of tight skin, Raynaud's phenomenon (cold hands), joint tenderness, dysphagia (trouble swallowing solids), interstitial lung disease (abnormal lung diffusion, restrictive lung disease), and hepatomegaly are classic features of systemic sclerosis."), ('Mixed Connective Tissue Disease (MCTD)', '15', " The presence of Raynaud's phenomenon, joint tenderness, lung involvement, and rash could suggest MCTD, which is an overlap syndrome with features of systemic lupus erythematosus, systemic sclerosis, and polymyositis."), ('Juvenile Dermatomyositis', '10', ' The rash on the knuckles, muscle weakness (suggested by the difficulty swallowing solids), and lung involvement could be indicative of juvenile dermatomyositis, an inflammatory myopathy.'), ("Sjögren's Syndrome", '3', " The dry mouth and joint tenderness could be signs of Sjögren's syndrome, an autoimmune disorder that affects the exocrine glands."), ('Juvenile Idiopathic Arthritis', '2', ' The joint tenderness and rash could be manifestations of juvenile idiopathic arthritis, although the other symptoms are not typical of this condition.')], [('Juvenile Idiopathic Arthritis (JIA)', '40', ' Joint tenderness and fever are common symptoms of JIA, which is an autoimmune disorder affecting children.'), ("Raynaud's Phenomenon", '25', " Finger turning blue could be a sign of Raynaud's, a condition that causes poor blood circulation in the extremities."), ('Esophageal Stricture', '15', ' Food getting stuck in the throat may indicate an esophageal stricture or narrowing of the esophagus.'), ('Hepatitis', '10', ' Hepatomegaly (enlarged liver) and fever could be signs of viral hepatitis or other liver diseases.'), ('Glomerulonephritis', '10', " Renal disease and fever may suggest glomerulonephritis, an inflammation of the kidney's filtering units.")], [('Juvenile Idiopathic Arthritis (JIA)', '40', ' Joint tenderness and effusion are common symptoms of JIA, which is an autoimmune disorder affecting children.'), ("Raynaud's Phenomenon", '25', " Finger turning blue could be a sign of Raynaud's, a condition that causes poor blood circulation in the extremities."), ('Lupus', '15', ' Rosy cheeks, joint pain, and trouble swallowing can be symptoms of lupus, an autoimmune disorder that can affect multiple organ systems.'), ('Kawasaki Disease', '10', ' Rosy cheeks, swollen joints, and trouble swallowing are potential symptoms of this rare childhood illness that affects blood vessels.'), ('Rheumatic Fever', '10', ' Joint pain, trouble swallowing, and rash (potentially causing rosy cheeks) can occur in rheumatic fever, a complication of untreated strep throat.')], [('Juvenile Idiopathic Arthritis (JIA)', '40', ' Joint tenderness, fever, and effusion are common symptoms of JIA, which is an autoimmune disorder affecting children.'), ('Systemic Lupus Erythematosus (SLE)', '25', ' Hard skin (due to potential skin rashes), fever, and muscular weakness can be seen in SLE, an autoimmune disorder affecting multiple organs.'), ('Dermatomyositis', '15', ' Muscular weakness, hard skin (due to potential skin rashes), and fever are characteristic of dermatomyositis, an inflammatory myopathy.') ...

# %%
dump_responses_to_file(informal_symptom_list, claude_all_parsed_responses_informal, f'{ground_truth}-informal-claude-3-opus.txt', patient_nominal_gender, patient_nominal_age, patient_nominal_weight, patient_nominal_height)

# %%
print('Top Responses')
top_responses_informal = [resp[0][0] for resp in claude_all_parsed_responses_informal]
get_frequencies(top_responses_informal)
# Out:
# Top Responses
# {'tracheoesophageal fistula': 1,
#  "raynaud's phenomenon": 5,
#  'scleroderma': 6,
#  'juvenile idiopathic arthritis (jia)': 237,
#  'juvenile dermatomyositis': 87,
#  'esophageal stricture': 1,
#  "sjögren's syndrome": 1,
#  'systemic lupus erythematosus (sle)': 543,
#  'glycogen storage disease': 1,
#  'systemic scleroderma (diffuse cutaneous systemic sclerosis)': 2,
#  'eisenmenger syndrome': 1,
#  'dermatomyositis': 1,
#  'sickle cell disease': 1,
#  'viral infection (e.g., influenza, common cold)': 1,
#  'leukemia': 1,
#  'juvenile rheumatoid arthritis (jra)': 1,
#  'kawasaki disease': 7,
#  "eisenmenger's syndrome": 1,
#  'achalasia': 1,
#  'systemic sclerosis (scleroderma)': 101}

# %%
top_three_tmp = [[resp[0][0], resp[1][0], resp[2][0]] for resp in claude_all_parsed_responses_informal]
top_three_responses_informal = [x for lst in top_three_tmp for x in lst]
print('Top three responses')
get_frequencies(top_three_responses_informal)
# Out:
# Top three responses
# {'tracheoesophageal fistula': 1,
#  "raynaud's phenomenon": 164,
#  'eosinophilic esophagitis': 10,
#  'autoimmune hepatitis': 1,
#  'scleroderma': 220,
#  'henoch-schönlein purpura': 1,
#  'viral infection (e.g., influenza, adenovirus)': 2,
#  'pulmonary hypertension': 2,
#  'interstitial lung disease (ild)': 4,
#  'juvenile idiopathic arthritis (jia)': 451,
#  'rheumatoid arthritis': 4,
#  'esophageal stricture or dysphagia': 3,
#  'acute rheumatic fever': 1,
#  'lyme disease': 1,
#  'congenital heart disease': 2,
#  'juvenile rheumatoid arthritis': 2,
#  'systemic lupus erythematosus': 4,
#  'polymyositis/dermatomyositis': 1,
#  'henoch-schönlein purpura (hsp)': 5,
#  'juvenile dermatomyositis': 412,
#  'esophageal dysmotility': 2,
#  'vasculitis': 22,
#  'viral myocarditis': 1,
#  'meningococcal meningitis': 3,
#  'chronic kidney disease': 1,
#  'anemia': 1,
#  'esophageal stricture or achalasia': 4,
#  'esophageal stricture': 14,
#  'lupus': 4,
#  'viral infection (e.g., epstein-barr virus, cytomegalovirus)': 1,
#  'chronic liver disease': 1,
#  "sjögren's syndrome": 32,
#  'pulmonary arterial hypertension': 1,
#  'lupus erythematosus': 2,
#  'mixed connective tissue disease': 19,
#  'systemic lupus erythematosus (sle)': 772,
#  'sarcoidosis': 1,
#  'polyarteritis nodosa': 7,
#  'dehydration': 2,
#  'glycogen storage disease': 1,
#  'systemic scleroderma (diffuse cutaneous systemic sclerosis)': 2,
#  'rheumatic fever': 13,
#  'juvenile idiopathic arthritis': 20,
#  'muscular dystrophy': 3,
#  'meningitis': 2,
#  'eisenmenger syndrome': 1,
#  'costochondritis': 1,
#  'thalassemia': 1,
#  'dermatomyositis': 39,
#  'sickle cell disease': 3,
#  'viral infection (e.g., influenza, common cold)': 1,
#  'hypothyroidism': 2,
#  'leukemia': 9,
#  'streptococcal pharyngitis': 3,
#  'juvenile rheumatoid arthritis (jra)': 1,
#  'interstitial lung disease': 1,
#  'viral infection': 1,
#  'scleroderma (systemic sclerosis)': 6,
#  'lymphoma': 1,
#  'kawasaki disease': 36,
#  'mixed connective tissue disease (mctd)': 555,
#  'eosinophilic esophagitis (eoe)': 2,
#  'anxiety disorder or depression': 1,
#  'growing pains': 1,
#  "eisenmenger's syndrome": 1,
#  'achalasia': 2,
#  'systemic sclerosis (scleroderma)': 105,
#  'streptococcal pharyngitis (strep throat)': 1,
#  "sjogren's syndrome": 4}
