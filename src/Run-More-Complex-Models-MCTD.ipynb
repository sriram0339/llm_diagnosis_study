# %%
import pandas
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from openai import OpenAI
import utils

# %%
disease='MCTD'
symp_type='informal'
#model_old='chatgpt-3.5'
#model_new='chatgpt-4o'
#model_new_name = 'gpt-4o'


model_old='claude-3-opus'
model_new='claude-3.5-sonnet'
model_new_name = 'claude-3-5-sonnet-20240620'

filename=f'data/{disease}-{symp_type}-{model_old}.txt'
output_filename = f'data/{disease}-{symp_type}-{model_new}.txt'
keywords_list = ['mctd', 'mixed connective tissue disease']

# %% [markdown]
# ## Run More Complex Models
#
# The goal is to run more complex models and compare against the outputs of the baseline model.

# %%
all_patients = utils.process_file(filename)
# Out:
# Patient: number 1, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Fingers turning white
# Symptom: Fever
# Symptom: Cardiac disease
# Symptom: Chest pain
# Symptom: Abnormal lung  diffusion
# Symptom: Restrictive lung disese
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Joint tenderness, fever, cardiac disease, and restrictive lung disease are common manifestations of SLE in children.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,30%,*MCTD can present with joint pain, Raynaud's phenomenon (fingers turning white), fever, and lung involvement.*
# response: 3,*Juvenile Idiopathic Arthritis (JIA)*,20%,*Joint tenderness, fever, and restrictive lung disease can be seen in JIA, particularly the systemic onset type.*
# response: 4,*Scleroderma*,15%,*Raynaud's phenomenon, restrictive lung disease, and cardiac involvement can occur in juvenile scleroderma.*
# response: 5,*Vasculitis*,10%,*Vasculitis can cause joint pain, fever, Raynaud's phenomenon, and lung involvement, although less common in children.*
# Patient: number 2, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Cold hands
# Symptom: Tight skin
# Symptom: rash on kncules
# Symptom: Trouble swallowing solids
# Symptom: Chest pain
# Symptom: Dry mouth
# Symptom: Abnormal lung  diffusion
# Symptom: Restrictive lung disese
# Symptom: Hepatomegaly
# response: 1,*Systemic Sclerosis (Scleroderma)*,70%,*The combination of tight skin, Raynaud's phenomenon (cold hands), joint tenderness, dysphagia (trouble swallowing solids), interstitial lung disease (abnormal lung diffusion, restrictive lung disease), and hepatomegaly are classic features of systemic sclerosis.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,15%,*The presence of Raynaud's phenomenon, joint tenderness, lung involvement, and rash could suggest MCTD, which is an overlap syndrome with features of systemic lupus erythematosus, systemic sclerosis, and polymyositis.*
# response: 3,*Juvenile Dermatomyositis*,10%,*The rash on the knuckles, muscle weakness (suggested by the difficulty swallowing solids), and lung involvement could be indicative of juvenile dermatomyositis, an inflammatory myopathy.*
# response: 4,*Sjögren's Syndrome*,3%,*The dry mouth and joint tenderness could be signs of Sjögren's syndrome, an autoimmune disorder that affects the exocrine glands.*
# response: 5,*Juvenile Idiopathic Arthritis*,2%,*The joint tenderness and rash could be manifestations of juvenile idiopathic arthritis, although the other symptoms are not typical of this condition.*
# Patient: number 3, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Finger turning blue
# Symptom: Fever
# Symptom: Food gets stuck in throat
# Symptom: Hepatomegaly
# Symptom: Renal disease
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint tenderness and fever are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Raynaud's Phenomenon*,25%,*Finger turning blue could be a sign of Raynaud's, a condition that causes poor blood circulation in the extremities.*
# response: 3,*Esophageal Stricture*,15%,*Food getting stuck in the throat may indicate an esophageal stricture or narrowing of the esophagus.*
# response: 4,*Hepatitis*,10%,*Hepatomegaly (enlarged liver) and fever could be signs of viral hepatitis or other liver diseases.*
# response: 5,*Glomerulonephritis*,10%,*Renal disease and fever may suggest glomerulonephritis, an inflammation of the kidney's filtering units.*
# Patient: number 4, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Finger turning blue
# Symptom: Rosy cheeks
# Symptom: Trouble swallowing
# Symptom: Effusion
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint tenderness and effusion are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Raynaud's Phenomenon*,25%,*Finger turning blue could be a sign of Raynaud's, a condition that causes poor blood circulation in the extremities.*
# response: 3,*Lupus*,15%,*Rosy cheeks, joint pain, and trouble swallowing can be symptoms of lupus, an autoimmune disorder that can affect multiple organ systems.*
# response: 4,*Kawasaki Disease*,10%,*Rosy cheeks, swollen joints, and trouble swallowing are potential symptoms of this rare childhood illness that affects blood vessels.*
# response: 5,*Rheumatic Fever*,10%,*Joint pain, trouble swallowing, and rash (potentially causing rosy cheeks) can occur in rheumatic fever, a complication of untreated strep throat.*
# Patient: number 5, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Hard skin
# Symptom: Fever
# Symptom: Muscular Weakness
# Symptom: Effusion
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint tenderness, fever, and effusion are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Systemic Lupus Erythematosus (SLE)*,25%,*Hard skin (due to potential skin rashes), fever, and muscular weakness can be seen in SLE, an autoimmune disorder affecting multiple organs.*
# response: 3,*Dermatomyositis*,15%,*Muscular weakness, hard skin (due to potential skin rashes), and fever are characteristic of dermatomyositis, an inflammatory myopathy.*
# response: 4,*Juvenile Dermatomyositis*,10%,*Similar to dermatomyositis, but specifically affecting children, with symptoms like muscular weakness, hard skin, and fever.*
# response: 5,*Reactive Arthritis*,10%,*Joint tenderness, fever, and effusion can be seen in reactive arthritis, which is an inflammatory arthritis triggered by an infection.*
# Patient: number 6, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Cold hands
# Symptom: Rosy cheeks
# Symptom: Fever
# Symptom: Cardiac disease
# Symptom: Muscular Weakness
# Symptom: Dry mouth
# Symptom: Renal disease
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint pain, fever, and muscular weakness are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Systemic Lupus Erythematosus (SLE)*,30%,*Rosy cheeks, joint pain, fever, and renal disease are consistent with SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 3,*Rheumatic Fever*,15%,*Fever, joint pain, and cardiac disease are common symptoms of rheumatic fever, which is a complication of untreated streptococcal infection.*
# response: 4,*Sjogren's Syndrome*,10%,*Dry mouth, joint pain, and muscular weakness are symptoms of Sjogren's syndrome, an autoimmune disorder that affects exocrine glands.*
# response: 5,*Raynaud's Phenomenon*,5%,*Cold hands and joint pain can be associated with Raynaud's phenomenon, a condition that causes reduced blood flow to the extremities.*
# Patient: number 7, gender female, age 10, weight 54, height 46
# Symptom: Cold hands
# Symptom: Shiny skin
# Symptom: Rosy cheeks
# Symptom: Trouble swallowing
# Symptom: Cardiac disease
# Symptom: Muscular Weakness
# Symptom: Restrictive lung disese
# Symptom: Splenomegaly
# Symptom: Renal disease
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of symptoms such as cold hands, shiny skin, rosy cheeks, trouble swallowing, cardiac disease, muscular weakness, restrictive lung disease, splenomegaly, and renal disease are consistent with SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,30%,*MCTD is a rare autoimmune disorder that shares features with SLE, scleroderma, and polymyositis, which could explain the diverse symptoms observed in this patient, including skin manifestations, muscle weakness, and multi-organ involvement.*
# response: 3,*Scleroderma*,15%,*The presence of shiny skin, Raynaud's phenomenon (cold hands), and potential involvement of the gastrointestinal tract (trouble swallowing) and lungs (restrictive lung disease) could suggest scleroderma, a connective tissue disorder characterized by excessive collagen deposition.*
# response: 4,*Juvenile Dermatomyositis*,10%,*The combination of muscular weakness, skin rash (shiny skin, rosy cheeks), and potential lung involvement (restrictive lung disease) could be indicative of juvenile dermatomyositis, an autoimmune inflammatory disorder affecting the muscles and skin.*
# response: 5,*Juvenile Idiopathic Arthritis (JIA)*,5%,*While not a perfect fit, JIA is a possibility given the patient's age and the potential for multi-organ involvement, including joint pain, skin rash, and organ manifestations such as splenomegaly and renal disease.*
# Patient: number 8, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Shiny skin
# Symptom: rash on kncules
# Symptom: Trouble swallowing liquids
# Symptom: Chest pain
# Symptom: Sore muscles
# Symptom: Dry eyes
# Symptom: Cognitive issues
# Symptom: Hepatomegaly
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of joint pain, rash, cognitive issues, and hepatomegaly are common manifestations of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,25%,*The presence of joint pain, rash, muscle soreness, and cognitive issues could indicate MCTD, which is an overlap syndrome with features of lupus, scleroderma, and polymyositis.*
# response: 3,*Juvenile Dermatomyositis*,15%,*The rash, muscle weakness, and joint pain could suggest juvenile dermatomyositis, an inflammatory muscle disease that can also involve the skin.*
# response: 4,*Sjögren's Syndrome*,10%,*The dry eyes, joint pain, and rash could be indicative of Sjögren's syndrome, an autoimmune disorder that affects the moisture-producing glands.*
# response: 5,*Juvenile Idiopathic Arthritis (JIA)*,10%,*The joint pain, rash, and hepatomegaly could be manifestations of JIA, a group of autoimmune disorders characterized by chronic joint inflammation.*
# Patient: number 9, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Cold hands
# Symptom: Fever
# Symptom: Trouble swallowing liquids
# Symptom: Cardiac disease
# Symptom: Muscular Weakness
# Symptom: Abnormal lung  diffusion
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint stiffness, fever, and muscular weakness are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Systemic Lupus Erythematosus (SLE)*,25%,*SLE is an autoimmune disease that can cause joint stiffness, fever, and cardiac involvement, which may explain the cardiac disease symptom.*
# response: 3,*Mixed Connective Tissue Disease (MCTD)*,15%,*MCTD is an autoimmune disorder that can present with symptoms similar to lupus, rheumatoid arthritis, and scleroderma, including joint stiffness, fever, and muscular weakness.*
# response: 4,*Dermatomyositis*,10%,*Dermatomyositis is an inflammatory muscle disease that can cause muscular weakness, fever, and lung involvement, which may explain the abnormal lung diffusion symptom.*
# response: 5,*Scleroderma*,10%,*Scleroderma is an autoimmune disorder that can cause joint stiffness, Raynaud's phenomenon (cold hands), and lung involvement, which may explain the abnormal lung diffusion symptom.*
# Patient: number 10, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Fingers turning white
# Symptom: Hard skin
# Symptom: Rash on face
# Symptom: Fever
# Symptom: Sore muscles
# Symptom: Dry eyes
# Symptom: Psychiatric issues
# Symptom: Abnormal lung  diffusion
# Symptom: Hepatomegaly
# Symptom: Renal disease
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The combination of joint stiffness, rash, fever, muscle soreness, and potential organ involvement (lung, liver, and kidney) is highly suggestive of SLE.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,20%,*The presence of Raynaud's phenomenon (fingers turning white), joint stiffness, rash, and potential organ involvement could indicate MCTD, which is an overlap syndrome with features of SLE, scleroderma, and polymyositis.*
# response: 3,*Juvenile Dermatomyositis*,10%,*The muscle soreness, rash, and potential lung involvement could be indicative of juvenile dermatomyositis, an inflammatory myopathy.*
# response: 4,*Scleroderma*,5%,*The hard skin and Raynaud's phenomenon could suggest scleroderma, although the other symptoms are less typical for this condition.*
# response: 5,*Juvenile Idiopathic Arthritis (JIA)*,5%,*The joint stiffness and fever could be consistent with JIA, but the other symptoms are less typical for this condition.*
# Patient: number 11, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Cold hands
# Symptom: Dry eyes
# Symptom: Abnormal lung  diffusion
# response: 1,*Juvenile Rheumatoid Arthritis (JRA)*,40%,*Joint stiffness and cold hands can be symptoms of JRA, an autoimmune disorder that causes joint inflammation and other systemic manifestations.*
# response: 2,*Sjögren's Syndrome*,30%,*Dry eyes and abnormal lung diffusion can be indicative of Sjögren's syndrome, an autoimmune disorder that affects exocrine glands, including tear and salivary glands, and can cause lung involvement.*
# response: 3,*Systemic Lupus Erythematosus (SLE)*,15%,*Joint stiffness, cold hands, and abnormal lung diffusion can be seen in SLE, an autoimmune disorder that can affect multiple organ systems, including joints, skin, and lungs.*
# response: 4,*Mixed Connective Tissue Disease (MCTD)*,10%,*MCTD is an autoimmune disorder that can present with symptoms similar to other connective tissue diseases, such as joint stiffness, Raynaud's phenomenon (cold hands), and lung involvement.*
# response: 5,*Scleroderma*,5%,*Abnormal lung diffusion and cold hands (due to Raynaud's phenomenon) can be seen in scleroderma, an autoimmune disorder characterized by excessive collagen deposition in the skin and internal organs, including the lungs.*
# Patient: number 12, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Tight skin
# Symptom: Rosy cheeks
# Symptom: Fever
# Symptom: Trouble swallowing solids
# Symptom: Abnormal lung  diffusion
# Symptom: Effusion
# Symptom: Hepatomegaly
# Symptom: Renal disease
# response: 1,*Systemic Sclerosis (Scleroderma)*,70%,*Joint stiffness, tight skin, and abnormal lung diffusion are classic symptoms of systemic sclerosis, a connective tissue disorder characterized by excessive collagen deposition.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,50%,*The combination of joint stiffness, fever, and involvement of multiple organs (lungs, liver, and kidneys) is consistent with MCTD, an autoimmune disorder with overlapping features of various connective tissue diseases.*
# response: 3,*Juvenile Dermatomyositis*,40%,*The presence of rosy cheeks, joint stiffness, and muscle weakness (suggested by trouble swallowing solids) can be seen in juvenile dermatomyositis, an inflammatory muscle disease.*
# response: 4,*Systemic Lupus Erythematosus (SLE)*,30%,*Fever, joint stiffness, and multi-organ involvement (lungs, liver, and kidneys) can occur in SLE, an autoimmune disorder affecting multiple systems.*
# response: 5,*Juvenile Idiopathic Arthritis (JIA)*,20%,*Joint stiffness and fever can be present in JIA, an autoimmune arthritis affecting children, but the other symptoms are less typical for this condition.*
# Patient: number 13, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Hard skin
# Symptom: Fever
# Symptom: Sore muscles
# Symptom: Abnormal lung  diffusion
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint stiffness, fever, and sore muscles are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Systemic Lupus Erythematosus (SLE)*,25%,*Hard skin (due to possible skin rashes), fever, and abnormal lung diffusion can be seen in SLE, an autoimmune disease affecting multiple organs.*
# response: 3,*Dermatomyositis*,15%,*Hard skin (due to skin rashes), fever, and sore muscles are characteristic of dermatomyositis, an inflammatory muscle disease.*
# response: 4,*Scleroderma*,10%,*Hard skin (due to excessive collagen deposition) and abnormal lung diffusion (due to potential lung involvement) are seen in scleroderma, an autoimmune connective tissue disorder.*
# response: 5,*Juvenile Dermatomyositis*,10%,*Hard skin (due to skin rashes), fever, sore muscles, and potential lung involvement are features of juvenile dermatomyositis, an inflammatory muscle disease affecting children.*
# Patient: number 14, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Finger turning blue
# Symptom: Rosy cheeks
# Symptom: Fever
# Symptom: Dry eyes
# Symptom: Encephalopathy
# Symptom: Restrictive lung disese
# Symptom: Splenomegaly
# Symptom: Hepatomegaly
# Symptom: Renal disease
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The combination of joint tenderness, fever, dry eyes, encephalopathy, and renal disease are common manifestations of SLE, particularly in children.*
# response: 2,*Juvenile Dermatomyositis*,20%,*The presence of rosy cheeks, fever, and restrictive lung disease can be seen in juvenile dermatomyositis, an autoimmune condition affecting muscles and skin.*
# response: 3,*Polyarteritis Nodosa*,10%,*The symptoms of fever, splenomegaly, hepatomegaly, and renal disease can be indicative of polyarteritis nodosa, a rare vasculitis affecting multiple organ systems.*
# response: 4,*Scleroderma*,5%,*The finger turning blue (Raynaud's phenomenon) and restrictive lung disease can be seen in scleroderma, an autoimmune disorder affecting the skin and internal organs.*
# response: 5,*Henoch-Schönlein Purpura*,5%,*The joint tenderness, renal disease, and encephalopathy can be manifestations of Henoch-Schönlein purpura, a vasculitis that primarily affects small vessels.*
# Patient: number 15, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Rosy cheeks
# Symptom: Chest pain
# Symptom: Effusion
# Symptom: Splenomegaly
# Symptom: Renal disease
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of joint stiffness, rash (rosy cheeks), chest pain, effusion, splenomegaly, and renal disease are common manifestations of SLE in children.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,30%,*Joint stiffness, effusion, and splenomegaly can be seen in JIA, particularly the systemic onset type, which can also cause rash and chest pain.*
# response: 3,*Vasculitis*,15%,*Vasculitis can cause joint pain, rash, chest pain, effusion, splenomegaly, and renal disease, depending on the type and organs involved.*
# response: 4,*Juvenile Dermatomyositis*,10%,*This autoimmune condition can cause joint stiffness, rash (heliotrope rash), and muscle weakness, which may lead to chest pain.*
# response: 5,*Henoch-Schönlein Purpura (HSP)*,5%,*HSP is a vasculitis that can cause joint pain, rash, abdominal pain (which may be mistaken for chest pain), and renal disease.*
# Patient: number 16, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Pills get stuck in throat
# Symptom: Muscular Weakness
# Symptom: Dry mouth
# Symptom: Abnormal lung  diffusion
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint tenderness and muscular weakness are common symptoms of JIA, an autoimmune disorder affecting children.*
# response: 2,*Sjögren's Syndrome*,30%,*Dry mouth (xerostomia) and difficulty swallowing (dysphagia) are characteristic symptoms of Sjögren's, an autoimmune disorder affecting exocrine glands.*
# response: 3,*Interstitial Lung Disease (ILD)*,15%,*Abnormal lung diffusion capacity can be a sign of ILD, a group of disorders affecting the lung interstitium.*
# response: 4,*Myasthenia Gravis*,10%,*Muscular weakness and difficulty swallowing can be seen in myasthenia gravis, an autoimmune disorder affecting neuromuscular junctions.*
# response: 5,*Scleroderma*,5%,*Dry mouth and interstitial lung disease can occur in scleroderma, an autoimmune disorder causing fibrosis of the skin and internal organs.*
# Patient: number 17, gender female, age 10, weight 54, height 46
# Symptom: Cold hands
# Symptom: Tight skin
# Symptom: Hand rash
# Symptom: Fever
# Symptom: Pills get stuck in throat
# Symptom: Chest pain
# Symptom: Effusion
# Symptom: Hepatomegaly
# response: 1,*Systemic Sclerosis (Scleroderma)*,60%,*Tight skin, Raynaud's phenomenon (cold hands), and gastrointestinal involvement (pills getting stuck in throat) are common manifestations of systemic sclerosis.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,20%,*The combination of fever, rash, Raynaud's phenomenon, and multi-organ involvement (effusion, hepatomegaly) can be seen in MCTD, which overlaps with features of systemic lupus erythematosus, scleroderma, and polymyositis.*
# response: 3,*Juvenile Dermatomyositis*,10%,*The presence of rash, fever, and muscle weakness (suggested by chest pain) can be indicative of juvenile dermatomyositis, an inflammatory myopathy.*
# response: 4,*Juvenile Idiopathic Arthritis*,5%,*The fever, rash, and joint/muscle involvement (chest pain) could potentially be due to juvenile idiopathic arthritis, although the tight skin and Raynaud's phenomenon are less common in this condition.*
# response: 5,*Systemic Lupus Erythematosus*,5%,*The fever, rash, and multi-organ involvement (effusion, hepatomegaly) could potentially be due to systemic lupus erythematosus, although the tight skin and Raynaud's phenomenon are less common in this condition.*
# Patient: number 18, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Fingers turning white
# Symptom: Shiny skin
# Symptom: Muscular Weakness
# response: 1,*Juvenile Dermatomyositis*,40%,*Shiny skin, muscular weakness, and joint pain are characteristic symptoms of this autoimmune condition affecting muscles and skin.*
# response: 2,*Raynaud's Phenomenon*,30%,*Fingers turning white could be due to vasospasm associated with Raynaud's, which can occur in conjunction with autoimmune diseases like juvenile dermatomyositis.*
# response: 3,*Juvenile Idiopathic Arthritis*,15%,*Joint pain and muscular weakness could be indicative of an inflammatory arthritis condition like JIA.*
# response: 4,*Systemic Lupus Erythematosus*,10%,*Joint pain, Raynaud's phenomenon, and muscular weakness can sometimes be seen in pediatric lupus cases.*
# response: 5,*Mixed Connective Tissue Disease*,5%,*This rare autoimmune disorder can present with a combination of symptoms seen in lupus, dermatomyositis, and scleroderma.*
# Patient: number 19, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Finger turning blue
# Symptom: Tight skin
# Symptom: Rash on cheeks
# Symptom: Sore muscles
# Symptom: Hypertension
# Symptom: Hepatomegaly
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of joint tenderness, rash on cheeks, and hypertension are common manifestations of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Scleroderma*,30%,*The tight skin and finger turning blue (Raynaud's phenomenon) are characteristic of scleroderma, a connective tissue disorder that causes hardening and tightening of the skin and blood vessels.*
# response: 3,*Juvenile Idiopathic Arthritis (JIA)*,20%,*The joint tenderness and sore muscles could be indicative of JIA, an autoimmune disorder that causes joint inflammation and muscle pain in children.*
# response: 4,*Mixed Connective Tissue Disease (MCTD)*,15%,*The combination of symptoms such as joint tenderness, rash, and hypertension could suggest MCTD, an autoimmune disorder that shares features with lupus, scleroderma, and other connective tissue diseases.*
# response: 5,*Hepatitis*,10%,*The presence of hepatomegaly (enlarged liver) could be a sign of viral hepatitis or other liver disorders, although the other symptoms are not typical of hepatitis alone.*
# Patient: number 20, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Cold hands
# Symptom: Fever
# Symptom: Trouble swallowing solids
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint stiffness and fever are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Juvenile Dermatomyositis*,25%,*This rare inflammatory disease can cause joint stiffness, fever, and difficulty swallowing due to muscle weakness.*
# response: 3,*Systemic Lupus Erythematosus (SLE)*,15%,*SLE is an autoimmune disorder that can cause joint stiffness, fever, and Raynaud's phenomenon (cold hands).*
# response: 4,*Kawasaki Disease*,10%,*This childhood illness can cause fever, joint stiffness, and difficulty swallowing due to inflammation of the mouth and throat.*
# response: 5,*Rheumatic Fever*,10%,*This inflammatory disorder following a streptococcal infection can lead to joint stiffness, fever, and difficulty swallowing due to involvement of the heart and joints.*
# Patient: number 21, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Hand rash
# Symptom: Trouble swallowing
# Symptom: Muscular Weakness
# Symptom: Effusion
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint tenderness, rash, and muscular weakness are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Systemic Lupus Erythematosus (SLE)*,30%,*The combination of joint pain, rash, and trouble swallowing can be indicative of SLE, an autoimmune disease that can affect multiple organ systems.*
# response: 3,*Dermatomyositis*,15%,*The presence of rash, muscular weakness, and joint involvement can suggest dermatomyositis, an inflammatory condition affecting the skin and muscles.*
# response: 4,*Juvenile Dermatomyositis*,10%,*Similar to dermatomyositis, but specifically occurring in children, this condition can explain the rash, muscle weakness, and joint symptoms.*
# response: 5,*Reactive Arthritis*,5%,*The joint tenderness and rash could potentially be caused by reactive arthritis, which can occur after an infection and affect multiple joints.*
# Patient: number 22, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: rash on hands
# Symptom: Fever
# Symptom: Sore muscles
# Symptom: Abnormal lung  diffusion
# Symptom: Renal disease
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint stiffness, rash, fever, and muscle soreness are common symptoms of JIA, an autoimmune disorder affecting children.*
# response: 2,*Systemic Lupus Erythematosus (SLE)*,30%,*The combination of rash, fever, joint stiffness, and potential renal involvement is consistent with SLE, an autoimmune disorder affecting multiple organ systems.*
# response: 3,*Juvenile Dermatomyositis*,15%,*The presence of rash, muscle weakness, and potential lung involvement could indicate Juvenile Dermatomyositis, an inflammatory muscle disease.*
# response: 4,*Vasculitis*,10%,*The combination of rash, fever, and potential renal and lung involvement could suggest a vasculitis, an inflammation of blood vessels.*
# response: 5,*Sarcoidosis*,5%,*The abnormal lung diffusion and potential joint and skin manifestations could be indicative of sarcoidosis, a multisystem inflammatory disorder.*
# Patient: number 23, gender female, age 10, weight 54, height 46
# Symptom: Fingers turning white
# Symptom: Tight skin
# Symptom: Rosy cheeks
# Symptom: Fever
# Symptom: Cardiac disease
# Symptom: Renal disease
# response: 1,*Systemic Scleroderma (Diffuse Cutaneous Systemic Sclerosis)*,60%,*Tight skin, Raynaud's phenomenon (fingers turning white), and potential involvement of internal organs like the heart and kidneys.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,20%,*Overlapping features of systemic lupus erythematosus, scleroderma, and polymyositis, including Raynaud's phenomenon, fever, and potential cardiac and renal involvement.*
# response: 3,*Juvenile Dermatomyositis*,10%,*Characteristic skin manifestations like Gottron's papules, heliotrope rash, and potential involvement of muscles and internal organs.*
# response: 4,*Juvenile Idiopathic Arthritis*,5%,*Fever, potential joint involvement, and possible systemic manifestations like rash and internal organ involvement.*
# response: 5,*Henoch-Schönlein Purpura*,5%,*Rash, potential renal involvement, and fever, although the skin manifestations are not typical of the description provided.*
# Patient: number 24, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Fingers turning white
# Symptom: Tight skin
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint tenderness and stiffness are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Raynaud's Phenomenon*,30%,*The fingers turning white could be a sign of Raynaud's, a condition that causes reduced blood flow to the extremities.*
# response: 3,*Systemic Sclerosis (Scleroderma)*,20%,*Tight skin is a characteristic symptom of systemic sclerosis, an autoimmune disorder that causes hardening and tightening of the skin.*
# response: 4,*Mixed Connective Tissue Disease (MCTD)*,15%,*MCTD is an autoimmune disorder that can cause a combination of symptoms like joint pain, Raynaud's phenomenon, and skin tightness.*
# response: 5,*Dermatomyositis*,10%,*Dermatomyositis is an inflammatory muscle disease that can cause skin tightness and rashes, along with muscle weakness and joint pain.*
# Patient: number 25, gender female, age 10, weight 54, height 46
# Symptom: Finger turning blue
# Symptom: rash on kncules
# Symptom: Chest pain
# Symptom: Sore muscles
# Symptom: Abnormal lung  diffusion
# Symptom: Hepatomegaly
# response: 1,*Systemic Lupus Erythematosus (SLE)*,35%,*Raynaud's phenomenon (blue fingers), rash, chest pain, and hepatomegaly are common manifestations of SLE in children.*
# response: 2,*Dermatomyositis*,25%,*Rash, muscle weakness/pain, and abnormal lung function are characteristic symptoms of dermatomyositis, an inflammatory myopathy.*
# response: 3,*Scleroderma*,20%,*Raynaud's phenomenon, rash, and abnormal lung function can be seen in scleroderma, a connective tissue disorder.*
# response: 4,*Mixed Connective Tissue Disease (MCTD)*,15%,*MCTD can present with features of lupus, scleroderma, and myositis, including rash, Raynaud's phenomenon, and muscle weakness.*
# response: 5,*Juvenile Idiopathic Arthritis (JIA)*,5%,*While not a perfect fit, JIA can sometimes present with rash, muscle pain, and hepatomegaly in children.*
# Patient: number 26, gender female, age 10, weight 54, height 46
# Symptom: Hard skin
# Symptom: Fever
# Symptom: Abnormal lung  diffusion
# Symptom: Effusion
# Symptom: Splenomegaly
# response: 1,*Scleroderma*,40%,*Hardening of the skin (scleroderma) along with fever, lung involvement (abnormal diffusion), and splenomegaly are common features of systemic scleroderma in children.*
# response: 2,*Systemic Lupus Erythematosus (SLE)*,30%,*Fever, lung involvement (pleural effusion), and splenomegaly can occur in SLE, which is an autoimmune disorder that can affect multiple organs, including the skin.*
# response: 3,*Rheumatoid Arthritis*,15%,*Although less common in children, rheumatoid arthritis can cause fever, lung involvement (pleural effusion), and splenomegaly, along with joint swelling and stiffness.*
# response: 4,*Dermatomyositis*,10%,*Hardening of the skin (calcinosis) and fever can occur in dermatomyositis, which is an inflammatory muscle disease that can also involve the lungs and other organs.*
# response: 5,*Sarcoidosis*,5%,*Sarcoidosis is a multisystem disorder that can cause fever, lung involvement (abnormal diffusion), and splenomegaly, although skin manifestations are less common in children.*
# Patient: number 27, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Finger turning blue
# Symptom: Rash on face
# Symptom: Chest pain
# Symptom: Dry mouth
# Symptom: Abnormal lung  diffusion
# Symptom: Effusion
# Symptom: Hepatomegaly
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of joint stiffness, rash, chest pain, and hepatomegaly are common manifestations of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,25%,*The presence of Raynaud's phenomenon (finger turning blue), joint stiffness, rash, and lung involvement (abnormal diffusion) are consistent with MCTD, an overlap syndrome with features of lupus, scleroderma, and polymyositis.*
# response: 3,*Juvenile Idiopathic Arthritis (JIA)*,15%,*Joint stiffness, rash, and effusion can be seen in JIA, a group of autoimmune disorders characterized by chronic joint inflammation in children.*
# response: 4,*Scleroderma*,10%,*Raynaud's phenomenon, joint stiffness, and lung involvement (abnormal diffusion) can occur in scleroderma, a connective tissue disorder characterized by excessive collagen deposition.*
# response: 5,*Sjögren's Syndrome*,10%,*Dry mouth (xerostomia) and joint stiffness can be present in Sjögren's syndrome, an autoimmune disorder that primarily affects the exocrine glands.*
# Patient: number 28, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Finger turning blue
# Symptom: Tight skin
# Symptom: Fever
# Symptom: Trouble swallowing
# Symptom: Cardiac disease
# Symptom: Splenomegaly
# Symptom: Renal disease
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of joint pain, fever, cardiac disease, and renal disease are common manifestations of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Scleroderma*,30%,*The tight skin, Raynaud's phenomenon (finger turning blue), and trouble swallowing are characteristic of scleroderma, a connective tissue disorder that causes hardening and tightening of the skin and organs.*
# response: 3,*Juvenile Idiopathic Arthritis (JIA)*,15%,*The joint pain, fever, and splenomegaly can be seen in JIA, an autoimmune disorder that causes joint inflammation and can affect other organs.*
# response: 4,*Vasculitis*,10%,*The finger turning blue, renal disease, and cardiac disease can be manifestations of vasculitis, an inflammation of blood vessels that can affect various organs.*
# response: 5,*Juvenile Dermatomyositis*,5%,*The joint pain, tight skin, and trouble swallowing can be seen in juvenile dermatomyositis, an autoimmune disorder that causes muscle weakness and skin rashes.*
# Patient: number 29, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Muscular Weakness
# Symptom: Abnormal lung  diffusion
# Symptom: Restrictive lung disese
# response: 1,*Juvenile Dermatomyositis*,40%,*Joint tenderness, muscular weakness, and lung involvement (restrictive lung disease and abnormal diffusion) are common manifestations of this autoimmune condition affecting muscles and skin.*
# response: 2,*Systemic Lupus Erythematosus (SLE)*,25%,*This autoimmune disorder can also present with joint pain, muscle weakness, and lung involvement, particularly in children and adolescents.*
# response: 3,*Mixed Connective Tissue Disease (MCTD)*,15%,*MCTD is an overlap syndrome that can exhibit features of various autoimmune diseases, including joint pain, muscle weakness, and lung manifestations.*
# response: 4,*Scleroderma*,10%,*While more common in adults, scleroderma can occur in children and may involve joint pain, muscle weakness, and lung fibrosis leading to restrictive lung disease.*
# response: 5,*Rheumatoid Arthritis*,10%,*Although less common in children, juvenile rheumatoid arthritis can cause joint tenderness, muscle weakness, and, in some cases, lung involvement.*
# Patient: number 30, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Fingers turning white
# Symptom: rash on kncules
# Symptom: Fever
# Symptom: Cardiac disease
# Symptom: Chest pain
# Symptom: Dry mouth
# Symptom: Splenomegaly
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Joint pain, rash, fever, and splenomegaly are common symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,30%,*Joint pain, fever, and rash are common symptoms of JIA, a type of arthritis that occurs in children.*
# response: 3,*Raynaud's Phenomenon*,20%,*Fingers turning white is a characteristic symptom of Raynaud's phenomenon, a condition that affects blood circulation in the extremities.*
# response: 4,*Kawasaki Disease*,15%,*Fever, rash, and cardiac involvement (chest pain) are common symptoms of Kawasaki disease, a rare childhood illness that affects the blood vessels.*
# response: 5,*Sjögren's Syndrome*,10%,*Dry mouth (xerostomia) and joint pain are common symptoms of Sjögren's syndrome, an autoimmune disorder that affects the moisture-producing glands.*
# Patient: number 31, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Cold hands
# Symptom: Shiny skin
# Symptom: Hand rash
# Symptom: Fever
# Symptom: Chest pain
# Symptom: Dry eyes
# Symptom: Psychiatric issues
# Symptom: Abnormal lung  diffusion
# Symptom: Effusion
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Joint stiffness, rash, fever, chest pain, and dry eyes are common symptoms of SLE, an autoimmune disorder that can affect multiple organs.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,25%,*Joint stiffness, fever, and rash are common in JIA, an autoimmune disorder that primarily affects the joints in children.*
# response: 3,*Mixed Connective Tissue Disease (MCTD)*,15%,*MCTD is an autoimmune disorder that can cause symptoms similar to SLE, including joint stiffness, rash, fever, and lung involvement.*
# response: 4,*Scleroderma*,10%,*Shiny skin, Raynaud's phenomenon (cold hands), and lung involvement (abnormal diffusion) are characteristic of scleroderma, an autoimmune disorder affecting the skin and internal organs.*
# response: 5,*Juvenile Dermatomyositis*,10%,*Rash, muscle weakness (which can cause joint stiffness), fever, and lung involvement are seen in juvenile dermatomyositis, an autoimmune disorder affecting the skin and muscles.*
# Patient: number 32, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Finger turning blue
# Symptom: Tight skin
# Symptom: rash on hands
# Symptom: Trouble swallowing solids
# Symptom: Splenomegaly
# response: 1,*Systemic Sclerosis (Scleroderma)*,60%,*Tight skin, Raynaud's phenomenon (fingers turning blue), and trouble swallowing solids are common symptoms of systemic sclerosis.*
# response: 2,*Juvenile Idiopathic Arthritis*,20%,*Joint tenderness and rash on hands can be seen in juvenile idiopathic arthritis, which is an autoimmune disorder affecting children.*
# response: 3,*Mixed Connective Tissue Disease*,10%,*The combination of symptoms like Raynaud's phenomenon, joint tenderness, and splenomegaly can be seen in mixed connective tissue disease, which is an overlap of different autoimmune disorders.*
# response: 4,*Dermatomyositis*,5%,*Rash on hands and trouble swallowing solids can be seen in dermatomyositis, which is an inflammatory muscle disease.*
# response: 5,*Systemic Lupus Erythematosus*,5%,*Joint tenderness, rash, and splenomegaly can be present in systemic lupus erythematosus, which is an autoimmune disorder affecting multiple organs.*
# Patient: number 33, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Tight skin
# Symptom: Butterfly rash
# Symptom: Fever
# Symptom: Trouble swallowing solids
# Symptom: Dry mouth
# response: 1,*Systemic Lupus Erythematosus (SLE)*,70%,*The presence of butterfly rash, joint stiffness, fever, and trouble swallowing solids are classic symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,15%,*The combination of joint stiffness, tight skin, and fever could suggest MCTD, which is an overlap syndrome with features of lupus, scleroderma, and other connective tissue disorders.*
# response: 3,*Juvenile Dermatomyositis*,10%,*The tight skin, joint stiffness, and fever could be indicative of juvenile dermatomyositis, an inflammatory muscle disease that can also involve the skin.*
# response: 4,*Scleroderma*,3%,*The tight skin and trouble swallowing solids could be signs of scleroderma, a connective tissue disorder characterized by excessive collagen deposition in the skin and internal organs.*
# response: 5,*Sjögren's Syndrome*,2%,*The dry mouth and trouble swallowing solids could be related to Sjögren's syndrome, an autoimmune disorder that affects the moisture-producing glands, leading to dryness in the mouth and eyes.*
# Patient: number 34, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Finger turning blue
# Symptom: Trouble swallowing solids
# Symptom: Cardiac disease
# Symptom: Meningitis
# Symptom: Abnormal lung  diffusion
# Symptom: Restrictive lung disese
# Symptom: Splenomegaly
# Symptom: Hepatomegaly
# Symptom: Renal disease
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of joint tenderness, cardiac disease, renal disease, and splenomegaly/hepatomegaly are common manifestations of SLE in children.*
# response: 2,*Scleroderma*,25%,*The finger turning blue (Raynaud's phenomenon) and restrictive lung disease are characteristic of scleroderma, which can also cause joint tenderness and trouble swallowing solids.*
# response: 3,*Mixed Connective Tissue Disease (MCTD)*,15%,*MCTD can present with a combination of symptoms similar to SLE, scleroderma, and polymyositis, including joint tenderness, Raynaud's phenomenon, and lung involvement.*
# response: 4,*Juvenile Idiopathic Arthritis (JIA)*,10%,*Joint tenderness is a common symptom of JIA, and it can also involve other organs, such as the lungs and kidneys.*
# response: 5,*Vasculitis*,10%,*Vasculitis can affect multiple organs, including the joints, lungs, kidneys, and gastrointestinal tract, potentially explaining the diverse symptoms in this case.*
# Patient: number 35, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Finger turning blue
# Symptom: Shiny skin
# Symptom: Rosy cheeks
# Symptom: rash on hands
# Symptom: Trouble swallowing solids
# Symptom: Dry mouth
# Symptom: Abnormal lung  diffusion
# Symptom: Hepatomegaly
# Symptom: Renal disease
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The combination of joint pain, rash, renal disease, and abnormal lung function is highly suggestive of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,20%,*The presence of Raynaud's phenomenon (finger turning blue), joint pain, and potential involvement of multiple organs (lung, kidney, liver) could indicate MCTD, an overlap syndrome with features of various autoimmune diseases.*
# response: 3,*Scleroderma*,10%,*The shiny skin and Raynaud's phenomenon (finger turning blue) are characteristic of scleroderma, an autoimmune disorder that causes excessive collagen deposition in the skin and internal organs.*
# response: 4,*Sjögren's Syndrome*,5%,*The dry mouth and potential involvement of multiple organs (lung, kidney, liver) could suggest Sjögren's syndrome, an autoimmune disorder that primarily affects the exocrine glands but can also involve other organs.*
# response: 5,*Juvenile Dermatomyositis*,5%,*The rash on the hands, muscle weakness (suggested by trouble swallowing solids), and potential involvement of multiple organs (lung, liver) could indicate juvenile dermatomyositis, an autoimmune inflammatory disorder affecting the muscles and skin.*
# Patient: number 36, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Cold hands
# Symptom: Rosy cheeks
# Symptom: Dry eyes
# Symptom: Psychiatric issues
# Symptom: Effusion
# Symptom: Splenomegaly
# Symptom: Hepatomegaly
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Joint tenderness, dry eyes, and psychiatric issues are common symptoms of SLE, while splenomegaly and hepatomegaly can occur due to lupus-related inflammation.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,30%,*Joint tenderness, effusion, and rosy cheeks (due to fever) are common in JIA, which can also cause splenomegaly and hepatomegaly in some cases.*
# response: 3,*Juvenile Dermatomyositis*,15%,*Joint tenderness, rosy cheeks (due to rash), and cold hands (due to Raynaud's phenomenon) are common in juvenile dermatomyositis, which can also cause psychiatric issues.*
# response: 4,*Mixed Connective Tissue Disease (MCTD)*,10%,*Joint tenderness, dry eyes, and splenomegaly can occur in MCTD, which is an overlap syndrome with features of lupus, scleroderma, and polymyositis.*
# response: 5,*Sarcoidosis*,5%,*Joint tenderness, dry eyes, and hepatomegaly can be seen in sarcoidosis, which is a multisystem inflammatory disorder that can affect various organs.*
# Patient: number 37, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Fingers turning white
# Symptom: Tight skin
# Symptom: Chest pain
# Symptom: Cognitive issues
# Symptom: Hypertension
# Symptom: Effusion
# Symptom: Hepatomegaly
# response: 1,*Systemic Sclerosis (Scleroderma)*,60%,*Joint stiffness, tight skin, and Raynaud's phenomenon (fingers turning white) are classic symptoms of systemic sclerosis, which can also involve internal organs like the lungs (chest pain), kidneys (hypertension), and liver (hepatomegaly).*
# response: 2,*Mixed Connective Tissue Disease*,20%,*This condition can present with features of systemic sclerosis, lupus, and myositis, which could explain the joint stiffness, Raynaud's phenomenon, cognitive issues, and organ involvement.*
# response: 3,*Juvenile Idiopathic Arthritis*,10%,*The joint stiffness, effusion, and cognitive issues could be due to this autoimmune condition, but the other symptoms are less typical.*
# response: 4,*Juvenile Dermatomyositis*,5%,*The tight skin, muscle weakness (leading to cognitive issues), and organ involvement could be seen in this condition, but the Raynaud's phenomenon and joint stiffness are less common.*
# response: 5,*Overlap Syndrome*,5%,*This is a combination of two or more autoimmune diseases, which could account for the diverse range of symptoms, but it is a less common diagnosis.*
# Patient: number 38, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Finger turning blue
# Symptom: Hard skin
# Symptom: Pills get stuck in throat
# Symptom: Sore muscles
# Symptom: Effusion
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint pain, sore muscles, and effusion are common symptoms of JIA, an autoimmune disorder affecting children.*
# response: 2,*Raynaud's Phenomenon*,30%,*Finger turning blue could be a sign of Raynaud's, a condition that causes poor blood circulation in the extremities.*
# response: 3,*Scleroderma*,15%,*Hard skin and difficulty swallowing (pills getting stuck in throat) are characteristic of scleroderma, an autoimmune disorder affecting connective tissues.*
# response: 4,*Dermatomyositis*,10%,*Sore muscles, joint pain, and skin changes (hard skin) can occur in dermatomyositis, an inflammatory condition affecting muscles and skin.*
# response: 5,*Mixed Connective Tissue Disease (MCTD)*,5%,*MCTD is an autoimmune disorder that can cause a combination of symptoms like joint pain, Raynaud's phenomenon, and muscle weakness.*
# Patient: number 39, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Cold hands
# Symptom: Shiny skin
# Symptom: Rash on face
# Symptom: Pills get stuck in throat
# Symptom: Muscular Weakness
# Symptom: Cognitive issues
# Symptom: Abnormal lung  diffusion
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Joint pain, rash, and cognitive issues are common symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,30%,*MCTD is an autoimmune disorder that shares features with SLE, including joint pain, rash, and muscular weakness, and can also affect the lungs.*
# response: 3,*Juvenile Dermatomyositis*,20%,*This autoimmune condition can cause muscle weakness, rash, and lung involvement, which are present in this patient.*
# response: 4,*Scleroderma*,15%,*The shiny skin and difficulty swallowing (pills getting stuck in the throat) can be seen in scleroderma, an autoimmune disorder affecting the skin and internal organs.*
# response: 5,*Juvenile Idiopathic Arthritis (JIA)*,10%,*Joint pain and rash can be present in JIA, an autoimmune arthritis that can occur in children.*
# Patient: number 40, gender female, age 10, weight 54, height 46
# ...
# response: 5,*Mixed Connective Tissue Disease (MCTD)*,10%,*MCTD is an overlap syndrome that can present with features of lupus, scleroderma, and myositis, which may explain the diverse symptoms in this patient.*
# Patient: number 988, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Cold hands
# Symptom: Chest pain
# Symptom: Muscular Weakness
# Symptom: Abnormal lung  diffusion
# Symptom: Restrictive lung disese
# Symptom: Effusion
# Symptom: Splenomegaly
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Joint pain, chest pain, muscular weakness, and splenomegaly are common symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,25%,*MCTD is a rare autoimmune disorder that shares features with SLE, scleroderma, and polymyositis, which can explain the joint pain, muscular weakness, and lung involvement.*
# response: 3,*Juvenile Dermatomyositis*,15%,*This autoimmune condition can cause muscle weakness, joint pain, and lung involvement, which are present in this patient.*
# response: 4,*Scleroderma*,10%,*Scleroderma is an autoimmune disorder that can cause Raynaud's phenomenon (cold hands), joint pain, and lung involvement, which are seen in this patient.*
# response: 5,*Juvenile Idiopathic Arthritis (JIA)*,10%,*JIA is a type of arthritis that can cause joint pain, muscle weakness, and, in some cases, lung involvement, which are present in this patient.*
# Patient: number 989, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Rash on cheeks
# Symptom: Fever
# Symptom: Chest pain
# Symptom: Muscular Weakness
# Symptom: Hepatomegaly
# Symptom: Renal disease
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The combination of joint stiffness, rash on cheeks (malar rash), fever, and potential involvement of multiple organs (chest pain, muscular weakness, hepatomegaly, and renal disease) is highly suggestive of SLE.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,20%,*Joint stiffness, fever, and muscular weakness can be seen in JIA, particularly in the polyarticular or systemic subtypes, but the other symptoms are less typical.*
# response: 3,*Mixed Connective Tissue Disease (MCTD)*,10%,*MCTD can present with a combination of symptoms similar to SLE, including joint stiffness, rash, fever, and potential involvement of multiple organs.*
# response: 4,*Juvenile Dermatomyositis*,5%,*The presence of muscular weakness, rash, and potential involvement of other organs (hepatomegaly, renal disease) can be seen in juvenile dermatomyositis, but the joint stiffness and chest pain are less typical.*
# response: 5,*Henoch-Schönlein Purpura (HSP)*,5%,*HSP can present with rash, joint stiffness, and renal disease, but the other symptoms, such as fever, chest pain, muscular weakness, and hepatomegaly, are less common.*
# Patient: number 990, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Rosy cheeks
# Symptom: rash on hands
# Symptom: Fever
# Symptom: Chest pain
# Symptom: Restrictive lung disese
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Joint pain, rash, fever, and chest pain are common symptoms of SLE, which is an autoimmune disorder that can affect multiple organs, including the lungs.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,30%,*Joint pain, rash, and fever are common symptoms of JIA, which is an autoimmune disorder that primarily affects the joints in children.*
# response: 3,*Juvenile Dermatomyositis*,15%,*Rash on the hands, muscle weakness, and restrictive lung disease are common symptoms of Juvenile Dermatomyositis, which is an autoimmune disorder that affects the skin and muscles.*
# response: 4,*Kawasaki Disease*,10%,*Fever, rash, and chest pain are common symptoms of Kawasaki Disease, which is a rare childhood illness that affects the blood vessels.*
# response: 5,*Rheumatic Fever*,5%,*Joint pain, fever, and chest pain are common symptoms of Rheumatic Fever, which is a complication of streptococcal throat infection that can affect the heart, joints, and other organs.*
# Patient: number 991, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Fingers turning white
# Symptom: Hard skin
# Symptom: Encephalopathy
# Symptom: Abnormal lung  diffusion
# Symptom: Effusion
# Symptom: Renal disease
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of joint tenderness, Raynaud's phenomenon (fingers turning white), and potential kidney involvement (renal disease) are common manifestations of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,25%,*The presence of Raynaud's phenomenon, joint involvement, and potential lung involvement (abnormal lung diffusion) are consistent with MCTD, an autoimmune disorder with overlapping features of SLE, scleroderma, and polymyositis.*
# response: 3,*Scleroderma*,15%,*The hard skin (sclerosis) and Raynaud's phenomenon are characteristic of scleroderma, an autoimmune disorder that causes excessive collagen deposition in the skin and internal organs.*
# response: 4,*Juvenile Dermatomyositis*,10%,*The joint tenderness, potential lung involvement (abnormal lung diffusion), and encephalopathy (brain involvement) can be seen in juvenile dermatomyositis, an inflammatory muscle disease that can also affect other organs.*
# response: 5,*Juvenile Idiopathic Arthritis (JIA)*,10%,*The joint tenderness and potential effusion (joint swelling) could be indicative of JIA, an autoimmune disorder characterized by chronic joint inflammation in children.*
# Patient: number 992, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Finger turning blue
# Symptom: Pills get stuck in throat
# Symptom: Chest pain
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint pain and swelling are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Raynaud's Phenomenon*,30%,*The finger turning blue could be a sign of Raynaud's, a condition that causes poor blood circulation in the extremities.*
# response: 3,*Esophageal Stricture or Dysphagia*,20%,*Pills getting stuck in the throat may indicate an esophageal stricture or difficulty swallowing (dysphagia), which can have various causes.*
# response: 4,*Gastroesophageal Reflux Disease (GERD)*,15%,*Chest pain, especially after swallowing, could be a symptom of GERD, where stomach acid refluxes into the esophagus.*
# response: 5,*Vasculitis*,10%,*Chest pain and blue fingers could potentially be signs of vasculitis, an inflammation of blood vessels, although this is a less common condition in children.*
# Patient: number 993, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Fingers turning white
# Symptom: Shiny skin
# Symptom: Fever
# Symptom: Pills get stuck in throat
# Symptom: Cardiac disease
# Symptom: Dry mouth
# Symptom: Meningitis
# Symptom: Hypertension
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,30%,*Joint stiffness and fever are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Raynaud's Phenomenon*,25%,*Fingers turning white could be a sign of Raynaud's, a condition that affects blood circulation in the extremities.*
# response: 3,*Scleroderma*,20%,*Shiny skin and difficulty swallowing (pills getting stuck in throat) are characteristic of scleroderma, an autoimmune disorder affecting connective tissues.*
# response: 4,*Sjögren's Syndrome*,15%,*Dry mouth and joint stiffness are common symptoms of Sjögren's, an autoimmune disorder affecting moisture-producing glands.*
# response: 5,*Systemic Lupus Erythematosus (SLE)*,10%,*Fever, joint stiffness, and Raynaud's phenomenon can be seen in SLE, an autoimmune disorder affecting multiple organ systems.*
# Patient: number 994, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Cold hands
# Symptom: Hand rash
# Symptom: Fever
# Symptom: Trouble swallowing solids
# Symptom: Cardiac disease
# Symptom: Dry mouth
# Symptom: Splenomegaly
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint stiffness, rash, and fever are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Systemic Lupus Erythematosus (SLE)*,25%,*The combination of joint stiffness, rash, fever, and splenomegaly can be seen in SLE, an autoimmune disease affecting multiple organ systems.*
# response: 3,*Mixed Connective Tissue Disease (MCTD)*,15%,*MCTD is an autoimmune disorder that can present with symptoms similar to lupus, scleroderma, and polymyositis, including joint stiffness, rash, and fever.*
# response: 4,*Kawasaki Disease*,10%,*Kawasaki disease is a rare childhood illness that can cause fever, rash, and cardiac complications, which may explain the cardiac disease and fever in this patient.*
# response: 5,*Sjögren's Syndrome*,10%,*Sjögren's syndrome is an autoimmune disorder that can cause dry mouth, joint stiffness, and rash, which are present in this patient.*
# Patient: number 995, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Finger turning blue
# Symptom: Hard skin
# Symptom: Butterfly rash
# Symptom: rash on kncules
# Symptom: Muscular Weakness
# Symptom: Dry eyes
# Symptom: Abnormal lung  diffusion
# response: 1,*Systemic Lupus Erythematosus (SLE)*,70%,*The presence of butterfly rash, joint pain, and dry eyes are characteristic symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,50%,*The combination of symptoms such as joint pain, Raynaud's phenomenon (finger turning blue), and muscle weakness can be indicative of MCTD, which is an overlap of various autoimmune disorders.*
# response: 3,*Scleroderma*,40%,*The hard skin and Raynaud's phenomenon (finger turning blue) are common manifestations of scleroderma, a connective tissue disorder characterized by excessive collagen deposition.*
# response: 4,*Juvenile Dermatomyositis*,30%,*The presence of a rash on the knuckles, muscle weakness, and abnormal lung diffusion can suggest juvenile dermatomyositis, an inflammatory muscle disease that can affect the skin and lungs.*
# response: 5,*Rheumatoid Arthritis*,20%,*While joint pain is a common symptom, the other manifestations are less typical of rheumatoid arthritis, an autoimmune disorder primarily affecting the joints.*
# Patient: number 996, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Fingers turning white
# Symptom: Hard skin
# Symptom: Pills get stuck in throat
# Symptom: Abnormal lung  diffusion
# Symptom: Effusion
# response: 1,*Systemic Sclerosis (Scleroderma)*,60%,*Joint pain, skin hardening (scleroderma), and abnormal lung diffusion capacity are common symptoms of systemic sclerosis.*
# response: 2,*Mixed Connective Tissue Disease (MCTD)*,20%,*Joint pain, Raynaud's phenomenon (fingers turning white), and lung involvement are seen in MCTD, which shares features with systemic sclerosis.*
# response: 3,*Dermatomyositis*,10%,*Joint pain, skin hardening, and lung involvement can occur in dermatomyositis, an inflammatory myopathy.*
# response: 4,*Eosinophilic Esophagitis*,5%,*Difficulty swallowing (pills getting stuck in the throat) and joint pain can be seen in eosinophilic esophagitis, an allergic condition affecting the esophagus.*
# response: 5,*Juvenile Idiopathic Arthritis*,5%,*Joint pain and effusion (swelling) can be manifestations of juvenile idiopathic arthritis, an autoimmune disorder affecting children.*
# Patient: number 997, gender female, age 10, weight 54, height 46
# Symptom: Joint tenderness
# Symptom: Finger turning blue
# Symptom: Rosy cheeks
# Symptom: Trouble swallowing
# Symptom: Chest pain
# Symptom: Splenomegaly
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint tenderness and rosy cheeks are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Raynaud's Phenomenon*,25%,*Finger turning blue could be a sign of Raynaud's, a condition that causes poor blood circulation in the extremities.*
# response: 3,*Kawasaki Disease*,20%,*Fever, rash, and swollen lymph nodes (splenomegaly) are characteristic of Kawasaki disease, a rare childhood illness that affects the blood vessels.*
# response: 4,*Esophageal Stricture*,10%,*Trouble swallowing and chest pain could indicate an esophageal stricture, a narrowing of the esophagus that can be caused by various conditions.*
# response: 5,*Rheumatic Fever*,5%,*Joint pain, chest pain, and splenomegaly can be symptoms of rheumatic fever, a complication of untreated strep throat that can affect the heart, joints, and other organs.*
# Patient: number 998, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Finger turning blue
# Symptom: Tight skin
# Symptom: Fever
# Symptom: Muscular Weakness
# Symptom: Dry eyes
# response: 1,*Juvenile Dermatomyositis*,40%,*The combination of muscle weakness, joint pain, fever, and skin changes (tight skin and blue fingers) are characteristic of juvenile dermatomyositis, an autoimmune disorder affecting muscles and skin.*
# response: 2,*Systemic Lupus Erythematosus (SLE)*,25%,*The presence of fever, joint pain, and dry eyes could indicate SLE, an autoimmune disorder that can affect multiple organ systems, including the skin, joints, and eyes.*
# response: 3,*Mixed Connective Tissue Disease (MCTD)*,15%,*The overlapping symptoms of joint pain, muscle weakness, fever, and skin changes could suggest MCTD, a rare autoimmune disorder with features of lupus, scleroderma, and polymyositis.*
# response: 4,*Scleroderma*,10%,*The tight skin and blue fingers (Raynaud's phenomenon) could be indicative of scleroderma, an autoimmune disorder characterized by excessive collagen production and skin thickening.*
# response: 5,*Juvenile Idiopathic Arthritis (JIA)*,10%,*The joint pain and fever could be signs of JIA, an autoimmune disorder causing joint inflammation and other systemic symptoms in children.*
# Patient: number 999, gender female, age 10, weight 54, height 46
# Symptom: Joint stiffness
# Symptom: Cold hands
# Symptom: Shiny skin
# Symptom: Fever
# Symptom: Trouble swallowing liquids
# Symptom: Sore muscles
# Symptom: Dry eyes
# Symptom: Hepatomegaly
# response: 1,*Juvenile Dermatomyositis*,40%,*Combination of muscle weakness, skin rash, and fever suggests an autoimmune condition like juvenile dermatomyositis.*
# response: 2,*Systemic Lupus Erythematosus (SLE)*,25%,*Symptoms like joint stiffness, fever, and dry eyes can be seen in SLE, an autoimmune disorder.*
# response: 3,*Mixed Connective Tissue Disease (MCTD)*,15%,*Overlap of symptoms like Raynaud's phenomenon (cold hands), muscle weakness, and swallowing difficulties can occur in MCTD.*
# response: 4,*Juvenile Idiopathic Arthritis (JIA)*,10%,*Joint stiffness and fever can be present in JIA, an autoimmune arthritis condition.*
# response: 5,*Scleroderma*,10%,*Symptoms like skin tightness (shiny skin) and Raynaud's phenomenon (cold hands) can be seen in scleroderma, an autoimmune disorder.*
# Patient: number 1000, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Finger turning blue
# Symptom: Tight skin
# Symptom: Fever
# Symptom: Muscular Weakness
# Symptom: Effusion
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint pain, fever, and effusion are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Raynaud's Phenomenon*,25%,*Finger turning blue could be a sign of Raynaud's, a condition that causes poor blood circulation in the extremities.*
# response: 3,*Systemic Lupus Erythematosus (SLE)*,15%,*Tight skin, joint pain, fever, and muscular weakness can be manifestations of SLE, an autoimmune disorder affecting multiple organs.*
# response: 4,*Dermatomyositis*,10%,*Tight skin, muscular weakness, and fever are characteristic of dermatomyositis, an inflammatory condition affecting the skin and muscles.*
# response: 5,*Scleroderma*,10%,*Tight skin and Raynaud's phenomenon are common in scleroderma, an autoimmune disorder causing hardening and tightening of the skin.*

# %%
utils.run_llm_and_parse_response(all_patients[5], model_new_name)
# Out:
# Patient ID: 6
# [('Juvenile Rheumatoid Arthritis (JRA)',
#   '40',
#   ' Joint pain, fever, and rosy cheeks are classic symptoms; cardiac and renal involvement can occur in severe cases'),
#  ('Systemic Lupus Erythematosus (SLE)',
#   '30',
#   ' Multi-system involvement including joints, skin, kidneys, and heart; fever and muscular weakness are common'),
#  ('Mixed Connective Tissue Disease',
#   '15',
#   ' Combines features of lupus, scleroderma, and polymyositis; explains joint pain, cold hands, and multi-organ involvement'),
#  ('Kawasaki Disease',
#   '10',
#   ' Fever, redness in cheeks, and cardiac involvement are typical; can affect kidneys and cause joint pain in some cases'),
#  ("Sjogren's Syndrome",
#   '5',
#   ' Dry mouth is a hallmark symptom; can cause joint pain and rarely affect heart and kidneys in children')]

# %%
resps = [ utils.run_llm_and_parse_response(p, model_new_name) for p in all_patients]
# Out:
# Patient ID: 1
# Patient ID: 2
# Patient ID: 3
# Patient ID: 4
# Patient ID: 5
# Patient ID: 6
# Patient ID: 7
# Patient ID: 8
# Patient ID: 9
# Patient ID: 10
# Patient ID: 11
# Patient ID: 12
# Patient ID: 13
# Patient ID: 14
# Patient ID: 15
# Patient ID: 16
# Patient ID: 956
# Patient ID: 957
# Patient ID: 958
# Patient ID: 959
# Patient ID: 960
# Patient ID: 961
# Patient ID: 962
# Patient ID: 963
# Patient ID: 964
# Patient ID: 965
# Patient ID: 966
# Patient ID: 967
# Patient ID: 968
# Patient ID: 969
# Patient ID: 970
# Patient ID: 971
# Patient ID: 972
# Patient ID: 973
# Patient ID: 974
# Patient ID: 975
# Patient ID: 976
# Patient ID: 977
# Patient ID: 978
# Patient ID: 979
# Patient ID: 980
# Patient ID: 981
# Patient ID: 982
# Patient ID: 983
# Patient ID: 984
# Patient ID: 985
# Patient ID: 986
# Patient ID: 987
# Patient ID: 988
# Patient ID: 989
# Patient ID: 990
# Patient ID: 991
# Patient ID: 992
# Patient ID: 993
# Patient ID: 994
# Patient ID: 995
# Patient ID: 996
# Patient ID: 997
# Patient ID: 998
# Patient ID: 999

# %%
print(resps)
# Out:
# [[('Juvenile Systemic Sclerosis', '40', " Combination of joint tenderness, Raynaud's phenomenon (fingers turning white), and involvement of multiple organ systems (cardiac, pulmonary) is highly suggestive of this rare autoimmune condition."), ('Juvenile Idiopathic Arthritis (JIA)', '25', ' Joint tenderness and fever are primary symptoms, and some forms of JIA can involve other organs, including the heart and lungs.'), ('Mixed Connective Tissue Disease', '15', " This condition combines features of various autoimmune diseases and can explain the joint, cardiac, and pulmonary symptoms, as well as Raynaud's phenomenon."), ('Systemic Lupus Erythematosus (SLE)', '10', " Can cause joint pain, fever, and involve multiple organ systems including the heart and lungs. Raynaud's phenomenon is also common in SLE."), ('Rheumatic Fever', '5', " Although less common now, it can cause joint pain, fever, and cardiac involvement in children. However, the lung symptoms and Raynaud's phenomenon are less typical.")], [('Juvenile Systemic Sclerosis', '70', " Combination of tight skin, joint tenderness, cold hands (Raynaud's phenomenon), and internal organ involvement (lung and liver) strongly suggests this rare autoimmune condition."), ('Mixed Connective Tissue Disease', '60', ' Presents with features of multiple autoimmune disorders, explaining the diverse symptoms including joint pain, skin changes, and organ involvement.'), ('Juvenile Dermatomyositis', '50', ' Can cause skin rash, joint pain, and difficulty swallowing; however, the lack of muscle weakness makes this less likely.'), ('Systemic Lupus Erythematosus (SLE)', '40', ' Can explain joint pain, rash, and organ involvement, but some typical SLE symptoms are missing.'), ('Eosinophilic Fasciitis', '30', ' Rare condition that can cause skin tightening and joint pain, but less likely due to the extent of internal organ involvement in this case.')], [('Systemic Lupus Erythematosus (SLE)', '40', " Joint tenderness, fever, and renal disease are common in SLE; Raynaud's phenomenon (finger turning blue) can occur; hepatomegaly is possible due to inflammation"), ('Juvenile Idiopathic Arthritis (JIA)', '25', ' Joint tenderness and fever are hallmark symptoms; systemic form can affect internal organs like liver (hepatomegaly) and rarely kidneys'), ('Mixed Connective Tissue Disease', '15', " Combines features of lupus, scleroderma, and myositis; can explain joint tenderness, Raynaud's phenomenon, fever, and potential organ involvement"), ('Scleroderma', '10', " Can cause Raynaud's phenomenon, joint pain, and potentially affect internal organs; difficulty swallowing (food getting stuck) is common in this condition"), ('Polyarteritis Nodosa', '5', ' Rare vasculitis that can cause fever, joint pain, and affect multiple organs including kidneys and liver; can also cause gastrointestinal symptoms')], [('Juvenile Idiopathic Arthritis (JIA)', '40', ' Joint tenderness and effusion are hallmark symptoms; rosy cheeks could be a sign of systemic JIA'), ("Raynaud's Syndrome", '25', ' Finger turning blue is a classic sign; can be associated with autoimmune conditions that cause joint pain'), ('Systemic Lupus Erythematosus (SLE)', '15', ' Can cause joint pain, skin changes (rosy cheeks), and vascular issues (blue fingers)'), ('Scleroderma', '10', " Can cause trouble swallowing, joint pain, and Raynaud's phenomenon (blue fingers)"), ('Mixed Connective Tissue Disease', '5', ' Combines features of lupus, scleroderma, and polymyositis; can explain multiple symptoms')], [('Juvenile Idiopathic Arthritis (JIA)', '40', ' Joint tenderness, fever, and effusion are classic symptoms; muscular weakness can occur due to pain and inflammation'), ('Systemic Lupus Erythematosus (SLE)', '25', ' Can cause joint pain, fever, and muscle weakness; skin involvement (hard skin) is possible in some cases'), ('Scleroderma', '15', ' Hard skin is a hallmark symptom; can also cause joint pain and muscle weakness'), ('Lyme Disease', '10', ' Can c ...

# %%
def dump_response_to_file(filehandle, patient, resp):
    print(f'P: {patient.n}, {patient.gender}, {patient.age}, {patient.weight}, {patient.height}', file=filehandle)
    for s in patient.symptom_list:
        print(f'S:{s}', file=filehandle)
    for (j, r) in enumerate(resp):
        (disease_name, prob, descr) = r
        print(f'R: {j+1}, {disease_name}, {prob}, {descr}', file=filehandle)

# dump responses to output file
fhandle = open(output_filename,'w')
for (pt, resp) in zip(all_patients, resps):
    dump_response_to_file(fhandle, pt, resp)
fhandle.close()

# %%
def analyze_responses_for_top_three(resps, keywords_list, k=3):
    num_matches = 0
    for resp in resps:
        for (j, r) in enumerate(resp):
            if (j < k):
                (disease_name, prob, descr) = r
                if utils.approx_matches(keywords_list, [disease_name]):
                    num_matches = num_matches + 1
                    break 
    return num_matches

# %%
matches_1 = analyze_responses_for_top_three(resps, keywords_list, k=1)
print(f'{model_new} is able to find {disease} in top 1 for {matches_1} out of {len(resps)} cases')
matches_3 = analyze_responses_for_top_three(resps, keywords_list, k=3)
print(f'{model_new} is able to find {disease} in top 3 for {matches_3} out of {len(resps)} cases ')
# Out:
# claude-3.5-sonnet is able to find MCTD in top 1 for 0 out of 999 cases
# claude-3.5-sonnet is able to find MCTD in top 3 for 510 out of 999 cases

# %%
not_in_top_3 = utils.select_where_x_is_not_top(all_patients, keywords_list)
print(len(not_in_top_3))
# Out:
# 425

# %%
chat_gpt_4_responses = [resps[pt.n-1] for pt in not_in_top_3]
matches_1 = analyze_responses_for_top_three(chat_gpt_4_responses, keywords_list, k=1)
print(f'{model_new} is able to find {disease} in top 1 for {matches_1} out of {len(not_in_top_3)} cases where {model_old} fails')
matches_3 = analyze_responses_for_top_three(chat_gpt_4_responses, keywords_list, k=3)
print(f'{model_new} is able to find {disease} in top 3 for {matches_3} out of {len(not_in_top_3)} cases where {model_old} fails ')
# Out:
# claude-3.5-sonnet is able to find MCTD in top 1 for 0 out of 425 cases where claude-3-opus fails
# claude-3.5-sonnet is able to find MCTD in top 3 for 163 out of 425 cases where claude-3-opus fails
