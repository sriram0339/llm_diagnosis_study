# %%
import pandas
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from openai import OpenAI
import utils

# %%
disease='SLE'
symp_type='informal'
#model_old='chatgpt-3.5'
#model_new='chatgpt-4o'
#model_new_name = 'gpt-4o'


model_old='claude-3-opus'
model_new='claude-3.5-sonnet'
model_new_name = 'claude-3-5-sonnet-20240620'

filename=f'{disease}-{symp_type}-{model_old}.txt'
output_filename = f'{disease}-{symp_type}-{model_new}.txt'
keywords_list = ['sle', 'lupus']

# %% [markdown]
# ## Run More Complex Models
#
# The goal is to run more complex models and compare against the outputs of the baseline model.

# %%
all_patients = utils.process_file(filename)
# Out:
# Patient: number 1, gender female, age 10, weight 54, height 46
# Symptom: lumps in neck
# Symptom: Butterfly rash
# Symptom: Lung disease
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The presence of a butterfly rash and lung disease are common manifestations of SLE, an autoimmune disorder that can affect multiple organ systems, including the skin, joints, and lungs.*
# response: 2,*Lymphoma*,20%,*The lumps in the neck could be swollen lymph nodes, which can be a sign of lymphoma, a type of cancer that affects the lymphatic system.*
# response: 3,*Juvenile Idiopathic Arthritis (JIA)*,10%,*While not specifically mentioned, joint pain and swelling are common symptoms of JIA, an autoimmune disorder that can also cause rashes and lung involvement in some cases.*
# response: 4,*Sarcoidosis*,5%,*This inflammatory disorder can cause lung disease and swollen lymph nodes, although the butterfly rash is less common in sarcoidosis.*
# response: 5,*Juvenile Dermatomyositis*,5%,*This autoimmune disorder can cause a rash similar to the butterfly rash, as well as lung disease and muscle weakness, although swollen lymph nodes are less common.*
# Patient: number 2, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: lumps in neck
# Symptom: Enlarged Spleen
# Symptom: Joint pain
# Symptom: rash on face
# Symptom: Sores in mouth
# Symptom: Blood in urine
# Symptom: chest pain
# Symptom: sore muscles
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of fever, rash, joint pain, and potential kidney involvement (blood in urine) is highly suggestive of SLE in a young female patient.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,25%,*The presence of joint pain, fever, and rash could indicate JIA, a type of autoimmune arthritis that can affect children.*
# response: 3,*Acute Lymphoblastic Leukemia (ALL)*,15%,*The enlarged spleen, fever, and potential bone/joint pain could be signs of ALL, a type of blood cancer common in children.*
# response: 4,*Kawasaki Disease*,10%,*The fever, rash, and potential lymphadenopathy (lumps in neck) are characteristic of this childhood vasculitis disorder.*
# response: 5,*Juvenile Dermatomyositis*,10%,*The muscle pain, rash, and fever could suggest this autoimmune condition affecting the skin and muscles in children.*
# Patient: number 3, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Weight loss
# Symptom: Joint swelling
# Symptom: Butterfly rash
# Symptom: Sores in nose
# Symptom: Hair thinning
# Symptom: Psychosis
# response: 1,*Systemic Lupus Erythematosus (SLE)*,70%,*The combination of fever, butterfly rash, joint swelling, and hair thinning are classic symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Dermatomyositis*,15%,*The presence of fever, rash, and muscle weakness (suggested by weight loss) could indicate juvenile dermatomyositis, an inflammatory muscle disease.*
# response: 3,*Vasculitis*,5%,*The sores in the nose and psychosis could be manifestations of vasculitis, an inflammation of blood vessels that can affect various organs.*
# response: 4,*Juvenile Idiopathic Arthritis*,5%,*The joint swelling and fever could be signs of juvenile idiopathic arthritis, an autoimmune disorder that primarily affects the joints.*
# response: 5,*Lymphoma*,5%,*Weight loss, fever, and psychosis can sometimes be seen in lymphoma, a type of blood cancer that can affect various organs and systems.*
# Patient: number 4, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Joint pain and  stiffness
# Symptom: Butterfly rash
# Symptom: Sores in mouth
# Symptom: Hair thinning
# Symptom: Protein in urine
# Symptom: Psychosis
# Symptom: Cardiovascular disease
# Symptom: chest pain
# Symptom: Stomach pain
# response: 1,*Systemic Lupus Erythematosus (SLE)*,80%,*The presence of fever, joint pain, butterfly rash, mouth sores, and proteinuria are classic symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,60%,*The joint pain, stiffness, and fever could be indicative of JIA, a type of arthritis that occurs in children.*
# response: 3,*Kawasaki Disease*,40%,*The fever, rash, and cardiovascular involvement could suggest Kawasaki disease, a rare childhood illness that affects the blood vessels.*
# response: 4,*Mixed Connective Tissue Disease (MCTD)*,30%,*The combination of symptoms, including fever, rash, joint pain, and potential organ involvement, could be consistent with MCTD, an autoimmune disorder with features of several connective tissue diseases.*
# response: 5,*Juvenile Dermatomyositis*,20%,*The presence of a rash, muscle weakness (suggested by the joint pain and stiffness), and potential organ involvement could indicate juvenile dermatomyositis, an inflammatory muscle disease.*
# Patient: number 5, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Enlarged Spleen
# Symptom: Weight loss
# Symptom: Rash that comes on in sun
# Symptom: Hair loss
# Symptom: chest pain
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of fever, rash, hair loss, and chest pain are common symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Leukemia*,25%,*The enlarged spleen, weight loss, and fever could be indicative of leukemia, a type of blood cancer that can affect children.*
# response: 3,*Juvenile Idiopathic Arthritis (JIA)*,15%,*The fever, rash, and chest pain could be manifestations of JIA, an autoimmune disorder that causes joint inflammation and can also involve other organs.*
# response: 4,*Juvenile Dermatomyositis*,10%,*The rash, hair loss, and muscle weakness (suggested by chest pain) are characteristic of this autoimmune condition that affects the skin and muscles.*
# response: 5,*Viral Infection*,10%,*The fever, rash, and enlarged spleen could also be caused by a viral infection, such as Epstein-Barr virus or cytomegalovirus, which can sometimes present with these symptoms in children.*
# Patient: number 6, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Enlarged Liver and Spleen
# Symptom: Weight loss
# Symptom: Joint pain and  stiffness
# Symptom: rash on face
# Symptom: Rash that comes on in sun
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Fever, rash, joint pain, and photosensitivity are common symptoms of SLE, which is an autoimmune disorder that can affect multiple organs, including the liver and spleen.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,30%,*Joint pain, stiffness, and fever are common in JIA, which is an autoimmune disorder that primarily affects the joints but can also cause systemic symptoms like rash and enlarged organs.*
# response: 3,*Acute Lymphoblastic Leukemia (ALL)*,15%,*Fever, weight loss, and enlarged liver and spleen can be signs of ALL, which is a type of blood cancer that is more common in children.*
# response: 4,*Juvenile Dermatomyositis*,10%,*Rash, joint pain, and fever are characteristic of this autoimmune disorder that affects the muscles and skin.*
# response: 5,*Viral Hepatitis*,5%,*Enlarged liver and spleen, along with fever and rash, can be seen in viral hepatitis, which is an inflammation of the liver caused by a viral infection.*
# Patient: number 7, gender female, age 10, weight 54, height 46
# Symptom: Enlarged Liver
# Symptom: Weight loss
# Symptom: Joint pain
# Symptom: Butterfly rash
# Symptom: Sores in mouth
# Symptom: Headache
# Symptom: Cardiovascular disease
# Symptom: Stomach pain
# response: 1,*Systemic Lupus Erythematosus (SLE)*,70%,*The presence of butterfly rash, joint pain, mouth sores, and potential organ involvement (enlarged liver, cardiovascular disease) are characteristic of SLE.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,50%,*Joint pain, weight loss, and potential organ involvement (enlarged liver) can be seen in JIA, particularly the systemic onset type.*
# response: 3,*Autoimmune Hepatitis*,40%,*Enlarged liver, joint pain, and potential autoimmune features (butterfly rash, mouth sores) could indicate autoimmune hepatitis.*
# response: 4,*Inflammatory Bowel Disease (IBD)*,30%,*Weight loss, stomach pain, and potential extraintestinal manifestations (joint pain, mouth sores) can be seen in IBD, such as Crohn's disease or ulcerative colitis.*
# response: 5,*Juvenile Dermatomyositis*,20%,*The presence of a rash (butterfly rash), joint pain, and potential muscle involvement (weight loss, headache) could suggest juvenile dermatomyositis.*
# Patient: number 8, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Enlarged Liver
# Symptom: Joint pain and  stiffness
# Symptom: rash on face
# Symptom: Blood in urine
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Fever, rash, joint pain, and blood in urine are common symptoms of SLE, an autoimmune disorder that can affect multiple organs.*
# response: 2,*Henoch-Schönlein Purpura (HSP)*,30%,*HSP is a vasculitis that can cause fever, rash, joint pain, and blood in urine, and is more common in children.*
# response: 3,*Acute Glomerulonephritis*,15%,*The presence of blood in urine, fever, and enlarged liver can indicate acute glomerulonephritis, an inflammation of the kidney's filtering units.*
# response: 4,*Juvenile Idiopathic Arthritis (JIA)*,10%,*JIA is an autoimmune disorder that can cause joint pain, stiffness, fever, and rash, and is more common in children.*
# response: 5,*Viral Hepatitis*,5%,*Fever, enlarged liver, and rash can be symptoms of viral hepatitis, an inflammation of the liver caused by a viral infection.*
# Patient: number 9, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Joint swelling
# Symptom: rash on face
# Symptom: Protein in urine
# Symptom: Poor school performance
# Symptom: Pleuritis
# Symptom: Stomach pain
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of fever, rash, joint swelling, pleuritis, and proteinuria is highly suggestive of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,25%,*The presence of joint swelling and fever could indicate JIA, a type of childhood arthritis that can also involve rash and other systemic symptoms.*
# response: 3,*Henoch-Schönlein Purpura (HSP)*,15%,*The rash, joint swelling, abdominal pain, and proteinuria are consistent with HSP, a vasculitis that primarily affects children.*
# response: 4,*Acute Glomerulonephritis*,10%,*The presence of proteinuria and fever could suggest an underlying kidney disorder, such as acute glomerulonephritis, which can also cause joint pain and rash.*
# response: 5,*Juvenile Dermatomyositis*,10%,*The combination of rash, fever, and muscle weakness (indicated by poor school performance) could point towards juvenile dermatomyositis, an autoimmune condition affecting the skin and muscles.*
# Patient: number 10, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Butterfly rash
# Symptom: Sores in nose
# Symptom: Seizures
# Symptom: Headache
# Symptom: chest pain
# Symptom: Shortness of breath
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The presence of fever, butterfly rash, and seizures are common symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Dermatomyositis*,20%,*The combination of fever, rash, and muscle weakness (indicated by chest pain and shortness of breath) can suggest juvenile dermatomyositis, an inflammatory muscle disease.*
# response: 3,*Vasculitis*,10%,*Fever, rash, and nasal sores can be manifestations of vasculitis, an inflammation of blood vessels that can affect various organs.*
# response: 4,*Juvenile Idiopathic Arthritis*,5%,*Fever, rash, and joint pain (indicated by chest pain) can be seen in some forms of juvenile idiopathic arthritis, an autoimmune disorder affecting joints.*
# response: 5,*Kawasaki Disease*,5%,*Fever, rash, and chest pain (potentially indicating coronary artery involvement) can be symptoms of Kawasaki disease, a rare childhood illness that affects blood vessels.*
# Patient: number 11, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Sores in nose
# Symptom: Cardiovascular disease
# Symptom: sore muscles
# response: 1,*Kawasaki Disease*,60%,*Fever, sores in the nose, cardiovascular involvement, and muscle pain are all characteristic symptoms of Kawasaki disease, a rare childhood illness that causes inflammation in blood vessels.*
# response: 2,*Juvenile Idiopathic Arthritis*,20%,*Fever, muscle pain, and potential cardiovascular involvement could be signs of juvenile idiopathic arthritis, an autoimmune disorder that causes joint inflammation and can affect other organs.*
# response: 3,*Systemic Lupus Erythematosus*,10%,*Fever, muscle pain, and potential cardiovascular involvement could be indicative of systemic lupus erythematosus, an autoimmune disorder that can affect multiple organ systems.*
# response: 4,*Viral Infection*,5%,*Fever, sores in the nose, and muscle pain could be caused by a viral infection, such as influenza or a common cold virus, although the cardiovascular involvement is less typical.*
# response: 5,*Bacterial Infection*,5%,*Fever, sores in the nose, and muscle pain could potentially be caused by a bacterial infection, such as streptococcal pharyngitis or staphylococcal infection, but the cardiovascular involvement is less common.*
# Patient: number 12, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Joint pain
# Symptom: rash on face
# Symptom: Protein in urine
# Symptom: Pleuritis
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of fever, joint pain, rash, and protein in urine are common manifestations of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,25%,*The presence of joint pain and fever could indicate JIA, a type of arthritis that affects children, and can sometimes be accompanied by rash and pleuritis.*
# response: 3,*Henoch-Schönlein Purpura (HSP)*,15%,*HSP is a vasculitis disorder that can cause rash, joint pain, and protein in urine, and is more common in children.*
# response: 4,*Kawasaki Disease*,10%,*Kawasaki disease is a rare childhood illness that can cause fever, rash, and inflammation of various organs, including the heart and lungs (pleuritis).*
# response: 5,*Post-Streptococcal Glomerulonephritis*,10%,*This condition, caused by a previous streptococcal infection, can lead to fever, joint pain, rash, and protein in urine due to kidney inflammation.*
# Patient: number 13, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Sores in mouth
# Symptom: Seizures
# Symptom: Depression
# Symptom: Cardiovascular disease
# Symptom: Pleuritis
# Symptom: Stomach pain
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The combination of joint pain, mouth sores, seizures, and pleuritis are common manifestations of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,20%,*Joint pain and mouth sores can be symptoms of JIA, a type of arthritis that occurs in children, and depression can be a comorbid condition.*
# response: 3,*Inflammatory Bowel Disease (IBD)*,10%,*Stomach pain and mouth sores can be indicative of IBD, such as Crohn's disease or ulcerative colitis, which can also cause joint pain and depression.*
# response: 4,*Vasculitis*,5%,*Cardiovascular disease and pleuritis can be signs of vasculitis, an inflammation of blood vessels, which can also cause joint pain and mouth sores.*
# response: 5,*Central Nervous System (CNS) Vasculitis*,5%,*Seizures and depression can be neurological manifestations of CNS vasculitis, an inflammation of blood vessels in the brain and spinal cord, which can also cause joint pain and mouth sores.*
# Patient: number 14, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: lumps in neck
# Symptom: Enlarged Liver and Spleen
# Symptom: Joint swelling
# Symptom: Butterfly rash
# Symptom: Rash that comes on in sun
# Symptom: Sores in mouth
# Symptom: Protein in urine
# Symptom: Shortness of breath
# Symptom: Stomach pain
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The presence of fever, butterfly rash, joint swelling, and protein in urine are classic symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,20%,*The joint swelling, fever, and enlarged liver and spleen could be indicative of JIA, a type of arthritis that affects children.*
# response: 3,*Acute Lymphoblastic Leukemia (ALL)*,10%,*The enlarged liver and spleen, along with fever and shortness of breath, could suggest ALL, a type of blood cancer common in children.*
# response: 4,*Juvenile Dermatomyositis*,5%,*The rash that comes on in the sun, along with fever and joint swelling, could point to juvenile dermatomyositis, an autoimmune disorder affecting muscles and skin.*
# response: 5,*Kawasaki Disease*,5%,*The fever, lymphadenopathy (lumps in neck), and rash could be signs of Kawasaki disease, a rare childhood illness that affects blood vessels.*
# Patient: number 15, gender female, age 10, weight 54, height 46
# Symptom: Fever
# response: 1,*Viral Infection (e.g., Influenza, Common Cold)*,60%,*Fever is a common symptom of viral infections, which are prevalent in children.*
# response: 2,*Bacterial Infection (e.g., Streptococcal Pharyngitis, Urinary Tract Infection)*,20%,*Bacterial infections can also cause fever, especially if left untreated.*
# response: 3,*Gastroenteritis*,10%,*Fever can accompany gastrointestinal illnesses like viral gastroenteritis, which is common in children.*
# response: 4,*Otitis Media (Ear Infection)*,5%,*Ear infections are frequent in children and can present with fever as a symptom.*
# response: 5,*Kawasaki Disease*,5%,*Although rare, Kawasaki disease is a childhood illness that can cause fever and other symptoms.*
# Patient: number 16, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: lumps in neck
# Symptom: Butterfly rash
# Symptom: Sores in mouth
# Symptom: Lung disease
# response: 1,*Systemic Lupus Erythematosus (SLE)*,70%,*The presence of fever, butterfly rash, oral sores, and potential lung involvement are characteristic symptoms of SLE.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,15%,*The presence of fever and lymphadenopathy (lumps in the neck) can be seen in JIA, although the other symptoms are less specific.*
# response: 3,*Juvenile Dermatomyositis*,10%,*The fever, rash, and potential lung involvement could be indicative of juvenile dermatomyositis, although the other symptoms are less specific.*
# response: 4,*Lymphoma*,3%,*The presence of fever and lymphadenopathy (lumps in the neck) can be seen in lymphoma, but the other symptoms are less typical.*
# response: 5,*Infectious Mononucleosis*,2%,*The fever and lymphadenopathy (lumps in the neck) could be consistent with infectious mononucleosis, but the other symptoms are less typical.*
# Patient: number 17, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: rash on face
# Symptom: Protein in urine
# Symptom: Headache
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Joint pain, rash, and proteinuria are common manifestations of SLE, which is an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,30%,*Joint pain and rash can be symptoms of JIA, which is an autoimmune disorder that primarily affects the joints in children.*
# response: 3,*Henoch-Schönlein Purpura (HSP)*,15%,*HSP is a vasculitis that can cause joint pain, rash, and proteinuria, and is more common in children.*
# response: 4,*Acute Glomerulonephritis*,10%,*Proteinuria and headache can be symptoms of acute glomerulonephritis, which is an inflammation of the kidney's filtering units.*
# response: 5,*Juvenile Dermatomyositis*,5%,*Joint pain, rash, and headache can be symptoms of juvenile dermatomyositis, which is an autoimmune disorder that affects the muscles and skin.*
# Patient: number 18, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Joint pain and  stiffness
# Symptom: Butterfly rash
# Symptom: Sores in mouth
# Symptom: Blood in urine
# Symptom: Shortness of breath
# response: 1,*Systemic Lupus Erythematosus (SLE)*,70%,*The presence of fever, joint pain, butterfly rash, oral sores, and blood in urine are classic symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,15%,*The joint pain and stiffness, along with fever, could indicate JIA, a type of arthritis that affects children.*
# response: 3,*Henoch-Schönlein Purpura (HSP)*,5%,*The presence of blood in urine and joint pain could suggest HSP, a condition characterized by inflammation of small blood vessels.*
# response: 4,*Kawasaki Disease*,5%,*The fever, rash, and mouth sores could be indicative of Kawasaki disease, a rare childhood illness that affects the blood vessels.*
# response: 5,*Juvenile Dermatomyositis*,5%,*The rash, joint pain, and shortness of breath could be signs of juvenile dermatomyositis, an inflammatory disease that affects the muscles and skin.*
# Patient: number 19, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: lumps in neck
# Symptom: Weight loss
# Symptom: Joint pain and  stiffness
# Symptom: Blood in urine
# Symptom: Cardiovascular disease
# Symptom: Lung disease
# Symptom: Pleuritis
# Symptom: Abnormal liver function
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of fever, joint pain, weight loss, and potential involvement of multiple organs (cardiovascular, lung, liver) is consistent with SLE, an autoimmune disorder.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,25%,*The presence of joint pain, stiffness, and fever could indicate JIA, a type of childhood arthritis with potential systemic involvement.*
# response: 3,*Lymphoma*,15%,*The presence of lumps in the neck, weight loss, and potential organ involvement (lung, liver) could suggest a lymphoproliferative disorder like lymphoma.*
# response: 4,*Vasculitis*,10%,*The combination of fever, joint pain, blood in urine, and potential organ involvement (cardiovascular, lung, liver) could be indicative of a vasculitic disorder.*
# response: 5,*Tuberculosis*,10%,*The presence of fever, weight loss, lung involvement (pleuritis), and potential lymphadenopathy (lumps in neck) could suggest tuberculosis, especially in a pediatric patient.*
# Patient: number 20, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Weight loss
# Symptom: Joint pain
# Symptom: Butterfly rash
# Symptom: Protein in urine
# Symptom: Poor school performance
# Symptom: Pleuritis
# Symptom: Abnormal liver function
# response: 1,*Systemic Lupus Erythematosus (SLE)*,70%,*The combination of fever, butterfly rash, joint pain, pleuritis, and abnormal liver function tests are highly suggestive of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,15%,*The presence of joint pain, fever, and weight loss could indicate JIA, a type of childhood arthritis that can also involve other organs.*
# response: 3,*Juvenile Dermatomyositis*,5%,*The rash, muscle weakness (indicated by poor school performance), and abnormal liver function tests could point to this autoimmune condition affecting the skin and muscles.*
# response: 4,*Glomerulonephritis*,5%,*The presence of protein in the urine suggests kidney involvement, which could be due to various forms of glomerulonephritis, an inflammation of the kidney's filtering units.*
# response: 5,*Vasculitis*,5%,*The combination of fever, rash, joint pain, and abnormal liver function tests could also be indicative of a vasculitis, an inflammation of blood vessels that can affect multiple organs.*
# Patient: number 21, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Joint swelling
# Symptom: Cannot  tolerate sun
# Symptom: Hair thinning
# Symptom: chest pain
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Fever, joint swelling, photosensitivity, and hair thinning are common symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,30%,*Joint swelling and fever are common in JIA, an autoimmune condition that causes joint inflammation in children.*
# response: 3,*Dermatomyositis*,15%,*Fever, muscle weakness (which can cause chest pain), photosensitivity, and hair thinning are symptoms of this autoimmune disorder affecting the skin and muscles.*
# response: 4,*Kawasaki Disease*,10%,*Fever, joint swelling, and chest pain (due to potential coronary artery involvement) are seen in this childhood vasculitis.*
# response: 5,*Juvenile Rheumatoid Arthritis (JRA)*,5%,*Joint swelling, fever, and chest pain (due to potential lung involvement) can occur in this type of childhood arthritis.*
# Patient: number 22, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Joint pain and  stiffness
# Symptom: Protein in urine
# Symptom: Psychosis
# Symptom: Abnormal liver function
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of fever, joint pain, proteinuria, and abnormal liver function tests are consistent with SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,25%,*The presence of fever, joint pain, and stiffness could indicate JIA, a type of arthritis that affects children.*
# response: 3,*Henoch-Schönlein Purpura (HSP)*,15%,*HSP is a vasculitis that can cause joint pain, proteinuria, and abdominal pain, which could explain the abnormal liver function tests.*
# response: 4,*Acute Glomerulonephritis*,10%,*The presence of proteinuria and abnormal liver function tests could suggest acute glomerulonephritis, a kidney disorder that can also cause joint pain and fever.*
# response: 5,*Autoimmune Hepatitis*,10%,*The abnormal liver function tests and fever could be indicative of autoimmune hepatitis, a chronic liver disease that can also cause joint pain and proteinuria.*
# Patient: number 23, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: lumps in neck
# Symptom: Weight loss
# Symptom: Joint pain
# Symptom: Butterfly rash
# Symptom: Rash that comes on in sun
# Symptom: Protein in urine
# Symptom: Cardiovascular disease
# Symptom: chest pain
# Symptom: sore muscles
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The presence of fever, butterfly rash, joint pain, and proteinuria are classic symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,20%,*The joint pain, fever, and weight loss could be indicative of JIA, a type of arthritis that affects children.*
# response: 3,*Juvenile Dermatomyositis*,10%,*The rash that worsens with sun exposure, muscle weakness, and fever could suggest juvenile dermatomyositis, an inflammatory condition affecting the skin and muscles.*
# response: 4,*Kawasaki Disease*,5%,*The fever, lymphadenopathy (lumps in the neck), and cardiovascular involvement could be signs of Kawasaki disease, a rare childhood illness that affects the blood vessels.*
# response: 5,*Lymphoma*,5%,*The weight loss, fever, and lymphadenopathy (lumps in the neck) could potentially be caused by lymphoma, a type of cancer that affects the lymphatic system.*
# Patient: number 24, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Enlarged Liver and Spleen
# Symptom: Sores in mouth
# Symptom: Protein in urine
# Symptom: Seizures
# Symptom: Headache
# Symptom: Shortness of breath
# Symptom: Stomach pain
# Symptom: Peritonitis (sterile)
# Symptom: Abnormal liver function
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of fever, enlarged liver and spleen, mouth sores, proteinuria, seizures, and abnormal liver function tests are consistent with SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Hemolytic Uremic Syndrome (HUS)*,25%,*The presence of fever, enlarged liver and spleen, proteinuria, seizures, and abnormal liver function tests could indicate HUS, a condition characterized by the abnormal destruction of red blood cells, leading to kidney failure.*
# response: 3,*Acute Lymphoblastic Leukemia (ALL)*,15%,*The enlarged liver and spleen, fever, headache, and shortness of breath could be signs of ALL, a type of blood cancer that affects white blood cells.*
# response: 4,*Autoimmune Hepatitis*,10%,*The abnormal liver function tests, fever, and enlarged liver could suggest autoimmune hepatitis, a condition where the body's immune system attacks the liver cells.*
# response: 5,*Kawasaki Disease*,10%,*The fever, mouth sores, abdominal pain, and peritonitis (sterile) could be indicative of Kawasaki disease, a rare childhood illness that affects the blood vessels.*
# Patient: number 25, gender female, age 10, weight 54, height 46
# Symptom: Weight loss
# Symptom: Joint pain and  stiffness
# Symptom: Butterfly rash
# Symptom: Cannot  tolerate sun
# Symptom: Sores in mouth
# Symptom: Blood in urine
# response: 1,*Systemic Lupus Erythematosus (SLE)*,70%,*The presence of a butterfly rash, joint pain, photosensitivity, and blood in urine are classic symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,15%,*The joint pain and stiffness, along with weight loss, could be indicative of JIA, a type of arthritis that affects children.*
# response: 3,*Juvenile Dermatomyositis*,5%,*The rash, joint pain, and weight loss could suggest juvenile dermatomyositis, an inflammatory disease affecting the muscles and skin.*
# response: 4,*Henoch-Schönlein Purpura (HSP)*,5%,*The presence of blood in urine and mouth sores could be signs of HSP, a condition that causes inflammation of small blood vessels.*
# response: 5,*Crohn's Disease*,5%,*Weight loss, mouth sores, and blood in urine can sometimes be seen in Crohn's disease, an inflammatory bowel disease that can affect various parts of the digestive tract.*
# Patient: number 26, gender female, age 10, weight 54, height 46
# Symptom: rash on face
# Symptom: Psychosis
# Symptom: Pleuritis
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of rash, psychosis, and pleuritis can be seen in SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Dermatomyositis*,25%,*This condition can present with a characteristic rash, along with muscle weakness and lung involvement (pleuritis), and sometimes psychosis.*
# response: 3,*Vasculitis*,15%,*Certain types of vasculitis, such as Henoch-Schönlein purpura, can cause rash, pleuritis, and neurological manifestations like psychosis.*
# response: 4,*Drug Reaction*,10%,*Certain medications can cause a drug rash with eosinophilia and systemic symptoms (DRESS syndrome), which can include rash, psychosis, and pleuritis.*
# response: 5,*Juvenile Idiopathic Arthritis*,10%,*While not a classic presentation, some forms of juvenile idiopathic arthritis can be associated with rash, lung involvement, and neuropsychiatric symptoms.*
# Patient: number 27, gender female, age 10, weight 54, height 46
# Symptom: Joint pain and  stiffness
# Symptom: rash on face
# Symptom: Protein in urine
# Symptom: Stomach pain
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Joint pain, rash, and proteinuria are common manifestations of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,30%,*Joint pain and stiffness are hallmarks of JIA, an autoimmune condition affecting children, and it can also cause rash and abdominal pain.*
# response: 3,*Henoch-Schönlein Purpura (HSP)*,15%,*HSP is a vasculitis that can cause joint pain, abdominal pain, rash, and proteinuria in children.*
# response: 4,*Juvenile Dermatomyositis*,10%,*This autoimmune condition can cause muscle weakness, rash, and joint pain, and it can also affect the kidneys, leading to proteinuria.*
# response: 5,*Post-streptococcal Glomerulonephritis*,5%,*This condition, caused by a recent streptococcal infection, can lead to joint pain, rash, and proteinuria due to kidney inflammation.*
# Patient: number 28, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: lumps in neck
# Symptom: Joint pain and  stiffness
# Symptom: Butterfly rash
# Symptom: Sores in mouth
# Symptom: Lung disease
# Symptom: Stomach pain
# Symptom: Peritonitis (sterile)
# response: 1,*Systemic Lupus Erythematosus (SLE)*,70%,*The presence of fever, butterfly rash, joint pain and stiffness, mouth sores, and potential lung and abdominal involvement are characteristic of SLE.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,50%,*The joint pain, stiffness, and fever could be indicative of JIA, particularly in a young patient.*
# response: 3,*Juvenile Dermatomyositis*,40%,*The fever, rash, and potential lung involvement could suggest juvenile dermatomyositis, an autoimmune condition affecting muscles and skin.*
# response: 4,*Lymphoma*,30%,*The presence of fever, lymphadenopathy (lumps in the neck), and potential abdominal involvement could be signs of lymphoma, although other symptoms are not typical.*
# response: 5,*Juvenile Rheumatoid Arthritis (JRA)*,25%,*The joint pain, stiffness, and fever could also be indicative of JRA, a form of arthritis affecting children.*
# Patient: number 29, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: rash on face
# Symptom: Blood in urine
# Symptom: Lung disease
# Symptom: Pleuritis
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The combination of joint pain, rash, hematuria (blood in urine), and pleuritis (inflammation of the pleural lining) are common manifestations of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Henoch-Schönlein Purpura (HSP)*,20%,*HSP is a vasculitis that can cause joint pain, rash, and hematuria in children. The lung involvement is less common but can occur.*
# response: 3,*Juvenile Idiopathic Arthritis (JIA)*,10%,*JIA can present with joint pain, rash, and lung involvement (pleuritis), but hematuria is less common.*
# response: 4,*Wegener's Granulomatosis*,5%,*This rare autoimmune disorder can cause joint pain, rash, lung disease (including pleuritis), and hematuria, but it is more common in adults.*
# response: 5,*Microscopic Polyangiitis*,5%,*This small vessel vasculitis can cause joint pain, rash, lung disease (including pleuritis), and hematuria, but it is also more common in adults.*
# Patient: number 30, gender female, age 10, weight 54, height 46
# Symptom: lumps in neck
# Symptom: Joint pain
# Symptom: rash on face
# Symptom: Blood in urine
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,30%,*Joint pain and rash are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Lupus Nephritis*,25%,*Blood in urine and rash can be signs of lupus nephritis, which is an inflammation of the kidneys due to lupus, an autoimmune disease.*
# response: 3,*Lymphoma*,20%,*Lumps in the neck can be swollen lymph nodes, which can be a symptom of lymphoma, a type of blood cancer.*
# response: 4,*Henoch-Schönlein Purpura (HSP)*,15%,*HSP is a vasculitis disorder that can cause joint pain, rash, and blood in urine, especially in children.*
# response: 5,*Streptococcal Infection*,10%,*Rash, joint pain, and swollen lymph nodes can sometimes be caused by a streptococcal infection, such as strep throat or scarlet fever.*
# Patient: number 31, gender female, age 10, weight 54, height 46
# Symptom: Enlarged Liver
# Symptom: Joint swelling
# Symptom: rash on face
# Symptom: Abnormal liver function
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Enlarged liver, joint swelling, and rash on the face are common manifestations of SLE, an autoimmune disorder that can affect multiple organ systems, including the liver.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,30%,*Joint swelling and rash are common symptoms of JIA, an autoimmune disorder that primarily affects the joints but can also involve other organs, including the liver.*
# response: 3,*Autoimmune Hepatitis*,20%,*Abnormal liver function and enlarged liver are characteristic of autoimmune hepatitis, an autoimmune disorder that targets the liver.*
# response: 4,*Viral Hepatitis*,15%,*Abnormal liver function and enlarged liver can be caused by viral hepatitis, such as hepatitis A, B, or C, which can also present with rash and joint pain in some cases.*
# response: 5,*Wilson's Disease*,10%,*Wilson's disease is a rare genetic disorder that can cause liver dysfunction, neurological symptoms, and other manifestations, including joint swelling and rash in some cases.*
# Patient: number 32, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Enlarged Spleen
# Symptom: Joint pain and  stiffness
# Symptom: rash on face
# Symptom: Rash that comes on in sun
# Symptom: Hair loss
# Symptom: Blood in urine
# Symptom: Cardiovascular disease
# Symptom: Lung disease
# Symptom: Peritonitis (sterile)
# Symptom: Abnormal liver function
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The combination of fever, rash, joint pain, hair loss, and potential organ involvement (cardiovascular, lung, liver, and kidney) is highly suggestive of SLE.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,20%,*The presence of joint pain, stiffness, and fever could indicate JIA, particularly if the joint symptoms are persistent and accompanied by morning stiffness.*
# response: 3,*Acute Lymphoblastic Leukemia (ALL)*,10%,*The enlarged spleen, fever, and potential bone marrow involvement (indicated by blood in urine) could be signs of ALL, although other symptoms are not typical.*
# response: 4,*Juvenile Dermatomyositis*,5%,*The rash, muscle weakness (indicated by joint pain and stiffness), and potential organ involvement could suggest juvenile dermatomyositis, although other symptoms are not typical.*
# response: 5,*Henoch-Schönlein Purpura (HSP)*,5%,*The rash, joint pain, and potential kidney involvement (indicated by blood in urine) could be signs of HSP, although other symptoms are not typical.*
# Patient: number 33, gender female, age 10, weight 54, height 46
# Symptom: Enlarged Liver and Spleen
# Symptom: Weight loss
# Symptom: Butterfly rash
# Symptom: Blood in urine
# Symptom: Stomach pain
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The presence of butterfly rash, weight loss, and blood in urine are common symptoms of SLE, an autoimmune disorder that can affect multiple organs, including the liver, spleen, and kidneys.*
# response: 2,*Leukemia*,20%,*Enlarged liver and spleen, along with weight loss, can be signs of leukemia, a type of blood cancer that affects the production of blood cells.*
# response: 3,*Viral Hepatitis*,10%,*Enlarged liver and stomach pain could be indicative of viral hepatitis, an inflammation of the liver caused by a viral infection.*
# response: 4,*Hemolytic Anemia*,5%,*Blood in urine and an enlarged spleen can be associated with hemolytic anemia, a condition where red blood cells are destroyed prematurely.*
# response: 5,*Autoimmune Hepatitis*,5%,*Enlarged liver, weight loss, and stomach pain could be symptoms of autoimmune hepatitis, an autoimmune disorder that causes inflammation and damage to the liver.*
# Patient: number 34, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: lumps in neck
# Symptom: rash on face
# Symptom: Sores in nose
# Symptom: Hair thinning
# Symptom: Protein in urine
# Symptom: Stomach pain
# Symptom: Peritonitis (sterile)
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of fever, rash, hair thinning, proteinuria, and peritonitis are consistent with SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Dermatomyositis*,25%,*The presence of fever, rash, and muscle weakness (suggested by the peritonitis) could indicate juvenile dermatomyositis, an inflammatory muscle disease.*
# response: 3,*Lymphoma*,15%,*The lumps in the neck, fever, and weight loss could be signs of lymphoma, a cancer of the lymphatic system.*
# response: 4,*Kawasaki Disease*,10%,*The fever, rash, and sores in the nose could be indicative of Kawasaki disease, a rare childhood illness that affects the blood vessels.*
# response: 5,*Juvenile Idiopathic Arthritis*,10%,*The fever, rash, and stomach pain could be symptoms of juvenile idiopathic arthritis, an autoimmune disorder that causes joint inflammation and other systemic manifestations.*
# Patient: number 35, gender female, age 10, weight 54, height 46
# Symptom: Joint swelling
# Symptom: Butterfly rash
# Symptom: Rash that comes on in sun
# Symptom: Blood in urine
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The presence of a butterfly rash, joint swelling, and photosensitive rash are classic symptoms of SLE, and hematuria (blood in urine) can also occur due to lupus nephritis.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,20%,*Joint swelling and rash can be seen in some types of JIA, such as systemic JIA or polyarticular JIA, although the butterfly rash and photosensitivity are less common.*
# response: 3,*Henoch-Schönlein Purpura (HSP)*,10%,*HSP is a vasculitis that can cause joint swelling, rash, and hematuria, although the butterfly rash and photosensitivity are not typical features.*
# response: 4,*Juvenile Dermatomyositis*,5%,*Juvenile dermatomyositis can present with joint swelling, rash, and photosensitivity, but the butterfly rash and hematuria are less common.*
# response: 5,*Acute Glomerulonephritis*,5%,*Acute glomerulonephritis can cause hematuria and joint swelling, but the rash and photosensitivity are not typical features.*
# Patient: number 36, gender female, age 10, weight 54, height 46
# Symptom: lumps in neck
# Symptom: Weight loss
# Symptom: Sores in nose
# Symptom: Headache
# Symptom: Cardiovascular disease
# Symptom: Pleuritis
# response: 1,*Lymphoma*,40%,*Lumps in the neck, weight loss, and headache are common symptoms of lymphoma, a type of cancer that affects the lymphatic system.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,25%,*Pleuritis (inflammation of the lining of the lungs) and cardiovascular disease can be associated with JIA, an autoimmune disorder that affects children.*
# response: 3,*Wegener's Granulomatosis*,15%,*Sores in the nose, weight loss, and pleuritis can be symptoms of Wegener's Granulomatosis, a rare autoimmune disorder that affects the blood vessels.*
# response: 4,*Tuberculosis*,10%,*Weight loss, sores in the nose, and pleuritis can be symptoms of tuberculosis, a bacterial infection that primarily affects the lungs.*
# response: 5,*Sarcoidosis*,10%,*Sarcoidosis, an inflammatory disease that can cause lumps or nodules in the lymph nodes, lungs, and other organs, may explain the lumps in the neck, pleuritis, and cardiovascular disease.*
# Patient: number 37, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Weight loss
# Symptom: rash on face
# Symptom: Sores in mouth
# response: 1,*Juvenile Dermatomyositis*,40%,*Fever, rash, and mouth sores are common symptoms of this autoimmune disorder affecting muscles and skin.*
# response: 2,*Lupus Erythematosus*,30%,*The combination of fever, rash, and mouth sores can be seen in systemic lupus erythematosus, an autoimmune disorder.*
# response: 3,*Stevens-Johnson Syndrome*,15%,*This severe skin reaction can cause fever, rash, and mouth sores, often triggered by medications or infections.*
# response: 4,*Kawasaki Disease*,10%,*This childhood illness can present with fever, rash, mouth sores, and weight loss, often affecting children under 5 years old.*
# response: 5,*Crohn's Disease*,5%,*Although less likely in this age group, Crohn's disease can cause fever, weight loss, and mouth sores in some cases.*
# Patient: number 38, gender female, age 10, weight 54, height 46
# Symptom: lumps in neck
# Symptom: Weight loss
# Symptom: Joint swelling
# Symptom: rash on face
# Symptom: Seizures
# Symptom: Headache
# Symptom: chest pain
# Symptom: Shortness of breath
# response: 1,*Systemic Lupus Erythematosus (SLE)*,30%,*The combination of rash, joint swelling, seizures, and weight loss can be indicative of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,25%,*The presence of joint swelling, rash, and constitutional symptoms like weight loss and headache can suggest JIA, an autoimmune condition affecting joints and other organs.*
# response: 3,*Lymphoma*,20%,*The lumps in the neck, weight loss, and chest pain could be signs of lymphoma, a type of cancer affecting the lymphatic system.*
# response: 4,*Juvenile Dermatomyositis*,15%,*The rash, joint swelling, and muscle weakness (suggested by chest pain and shortness of breath) can be seen in juvenile dermatomyositis, an autoimmune condition affecting skin and muscles.*
# response: 5,*Vasculitis*,10%,*The rash, joint swelling, and neurological symptoms like seizures and headache can be manifestations of vasculitis, an inflammation of blood vessels.*
# Patient: number 39, gender female, age 10, weight 54, height 46
# Symptom: Hair thinning
# Symptom: Protein in urine
# Symptom: Headache
# Symptom: Cardiovascular disease
# Symptom: Shortness of breath
# Symptom: Pleuritis
# response: 1,*Lupus Nephritis*,40%,*Hair thinning, proteinuria, headache, and pleuritis are common manifestations of lupus, an autoimmune disorder that can affect multiple organ systems, including the kidneys, skin, and lungs.*
# response: 2,*Nephrotic Syndrome*,30%,*Proteinuria and edema (which can cause shortness of breath) are hallmarks of nephrotic syndrome, a kidney disorder characterized by excessive protein loss in the urine.*
# response: 3,*Juvenile Idiopathic Arthritis*,15%,*Hair thinning, joint pain (which can cause headaches), and pleuritis (inflammation of the lining of the lungs) can occur in juvenile idiopathic arthritis, an autoimmune disorder affecting children.*
# response: 4,*Kawasaki Disease*,10%,*Kawasaki disease is a rare childhood illness that can cause cardiovascular complications, including coronary artery aneurysms, which may explain the cardiovascular disease symptom.*
# response: 5,*Chronic Kidney Disease*,5%,*Proteinuria and shortness of breath (due to fluid retention) can be signs of chronic kidney disease, which can occur in children due to various underlying conditions.*
# Patient: number 40, gender female, age 10, weight 54, height 46
# Symptom: Sores in nose
# Symptom: Blood in urine
# Symptom: Abnormal liver function
# Symptom: Coughing up blood
# response: 1,*Granulomatosis with Polyangiitis (Wegener's Granulomatosis)*,40%,*Sores in the nose, abnormal liver function, and coughing up blood are common symptoms of this rare autoimmune disorder that affects small and medium-sized blood vessels.*
# response: 2,*Henoch-Schönlein Purpura*,25%,*This is a type of vasculitis that can cause blood in the urine, abdominal pain, and a rash or sores, which may explain the sores in the nose and blood in the urine.*
# response: 3,*Lupus Nephritis*,15%,*This is a kidney disorder caused by systemic lupus erythematosus (SLE), an autoimmune disease that can cause blood in the urine, abnormal liver function, and other symptoms.*
# response: 4,*Goodpasture's Syndrome*,10%,*This rare autoimmune disorder can cause bleeding from the lungs (coughing up blood) and kidney problems (blood in the urine), as well as abnormal liver function.*
# response: 5,*Microscopic Polyangiitis*,10%,*This is a type of vasculitis that can cause kidney problems (blood in the urine), lung problems (coughing up blood), and abnormal liver function.*
# Patient: number 41, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Sores in nose
# Symptom: Psychosis
# Symptom: Poor school performance
# Symptom: Cardiovascular disease
# Symptom: Lung disease
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*The combination of fever, nasal sores, psychosis, and potential organ involvement (cardiovascular and lung disease) is consistent with SLE, an autoimmune disorder that can affect multiple organ systems.*
# ...
# response: 4,*Lymphoma*,10%,*Fever, lymph node swelling (lumps in neck), and abnormal liver function can be seen in lymphoma, a type of cancer.*
# response: 5,*Wegener's Granulomatosis*,10%,*Fever, nasal sores, joint swelling, and abnormal liver function can occur in this rare autoimmune vasculitis.*
# Patient: number 988, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Enlarged Liver
# Symptom: Joint pain and  stiffness
# Symptom: Butterfly rash
# Symptom: chest pain
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The presence of fever, joint pain, stiffness, butterfly rash, and chest pain are characteristic symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,20%,*The joint pain, stiffness, and fever could be indicative of JIA, a type of arthritis that occurs in children, although the other symptoms are less common in JIA.*
# response: 3,*Viral Hepatitis*,10%,*The enlarged liver (hepatomegaly) and fever could suggest a viral infection affecting the liver, such as hepatitis A, B, or C, although the other symptoms are not typical of viral hepatitis.*
# response: 4,*Leukemia*,5%,*The enlarged liver, fever, and joint pain could potentially be caused by leukemia, a type of blood cancer, although the other symptoms are less common in leukemia.*
# response: 5,*Kawasaki Disease*,5%,*The fever, joint pain, and chest pain could be indicative of Kawasaki disease, a rare childhood illness that affects the blood vessels, although the other symptoms are less typical of this condition.*
# Patient: number 989, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Joint swelling
# Symptom: Cannot  tolerate sun
# Symptom: Sores in nose
# Symptom: Psychosis
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The combination of fever, joint swelling, photosensitivity, and mucosal ulcers (sores in the nose) are characteristic symptoms of SLE, an autoimmune disorder that can also involve neuropsychiatric manifestations like psychosis.*
# response: 2,*Juvenile Dermatomyositis*,20%,*This autoimmune condition can present with fever, joint swelling, photosensitivity, and skin rashes or ulcers, while psychosis is a rare but possible manifestation.*
# response: 3,*Juvenile Idiopathic Arthritis*,10%,*The fever, joint swelling, and inability to tolerate sun exposure could be indicative of this autoimmune arthritis, although the nasal sores and psychosis are less common features.*
# response: 4,*Vasculitis*,5%,*Certain types of vasculitis, such as Henoch-Schönlein purpura, can cause fever, joint swelling, nasal ulcers, and occasionally neurological symptoms like psychosis, but photosensitivity is less common.*
# response: 5,*Acute Rheumatic Fever*,5%,*This post-streptococcal condition can involve fever, joint swelling, and rarely neuropsychiatric symptoms, but photosensitivity and nasal ulcers are not typical features.*
# Patient: number 990, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: lumps in neck
# Symptom: Enlarged Liver
# Symptom: Joint swelling
# Symptom: Blood in urine
# Symptom: Psychosis
# Symptom: Cardiovascular disease
# Symptom: Stomach pain
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Fever, joint swelling, enlarged liver, and blood in urine are common symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Leukemia*,25%,*Fever, enlarged liver, and blood in urine can be signs of leukemia, a cancer of the blood and bone marrow, which can also cause swollen lymph nodes in the neck.*
# response: 3,*Juvenile Idiopathic Arthritis (JIA)*,15%,*Joint swelling and fever are common symptoms of JIA, an autoimmune disorder that causes joint inflammation in children.*
# response: 4,*Henoch-Schönlein Purpura (HSP)*,10%,*HSP is a vasculitis disorder that can cause joint swelling, abdominal pain, and blood in urine, and is more common in children.*
# response: 5,*Acute Glomerulonephritis*,10%,*Blood in urine, fever, and joint swelling can be signs of acute glomerulonephritis, an inflammation of the kidney's filtering units.*
# Patient: number 991, gender female, age 10, weight 54, height 46
# Symptom: Enlarged Spleen
# Symptom: rash on face
# Symptom: Cannot  tolerate sun
# Symptom: chest pain
# Symptom: Stomach pain
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Rash, photosensitivity, and multi-organ involvement (enlarged spleen, chest pain, and stomach pain) are common manifestations of SLE.*
# response: 2,*Acute Leukemia*,25%,*Enlarged spleen and constitutional symptoms like rash and pain can be seen in acute leukemia, especially in children.*
# response: 3,*Juvenile Idiopathic Arthritis (JIA)*,15%,*Rash, joint pain (chest pain), and abdominal pain can be present in JIA, particularly in systemic-onset JIA.*
# response: 4,*Vasculitis*,10%,*Rash, photosensitivity, and multi-organ involvement (enlarged spleen, chest pain, and stomach pain) can be seen in various types of vasculitis.*
# response: 5,*Inflammatory Bowel Disease (IBD)*,10%,*Abdominal pain and rash can be present in IBD, although enlarged spleen and photosensitivity are less common.*
# Patient: number 992, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Joint pain and  stiffness
# Symptom: Butterfly rash
# Symptom: Headache
# Symptom: Shortness of breath
# response: 1,*Systemic Lupus Erythematosus (SLE)*,70%,*The presence of fever, joint pain, butterfly rash, and shortness of breath are classic symptoms of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,15%,*The joint pain and stiffness, along with fever, could be indicative of JIA, a type of arthritis that affects children.*
# response: 3,*Juvenile Dermatomyositis*,5%,*The rash, muscle weakness (suggested by shortness of breath), and joint pain could be signs of this autoimmune condition affecting the skin and muscles.*
# response: 4,*Kawasaki Disease*,5%,*The fever, rash, and joint pain could be symptoms of this rare childhood illness that affects the blood vessels.*
# response: 5,*Viral Infection*,5%,*The fever, headache, and joint pain could be caused by a viral illness, although the other symptoms are less common with viral infections.*
# Patient: number 993, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Weight loss
# Symptom: Joint pain
# Symptom: Butterfly rash
# Symptom: Protein in urine
# Symptom: Cardiovascular disease
# response: 1,*Systemic Lupus Erythematosus (SLE)*,70%,*The presence of fever, joint pain, butterfly rash, and proteinuria are classic symptoms of SLE, an autoimmune disorder that can affect multiple organ systems, including the skin, joints, kidneys, and cardiovascular system.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,15%,*The joint pain and fever could be indicative of JIA, a type of arthritis that affects children and can cause inflammation in various joints, leading to pain, swelling, and stiffness.*
# response: 3,*Kawasaki Disease*,5%,*The fever, cardiovascular involvement, and weight loss could suggest Kawasaki disease, a rare childhood illness that causes inflammation in blood vessels, particularly the coronary arteries.*
# response: 4,*Juvenile Dermatomyositis*,5%,*The presence of a rash, joint pain, and potential muscle weakness (indicated by weight loss) could point to juvenile dermatomyositis, an autoimmune disorder that affects the skin and muscles.*
# response: 5,*Henoch-Schönlein Purpura (HSP)*,5%,*The joint pain, proteinuria, and potential rash (although not specifically mentioned as a purpuric rash) could be indicative of HSP, a vasculitis disorder that can affect the skin, joints, and kidneys in children.*
# Patient: number 994, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: lumps in neck
# Symptom: Enlarged Liver
# Symptom: Joint pain
# Symptom: rash on face
# Symptom: Protein in urine
# Symptom: Peritonitis (sterile)
# Symptom: Abnormal liver function
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Fever, rash, joint pain, and abnormal liver function are common symptoms of SLE, which is an autoimmune disorder that can affect multiple organs.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,25%,*Joint pain, fever, and rash can be manifestations of JIA, which is an autoimmune disorder affecting the joints and other organs.*
# response: 3,*Acute Lymphoblastic Leukemia (ALL)*,15%,*Enlarged liver, fever, and joint pain can be seen in ALL, which is a type of blood cancer common in children.*
# response: 4,*Kawasaki Disease*,10%,*Fever, rash, and lymphadenopathy (lumps in neck) are characteristic of Kawasaki disease, which is a rare childhood illness that affects blood vessels.*
# response: 5,*Henoch-Schönlein Purpura (HSP)*,10%,*Rash, joint pain, and protein in urine can be symptoms of HSP, which is a type of vasculitis that can affect the skin, joints, and kidneys.*
# Patient: number 995, gender female, age 10, weight 54, height 46
# Symptom: Weight loss
# Symptom: Joint pain and  stiffness
# Symptom: rash on face
# Symptom: Sores in mouth
# Symptom: Lung disease
# response: 1,*Juvenile Idiopathic Arthritis (JIA)*,40%,*Joint pain, stiffness, and rash are common symptoms of JIA, which is an autoimmune disorder affecting children.*
# response: 2,*Systemic Lupus Erythematosus (SLE)*,30%,*SLE is an autoimmune disease that can cause joint pain, rash, mouth sores, and lung involvement, especially in children and adolescents.*
# response: 3,*Crohn's Disease*,15%,*Crohn's disease is an inflammatory bowel disease that can cause weight loss, mouth sores, and lung complications in some cases.*
# response: 4,*Sarcoidosis*,10%,*Sarcoidosis is an inflammatory disorder that can affect multiple organs, including the lungs, joints, and skin, leading to symptoms like joint pain, rash, and lung disease.*
# response: 5,*Juvenile Dermatomyositis*,5%,*Juvenile Dermatomyositis is an autoimmune disorder that can cause muscle weakness, skin rash, and lung involvement in children.*
# Patient: number 996, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Joint swelling
# Symptom: rash on face
# Symptom: Sores in mouth
# Symptom: Protein in urine
# Symptom: chest pain
# Symptom: Abnormal liver function
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Fever, rash, joint swelling, oral ulcers, and proteinuria are common manifestations of SLE in children.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,30%,*Joint swelling, fever, and rash can be seen in JIA, particularly the systemic onset type.*
# response: 3,*Henoch-Schönlein Purpura (HSP)*,15%,*HSP can present with rash, joint pain, abdominal pain, and renal involvement (proteinuria) in children.*
# response: 4,*Kawasaki Disease*,10%,*Fever, rash, oral mucosal changes, and chest pain (due to potential coronary artery involvement) are characteristic of Kawasaki disease.*
# response: 5,*Acute Glomerulonephritis*,5%,*Proteinuria, fever, and abnormal liver function tests can be seen in acute glomerulonephritis, which can be triggered by various infections or autoimmune conditions.*
# Patient: number 997, gender female, age 10, weight 54, height 46
# Symptom: Enlarged Spleen
# Symptom: Butterfly rash
# Symptom: Rash that comes on in sun
# Symptom: Blood in urine
# Symptom: Abnormal liver function
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The presence of butterfly rash, photosensitive rash, and abnormal liver function tests are characteristic of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Henoch-Schönlein Purpura (HSP)*,20%,*The combination of rash, blood in urine, and abdominal pain (which can be caused by an enlarged spleen) is suggestive of HSP, a vasculitis that commonly affects children.*
# response: 3,*Autoimmune Hepatitis*,10%,*The abnormal liver function tests and the presence of other autoimmune features like rash and splenomegaly could indicate autoimmune hepatitis, a chronic liver disease.*
# response: 4,*Leukemia*,5%,*Splenomegaly and abnormal liver function tests can sometimes be seen in leukemia, a type of blood cancer, although the other symptoms are not typical.*
# response: 5,*Viral Hepatitis*,5%,*Viral hepatitis can cause abnormal liver function tests and splenomegaly, but the other symptoms are not commonly associated with this condition.*
# Patient: number 998, gender female, age 10, weight 54, height 46
# Symptom: Joint pain
# Symptom: Sores in mouth
# Symptom: chest pain
# Symptom: Abnormal liver function
# response: 1,*Systemic Lupus Erythematosus (SLE)*,40%,*Joint pain, mouth sores, and abnormal liver function can be manifestations of SLE, an autoimmune disorder that can affect multiple organ systems.*
# response: 2,*Juvenile Idiopathic Arthritis (JIA)*,30%,*Joint pain and chest pain (possibly due to inflammation around the lungs or chest wall) are common symptoms of JIA, an autoimmune disorder affecting children.*
# response: 3,*Inflammatory Bowel Disease (IBD)*,15%,*Mouth sores and abnormal liver function can be seen in IBD, which includes conditions like Crohn's disease and ulcerative colitis.*
# response: 4,*Juvenile Dermatomyositis*,10%,*Joint pain, muscle weakness (which could cause chest pain), and abnormal liver function can occur in this autoimmune disorder affecting muscles and skin.*
# response: 5,*Viral Infection (e.g., Epstein-Barr Virus, Cytomegalovirus)*,5%,*Viral infections can sometimes cause joint pain, mouth sores, and abnormal liver function, especially in children with immature immune systems.*
# Patient: number 999, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: lumps in neck
# Symptom: Joint swelling
# Symptom: Cannot  tolerate sun
# Symptom: Hair loss
# Symptom: Protein in urine
# Symptom: Poor school performance
# Symptom: Pneumonitis
# Symptom: Peritonitis (sterile)
# response: 1,*Systemic Lupus Erythematosus (SLE)*,60%,*The combination of fever, joint swelling, photosensitivity, hair loss, proteinuria, and serositis (peritonitis) are characteristic of SLE in children.*
# response: 2,*Juvenile Dermatomyositis*,20%,*The presence of fever, joint swelling, rash (photosensitivity), and muscle weakness (poor school performance) can be seen in juvenile dermatomyositis.*
# response: 3,*Juvenile Idiopathic Arthritis*,10%,*The joint swelling and fever could be due to juvenile idiopathic arthritis, but the other symptoms are not typical.*
# response: 4,*Lymphoma*,5%,*The presence of fever, lymphadenopathy (lumps in the neck), and pulmonary involvement (pneumonitis) could suggest lymphoma, but the other symptoms are not typical.*
# response: 5,*Juvenile Sarcoidosis*,5%,*The fever, lymphadenopathy, and pulmonary involvement (pneumonitis) could be seen in juvenile sarcoidosis, but the other symptoms are not typical.*
# Patient: number 1000, gender female, age 10, weight 54, height 46
# Symptom: Fever
# Symptom: Butterfly rash
# Symptom: Psychosis
# Symptom: Headache
# Symptom: Lung disease
# Symptom: Peritonitis (sterile)
# response: 1,*Systemic Lupus Erythematosus (SLE)*,70%,*The presence of fever, butterfly rash, and potential organ involvement (lung disease and peritonitis) are characteristic of SLE, an autoimmune disorder.*
# response: 2,*Juvenile Dermatomyositis*,15%,*The combination of fever, rash, and potential lung involvement could suggest juvenile dermatomyositis, an inflammatory muscle disorder.*
# response: 3,*Juvenile Rheumatoid Arthritis*,5%,*The fever, rash, and potential lung involvement could be manifestations of juvenile rheumatoid arthritis, an autoimmune disorder affecting joints and other organs.*
# response: 4,*Vasculitis*,5%,*The fever, rash, and potential organ involvement (lung disease and peritonitis) could be due to a vasculitis, an inflammation of blood vessels.*
# response: 5,*Acute Disseminated Encephalomyelitis (ADEM)*,5%,*The presence of fever, psychosis, and potential lung involvement could suggest ADEM, an inflammatory demyelinating disorder of the central nervous system.*

# %%
utils.run_llm_and_parse_response(all_patients[5], model_new_name)
# Out:
# Patient ID: 6
# [('Systemic Lupus Erythematosus (SLE)',
#   '40',
#   ' Combination of fever, joint pain, facial rash, and photosensitive rash strongly suggests SLE, which can also cause hepatosplenomegaly and weight loss in children.'),
#  ('Juvenile Idiopathic Arthritis (JIA)',
#   '25',
#   ' Joint pain and stiffness, fever, and rash are common symptoms; systemic JIA can also cause hepatosplenomegaly and weight loss.'),
#  ('Lyme Disease',
#   '15',
#   " Fever, joint pain, and rash can be present; hepatosplenomegaly is possible in late-stage disease. The rash may not be typical, but it's a consideration given the symptoms."),
#  ('Epstein-Barr Virus (EBV) Infection',
#   '10',
#   ' Can cause fever, hepatosplenomegaly, and occasionally joint pain. The rash is less common but possible, and weight loss can occur due to prolonged illness.'),
#  ('Leukemia',
#   '5',
#   ' While less likely, it can present with fever, hepatosplenomegaly, weight loss, and joint pain. The rash is less typical but can occur due to platelet deficiency or as a paraneoplastic symptom.')]

# %%
resps = [ utils.run_llm_and_parse_response(p, model_new_name) for p in all_patients]
# Out:
# Patient ID: 1
# Patient ID: 2
# Patient ID: 3
# Patient ID: 4
# Patient ID: 5
# Patient ID: 6
# Patient ID: 7
# Patient ID: 8
# Patient ID: 9
# Patient ID: 10
# Patient ID: 11
# Patient ID: 12
# Patient ID: 13
# Patient ID: 14
# Patient ID: 15
# Patient ID: 16
# Patient ID: 17
# Patient ID: 18
# Patient ID: 19
# Patient ID: 20
# Patient ID: 21
# Patient ID: 22
# Patient ID: 23
# Patient ID: 24
# Patient ID: 25
# Patient ID: 26
# Patient ID: 27
# Patient ID: 28
# Patient ID: 29
# Patient ID: 30
# Patient ID: 31
# Patient ID: 32
# Patient ID: 33
# Patient ID: 34
# Patient ID: 35
# Patient ID: 36
# Patient ID: 37
# Patient ID: 38
# Patient ID: 39
# Patient ID: 40
# Patient ID: 41
# Patient ID: 42
# Patient ID: 43
# Patient ID: 44
# Patient ID: 45
# Patient ID: 46
# Patient ID: 47
# Patient ID: 48
# Patient ID: 49
# Patient ID: 50
# Patient ID: 962
# Patient ID: 963
# Patient ID: 964
# Patient ID: 965
# Patient ID: 966
# Patient ID: 967
# Patient ID: 968
# Patient ID: 969
# Patient ID: 970
# Patient ID: 971
# Patient ID: 972
# Patient ID: 973
# Patient ID: 974
# Patient ID: 975
# Patient ID: 976
# Patient ID: 977
# Patient ID: 978
# Patient ID: 979
# Patient ID: 980
# Patient ID: 981
# Patient ID: 982
# Patient ID: 983
# Patient ID: 984
# Patient ID: 985
# Patient ID: 986
# Patient ID: 987
# Patient ID: 988
# Patient ID: 989
# Patient ID: 990
# Patient ID: 991
# Patient ID: 992
# Patient ID: 993
# Patient ID: 994
# Patient ID: 995
# Patient ID: 996
# Patient ID: 997
# Patient ID: 998
# Patient ID: 999

# %%
print(resps)
# Out:
# [[('Systemic Lupus Erythematosus (SLE)', '60', ' Butterfly rash is a hallmark symptom, and SLE can cause lymphadenopathy (neck lumps) and lung involvement'), ('Juvenile Idiopathic Arthritis (JIA)', '20', ' Can cause lymphadenopathy and lung disease, though butterfly rash is less common'), ('Sarcoidosis', '10', ' Can cause lymphadenopathy, lung disease, and occasionally facial rashes, though less common in children'), ('Lymphoma', '5', " Can cause lymphadenopathy (neck lumps) and lung involvement, but doesn't typically cause a butterfly rash"), ('Tuberculosis', '5', ' Can cause lymphadenopathy and lung disease, but the butterfly rash is not typical; less common in developed countries')], [('Systemic Lupus Erythematosus (SLE)', '70', ' Matches multiple symptoms including rash, joint pain, fever, and potential kidney involvement (blood in urine); common in young females'), ('Juvenile Idiopathic Arthritis (JIA)', '60', ' Explains joint pain, fever, and rash; can also cause enlarged spleen and lymph nodes (lumps in neck)'), ('Infectious Mononucleosis', '50', ' Accounts for fever, enlarged spleen, sore muscles, and lumps in neck (swollen lymph nodes); common in children and adolescents'), ('Kawasaki Disease', '40', ' Can cause fever, rash, swollen lymph nodes, and joint pain; typically affects children under 5 but can occur in older children'), ('Lyme Disease', '30', " May explain fever, joint pain, muscle soreness, and rash; less likely due to the combination of other symptoms but still possible if there's a history of tick exposure")], [('Systemic Lupus Erythematosus (SLE)', '70', ' Butterfly rash, joint swelling, and fever are classic symptoms of SLE; psychosis and hair thinning can also occur in pediatric lupus'), ('Juvenile Idiopathic Arthritis (JIA)', '15', ' Joint swelling and fever are common in JIA; weight loss and rash can occur, but the butterfly rash is less typical'), ('Mixed Connective Tissue Disease', '8', ' Can present with symptoms overlapping lupus and arthritis; fever, joint swelling, and rash are possible'), ('Lyme Disease', '5', ' Can cause fever, joint swelling, and rash; however, the butterfly rash and psychosis are less common'), ('Pediatric Sarcoidosis', '2', ' Can cause fever, weight loss, and joint symptoms; skin involvement is possible, but the specific symptoms are less typical')], [('Systemic Lupus Erythematosus (SLE)', '75', ' Classic presentation with butterfly rash, joint pain, fever, and multi-system involvement including renal and neuropsychiatric symptoms'), ('Juvenile Idiopathic Arthritis (JIA)', '60', ' Joint pain and stiffness, fever, and potential systemic involvement in a child, though some symptoms are atypical'), ('Mixed Connective Tissue Disease', '45', ' Overlapping features of lupus and other autoimmune conditions, with joint pain, fever, and multi-system involvement'), ('Lyme Disease', '30', ' Can cause fever, joint pain, and rash, though butterfly rash is atypical; cardiovascular involvement possible in later stages'), ('Kawasaki Disease', '20', ' Fever, rash, and potential cardiovascular involvement in a child, though some symptoms are atypical for this condition')], [('Systemic Lupus Erythematosus (SLE)', '40', ' Combination of fever, rash in sun exposure, hair loss, and chest pain are classic symptoms of SLE, which can affect children'), ('Juvenile Idiopathic Arthritis (JIA)', '25', ' Fever, rash, and chest pain (if due to pericarditis) can be present in JIA, which is more common in children'), ('Leukemia', '15', ' Fever, enlarged spleen, and weight loss are consistent with leukemia, which can occur in children'), ('Infectious Mononucleosis', '10', ' Fever, enlarged spleen, and fatigue (possibly causing weight loss) are typical symptoms, though less likely given the other symptoms'), ('Lyme Disease', '5', ' Fever, rash (though typically not sun-related), and joint pain (possibly manifesting as chest pain) can occur in Lyme disease, but less likely given the full symptom picture')],  ...

# %%
def dump_response_to_file(filehandle, patient, resp):
    print(f'P: {patient.n}, {patient.gender}, {patient.age}, {patient.weight}, {patient.height}', file=filehandle)
    for s in patient.symptom_list:
        print(f'S:{s}', file=filehandle)
    for (j, r) in enumerate(resp):
        (disease_name, prob, descr) = r
        print(f'R: {j+1}, {disease_name}, {prob}, {descr}', file=filehandle)

# dump responses to output file
fhandle = open(output_filename,'w')
for (pt, resp) in zip(all_patients, resps):
    dump_response_to_file(fhandle, pt, resp)
fhandle.close()

# %%
def analyze_responses_for_top_three(resps, keywords_list, k=3):
    num_matches = 0
    for resp in resps:
        for (j, r) in enumerate(resp):
            if (j < k):
                (disease_name, prob, descr) = r
                if utils.approx_matches(keywords_list, [disease_name]):
                    num_matches = num_matches + 1
                    break 
    return num_matches

# %%
matches_1 = analyze_responses_for_top_three(resps, keywords_list, k=1)
print(f'{model_new} is able to find {disease} in top 1 for {matches_1} out of {len(resps)} cases')
matches_3 = analyze_responses_for_top_three(resps, keywords_list, k=3)
print(f'{model_new} is able to find {disease} in top 3 for {matches_3} out of {len(resps)} cases ')
# Out:
# claude-3.5-sonnet is able to find SLE in top 1 for 901 out of 999 cases
# claude-3.5-sonnet is able to find SLE in top 3 for 970 out of 999 cases

# %%
not_in_top_3 = utils.select_where_x_is_not_top(all_patients, keywords_list)
print(len(not_in_top_3))
# Out:
# 37

# %%
chat_gpt_4_responses = [resps[pt.n-1] for pt in not_in_top_3]
matches_1 = analyze_responses_for_top_three(chat_gpt_4_responses, keywords_list, k=1)
print(f'{model_new} is able to find {disease} in top 1 for {matches_1} out of {len(not_in_top_3)} cases where {model_old} fails')
matches_3 = analyze_responses_for_top_three(chat_gpt_4_responses, keywords_list, k=3)
print(f'{model_new} is able to find {disease} in top 3 for {matches_3} out of {len(not_in_top_3)} cases where {model_old} fails ')
# Out:
# claude-3.5-sonnet is able to find SLE in top 1 for 3 out of 37 cases where claude-3-opus fails
# claude-3.5-sonnet is able to find SLE in top 3 for 13 out of 37 cases where claude-3-opus fails
