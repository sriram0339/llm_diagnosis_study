# %%
import pandas
from matplotlib import pyplot as plt
import numpy as np
import utils

t = 4

# %%
if t == 1:
    disease='MCTD'
    disease_fullname = 'Mixed Connective Tissue Disease'
    symp_types=['formal', 'informal']
    model_names = ['chatgpt-3.5', 'chatgpt-4o', 'claude-3-opus', 'claude-3.5-sonnet' ]
    keywords_list = ['mctd', 'mixed connective tissue disease']

# %%
if t == 2:
    disease='SLE'
    disease_fullname = 'Systemic Lupus Erythematosus' 
    symp_types=['formal', 'informal']
    model_names = ['chatgpt-3.5', 'chatgpt-4o', 'claude-3-opus', 'claude-3.5-sonnet' ]
    keywords_list = ['sle','lupus','systemic lupus erythematosus']

# %%
if t == 3:
    disease='JDM'
    disease_fullname = 'Juvenile Dermatomyositis'
    symp_types=['formal', 'informal']
    model_names = ['chatgpt-3.5', 'chatgpt-4o', 'claude-3-opus', 'claude-3.5-sonnet' ]
    keywords_list=['jdm', 'dermatomyositis']

# %%
if t == 4:
    disease='SystemicSclerosis'
    disease_fullname = 'Systemic Sclerosis'
    symp_types=['formal', 'informal']
    model_names = ['chatgpt-3.5', 'chatgpt-4o', 'claude-3-opus', 'claude-3.5-sonnet' ]
    keywords_list =  ['sclerosis','scleroderma']

# %%
all_diseases = ['SLE','SystemicSclerosis', 'JDM', 'MCTD']
all_types = ['formal', 'informal']
all_models = ['chatgpt-3.5', 'chatgpt-4o', 'claude-3-opus', 'claude-3.5-sonnet']
all_keywords = [ ['sle','lupus','systemic lupus erythematosus' ], 
                 ['sclerosis','scleroderma' ], 
                 [ 'jdm', 'dermatomyositis'], 
                 ['mctd', 'mixed connective tissue disease'] ]

# %%
top = {}
top_three = {}
top_five = {}

for s in symp_types:
    for m in model_names:
        fname = f'{disease}-{s}-{m}.txt'
        all_patients = utils.process_file(fname)
        top_symptom = sum([(1 if utils.approx_matches(keywords_list, p.get_top_three_symptoms(1)) else 0) for p in all_patients])
        top_three_symptom = sum([(1 if utils.approx_matches(keywords_list, p.get_top_three_symptoms(3)) else 0) for p in all_patients])
        top_five_symptom = sum([(1 if utils.approx_matches(keywords_list, p.get_top_three_symptoms(5)) else 0) for p in all_patients])
        n = len(all_patients)
        top[(s, m)] = top_symptom/n
        top_three[(s,m)] = top_three_symptom/n
        top_five[(s,m)] = top_five_symptom/n

# %%
bar_order = [(s,t) for s in symp_types for t in model_names]
print(bar_order)
# Out:
# [('formal', 'chatgpt-3.5'), ('formal', 'chatgpt-4o'), ('formal', 'claude-3-opus'), ('formal', 'claude-3.5-sonnet'), ('informal', 'chatgpt-3.5'), ('informal', 'chatgpt-4o'), ('informal', 'claude-3-opus'), ('informal', 'claude-3.5-sonnet')]

# %%
df_error = pandas.read_csv('results/error_bars_data.csv')

print(f'condition: {disease}')
# Now restrict to just the disease we care about
display(df_error[df_error['condition'] == disease] )

def get_accuracies_and_error_bars(bar_order):
    mod_disease = 'SSc' if (disease == 'SystemicSclerosis') else disease 
   # for (s, t) in bar_order:
   #     print(s, t)
   #     display(df_error.loc[ ((df_error['condition'] == mod_disease) & (df_error['type'] == s) & ( df_error['model'] == t) & (df_error['diagnosis'] == 3)), 'prob'].values[0])
    
    prob_series_formal3 = [ (df_error.loc[ ((df_error['condition'] == mod_disease) & (df_error['type'] == s) & ( df_error['model'] == t) & (df_error['diagnosis'] == 3)), 'mean']).values[0] for (s, t) in bar_order]
    lower_ci_series_formal3 = [ (df_error.loc[ ((df_error['condition'] == mod_disease) & (df_error['type'] == s) & ( df_error['model'] == t) & (df_error['diagnosis'] == 3)), 'lower_ci']).values[0] for (s, t) in bar_order]
    upper_ci_series_formal3 =  [ (df_error.loc[ ((df_error['condition'] == mod_disease) & (df_error['type'] == s) & ( df_error['model'] == t) & (df_error['diagnosis'] == 3)), 'upper_ci']).values[0] for (s, t) in bar_order]
    err_series_formal3 = [ lower_ci_series_formal3, upper_ci_series_formal3]
    prob_series_formal5 = [ (df_error.loc[ ((df_error['condition'] == mod_disease) & (df_error['type'] == s) & ( df_error['model'] == t) & (df_error['diagnosis'] == 5)), 'mean']).values[0] for (s, t) in bar_order]
    lower_ci_series_formal5 = [ (df_error.loc[ ((df_error['condition'] == mod_disease) & (df_error['type'] == s) & ( df_error['model'] == t) & (df_error['diagnosis'] == 5)), 'lower_ci']).values[0] for (s, t) in bar_order]
    upper_ci_series_formal5 =  [ (df_error.loc[ ((df_error['condition'] == mod_disease) & (df_error['type'] == s) & ( df_error['model'] == t) & (df_error['diagnosis'] == 5)), 'upper_ci']).values[0] for (s, t) in bar_order]
    err_series_formal5 = [ lower_ci_series_formal5, upper_ci_series_formal5]
                          
    return ( prob_series_formal3, err_series_formal3, prob_series_formal5,  err_series_formal5) 


( prob_series_formal3, err_series_formal3, prob_series_formal5,  err_series_formal5)  = get_accuracies_and_error_bars(bar_order)
#print(prob_series_formal3)
# Out:
# condition: JDM
#    condition      type              model  diagnosis    n      mean        se  \
# 0        JDM    formal        chatgpt-3.5          3  248  1.000000  0.000000
# 1        JDM    formal         chatgpt-4o          3  248  1.000000  0.000000
# 2        JDM    formal      claude-3-opus          3  248  1.000000  0.000000
# 3        JDM    formal  claude-3.5-sonnet          3  248  1.000000  0.000000
# 4        JDM  informal        chatgpt-3.5          3  998  0.786573  0.012976
# 5        JDM  informal         chatgpt-4o          3  998  0.964930  0.005826
# 6        JDM  informal      claude-3-opus          3  998  0.859719  0.010998
# 7        JDM  informal  claude-3.5-sonnet          3  998  0.964930  0.005826
# 32       JDM    formal        chatgpt-3.5          5  248  1.000000  0.000000
# 33       JDM    formal         chatgpt-4o          5  248  1.000000  0.000000
# 34       JDM    formal      claude-3-opus          5  248  1.000000  0.000000
# 35       JDM    formal  claude-3.5-sonnet          5  248  1.000000  0.000000
# 36       JDM  informal        chatgpt-3.5          5  998  0.863727  0.010865
# 37       JDM  informal         chatgpt-4o          5  998  0.969940  0.005408
# 38       JDM  informal      claude-3-opus          5  998  0.924850  0.008349
# 39       JDM  informal  claude-3.5-sonnet          5  998  0.980962  0.004328
#
#        lower     upper      prob  lower_ci  upper_ci
# 0   1.000000  1.000000  1.000000  0.000000  0.000000
# 1   1.000000  1.000000  1.000000  0.000000  0.000000
# 2   1.000000  1.000000  1.000000  0.000000  0.000000
# 3   1.000000  1.000000  1.000000  0.000000  0.000000
# 4   0.761140  0.812006  0.786573  0.025433  0.025433
# 5   0.953511  0.976349  0.964930  0.011419  0.011419
# 6   0.838163  0.881276  0.859719  0.021557  0.021557
# 7   0.953511  0.976349  0.964930  0.011419  0.011419
# 32  1.000000  1.000000  1.000000  0.000000  0.000000
# 33  1.000000  1.000000  1.000000  0.000000  0.000000
# 34  1.000000  1.000000  1.000000  0.000000  0.000000
# 35  1.000000  1.000000  1.000000  0.000000  0.000000
# 36  0.842431  0.885024  0.863727  0.021296  0.021296
# 37  0.959341  0.980539  0.969940  0.010599  0.010599
# 38  0.908485  0.941214  0.924850  0.016365  0.016365
# 39  0.972479  0.989445  0.980962  0.008483  0.008483

# %%
from matplotlib.patches import Rectangle
x = [f'{m}' for (s,m) in bar_order]
top_accuracies = [top[tup] for tup in bar_order]
top_three_accuracies = prob_series_formal3 # [top_three[tup] for tup in bar_order]
top_five_accuracies =  prob_series_formal5 #[top_five[tup] for tup in bar_order]
top_three_errors = err_series_formal3
top_five_errors = err_series_formal5 
X_axis = np.arange(len(top_three_accuracies)) 
  

# Create a bar plot
fig, ax = plt.subplots(figsize=(10, 6))
#ax.axvspan(-0.5, 3.5, color='lightblue', alpha=0.3)

 
rect = Rectangle(
    (-0.5, 0),  # Start position (x, y) for the shaded region
    4,  # Width to cover the first half of the bars
    1.0,  # Height to cover the bars fully
    color='lightgray',  # Background color
    alpha=0.3,  # Transparency
    hatch='',  # Hatching pattern
    zorder=0  # Place behind the bars
)
ax.add_patch(rect)

# getting rid of top diagnosis
#bar1 = ax.bar(X_axis - 0.2, top_accuracies, 0.2, label = f'Top Diagnosis', edgecolor='black', color='white') 
# getting rid of to top three
bar2 = ax.bar(X_axis-0.2, top_three_accuracies,  0.4, yerr=err_series_formal3, label = f'Top Three Diagnoses', edgecolor='black', color='lightgray', capsize=5)
bar3 = ax.bar(X_axis+0.2, top_five_accuracies,  0.4, yerr=err_series_formal5, label = f'Top Five Diagnoses', edgecolor='black', color='gray', capsize=5)

# Color the first half differently
# Getting rid of top and top three, just plot top 5.
#for i, bar in enumerate(bar1):
#    if i <= 3:
#        #bar.set_color('lightblue')
#        bar.set_edgecolor('black')
    #bar.set_hatch('\\')
    
# Color the first half differently
for i, bar in enumerate(bar2):
    if i <= 3:
        #bar.set_color('lightblue')
        bar.set_edgecolor('black')
    #bar.set_hatch('//')

# Color the first half differently
for i, bar in enumerate(bar3):
    if i <= 3:
        #bar.set_color('lightblue')
        bar.set_edgecolor('black')
    #bar.set_hatch('-')



plt.xticks(X_axis, x, rotation=45, ha='right')  
plt.ylabel("Probability",fontsize=18) 
plt.title(f"{disease_fullname}",fontsize=18) 
plt.legend(bbox_to_anchor=(1.3, 1))
plt.tick_params(direction='in')
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)  # Set font size for y-axis ticks

ax.text(1,1.0,'Formal',fontsize=18)
ax.text(5,1.0,'Informal', fontsize=18)
plt.savefig(f'results/{disease}-diagnosis-accuracies.pdf', bbox_inches='tight', dpi=500)
plt.show()

# %%
from matplotlib.patches import Rectangle

# Generate only top 5 for Chatgpt

bar_order_new = [(s,m) for (s,m) in bar_order if 'chatgpt' in m]
(prob_series_formal3, err_series_formal3, prob_series_formal5, err_series_formal5) = get_accuracies_and_error_bars(bar_order_new)
print(prob_series_formal3)
print(err_series_formal3)

x = [f'{m}' for (s,m) in bar_order_new ]

#top_accuracies = [top[tup] for tup in bar_order_new ]
top_three_accuracies = prob_series_formal3 #[top_three[tup] for tup in bar_order_new ]
top_five_accuracies = prob_series_formal5 #[top_five[tup] for tup in bar_order_new ]
X_axis = np.arange(len(top_three_accuracies)) 
  

# Create a bar plot
fig, ax = plt.subplots(figsize=(10, 6))
#ax.axvspan(-0.5, 3.5, color='lightblue', alpha=0.3)

 
rect = Rectangle(
    (-0.5, 0),  # Start position (x, y) for the shaded region
    2,  # Width to cover the first half of the bars
    1.0,  # Height to cover the bars fully
    color='lightgray',  # Background color
    alpha=0.3,  # Transparency
    hatch='',  # Hatching pattern
    zorder=0  # Place behind the bars
)
ax.add_patch(rect)

# getting rid of top diagnosis
#bar1 = ax.bar(X_axis - 0.2, top_accuracies, 0.2, label = f'Top Diagnosis', edgecolor='black', color='white') 
# getting rid of to top three
bar2 = ax.bar(X_axis, top_three_accuracies, 0.2, label = f'Top Three Diagnoses', yerr=err_series_formal3, capsize=5, edgecolor='black', color='lightgray')
bar3 = ax.bar(X_axis+0.2, top_five_accuracies, 0.2, label = f'Top Five Diagnoses', yerr=err_series_formal5, capsize=5, edgecolor='black', color='gray')

# Color the first half differently
# Getting rid of top and top three, just plot top 5.
#for i, bar in enumerate(bar1):
#    if i <= 3:
#        #bar.set_color('lightblue')
#        bar.set_edgecolor('black')
#    #bar.set_hatch('\\')
    
# Color the first half differently
for i, bar in enumerate(bar2):
    if i <= 3:
        #bar.set_color('lightblue')
        bar.set_edgecolor('black')
    #bar.set_hatch('//')

# Color the first half differently
for i, bar in enumerate(bar3):
    if i <= 3:
        #bar.set_color('lightblue')
        bar.set_edgecolor('black')
    #bar.set_hatch('-')



plt.xticks(X_axis, x, rotation=45, ha='right')  
plt.ylabel("Probability",fontsize=18) 
plt.title(f"{disease_fullname}",fontsize=18) 
plt.legend(bbox_to_anchor=(1.3, 1))
plt.tick_params(direction='in')
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)  # Set font size for y-axis ticks

ax.text(0.5,1.0,'Formal',fontsize=18)
ax.text(2.5,1.0,'Informal', fontsize=18)
plt.savefig(f'results/{disease}-diagnosis-accuracies-chatgpt.pdf', bbox_inches='tight', dpi=500)
plt.show()
# Out:
# [np.float64(1.0), np.float64(1.0), np.float64(0.7865731462925851), np.float64(0.9649298597194388)]
# [[np.float64(0.0), np.float64(0.0), np.float64(0.025433292), np.float64(0.011418922)], [np.float64(0.0), np.float64(0.0), np.float64(0.025433292), np.float64(0.011418922)]]

# %%
from matplotlib.patches import Rectangle

# Generate only top 5 for Chatgpt

bar_order_new = [(s,m) for (s,m) in bar_order if 'claude' in m]

x = [f'{m}' for (s,m) in bar_order_new ]

(prob_series_formal3, err_series_formal3, prob_series_formal5, err_series_formal5) = get_accuracies_and_error_bars(bar_order_new)
print(prob_series_formal3)
print(err_series_formal3)

x = [f'{m}' for (s,m) in bar_order_new ]

#top_accuracies = [top[tup] for tup in bar_order_new ]
top_three_accuracies = prob_series_formal3 #[top_three[tup] for tup in bar_order_new ]
top_five_accuracies = prob_series_formal5 #[top_five[tup] for tup in bar_order_new ]
X_axis = np.arange(len(top_three_accuracies)) 
  

# Create a bar plot
fig, ax = plt.subplots(figsize=(10, 6))
#ax.axvspan(-0.5, 3.5, color='lightblue', alpha=0.3)

 
rect = Rectangle(
    (-0.5, 0),  # Start position (x, y) for the shaded region
    2,  # Width to cover the first half of the bars
    1.0,  # Height to cover the bars fully
    color='lightgray',  # Background color
    alpha=0.3,  # Transparency
    hatch='',  # Hatching pattern
    zorder=0  # Place behind the bars
)
ax.add_patch(rect)


bar2 = ax.bar(X_axis, top_three_accuracies, 0.2, label = f'Top Three Diagnoses', yerr=err_series_formal3, capsize=5, edgecolor='black', color='lightgray')
bar3 = ax.bar(X_axis+0.2, top_five_accuracies, 0.2, label = f'Top Five Diagnoses', yerr=err_series_formal5, capsize=5, edgecolor='black', color='gray')

# getting rid of top diagnosis
#bar1 = ax.bar(X_axis - 0.2, top_accuracies, 0.2, label = f'Top Diagnosis', edgecolor='black', color='white') 
# getting rid of to top three


# Color the first half differently
# Getting rid of top and top three, just plot top 5.
#for i, bar in enumerate(bar1):
#    if i <= 3:
#        #bar.set_color('lightblue')
#        bar.set_edgecolor('black')
#    #bar.set_hatch('\\')
    
# Color the first half differently
for i, bar in enumerate(bar2):
    if i <= 3:
        #bar.set_color('lightblue')
        bar.set_edgecolor('black')
    #bar.set_hatch('//')

# Color the first half differently
for i, bar in enumerate(bar3):
    if i <= 3:
        #bar.set_color('lightblue')
        bar.set_edgecolor('black')
    #bar.set_hatch('-')



plt.xticks(X_axis, x, rotation=45, ha='right')  
plt.ylabel("Probability",fontsize=18) 
plt.title(f"{disease_fullname}",fontsize=18) 
plt.legend(bbox_to_anchor=(1.3, 1))
plt.tick_params(direction='in')
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)  # Set font size for y-axis ticks

ax.text(0.5,1.0,'Formal',fontsize=18)
ax.text(2.5,1.0,'Informal', fontsize=18)
plt.savefig(f'results/{disease}-diagnosis-accuracies-claude.pdf', bbox_inches='tight', dpi=500)
plt.show()
# Out:
# [np.float64(1.0), np.float64(1.0), np.float64(0.8597194388777555), np.float64(0.9649298597194388)]
# [[np.float64(0.0), np.float64(0.0), np.float64(0.021556866), np.float64(0.011418922)], [np.float64(0.0), np.float64(0.0), np.float64(0.021556866), np.float64(0.011418922)]]

# %% [markdown]
# ## Frequencies for the top five diagnoses

# %%
def get_frequencies(lst_of_top_responses, lower=True):
    lower_case_responses = [(s.lower() if lower else s) for s in lst_of_top_responses]
    return {i:lower_case_responses.count(i) for i in set(lower_case_responses)}


def cleanup_diagnosis_name(diag_name):
    # remove preceding and succeeding **
    diag_name1 = diag_name.replace("*","")
    return diag_name1
    
def get_top_five_responses(symp_type, model_name):
    fname = f'{disease}-{symp_type}-{model_name}.txt'
    all_patients = utils.process_file(fname)
    top_five_tmp = [resp.get_top_three_symptoms(5) for resp in all_patients]
    top_five_responses_informal = [cleanup_diagnosis_name(x) for lst in top_five_tmp for x in lst]
    print('Top five responses')
    freqs = get_frequencies(top_five_responses_informal)
    print(freqs)
    outfile_name = f'{disease}-{symp_type}-{model_name}-top-five-responses.csv'
    outfile = open(outfile_name,'w')
    N = len(top_five_responses_informal)
    print(N)
    print(' Diagnosis, Precentage in Top Five', file=outfile)
    for diag_name in sorted(freqs):
        freq_diagnosis = int(freqs[diag_name]/N*10000.0)/100.0
        print(f'{diag_name}, {freq_diagnosis}', file=outfile)
    outfile.close()

# %%
get_top_five_responses('formal','chatgpt-3.5')
# Out:
# Top five responses
# {'chronic inflammatory demyelinating polyneuropathy (cidp)': 4, 'dermatomyositis': 35, 'congenital muscular dystrophy': 1, 'kawasaki disease': 28, 'inflammatory myopathy': 10, "cushing's syndrome": 1, 'gastrointestinal disorders (such as inflammatory bowel disease)': 1, 'infectious myositis': 4, 'systemic sclerosis': 41, 'congestive heart failure': 2, 'cardiomyopathy': 5, 'infectious gastroenteritis': 1, 'viral infection': 5, 'metabolic myopathy': 1, 'systemic scleroderma': 2, 'duchenne muscular dystrophy': 10, 'malnutrition': 4, 'systemic lupus erythematosus': 104, 'lymphoma': 1, 'infectious mononucleosis': 2, 'inflammatory myopathies': 5, 'juvenile idiopathic arthritis': 106, 'systemic sclerosis (scleroderma)': 22, 'heart failure': 4, 'idiopathic thrombocytopenic purpura (itp)': 1, 'systemic juvenile idiopathic arthritis (sjia)': 1, 'juvenile myasthenia gravis': 1, 'juvenile mixed connective tissue disease': 1, 'sle (systemic lupus erythematosus)': 1, 'sarcoidosis': 2, 'polymyositis': 170, 'idiopathic inflammatory myopathies': 4, 'lipodystrophy': 5, 'myasthenia gravis': 16, 'periodontal disease': 2, 'gastrointestinal bleeding or ulceration': 1, 'juvenile idiopathic arthritis (jia)': 12, 'lupus myositis': 1, 'inflammatory bowel disease': 8, 'lyme disease': 5, 'vasculitis': 3, 'gingivostomatitis': 1, 'mitochondrial myopathy': 4, 'juvenile idiopathic inflammatory myopathy': 1, 'chronic fatigue syndrome': 4, 'juvenile systemic sclerosis': 4, 'chronic anemia': 1, 'familial partial lipodystrophy': 1, 'mixed connective tissue disease (mctd)': 18, 'rheumatic fever': 1, 'gingival hyperplasia': 1, 'lupus': 13, 'vitamin d deficiency': 2, 'inflammatory bowel disease (ibd)': 1, 'celiac disease': 2, 'gastrointestinal disorders (e.g., ulcerative colitis)': 1, 'viral myositis': 2, 'juvenile polymyositis': 1, 'hypothyroidism': 24, 'systemic juvenile idiopathic arthritis': 7, 'childhood systemic vasculitis': 1, 'systemic vasculitis': 3, 'acute glomerulonephritis': 1, 'hypothyroid myopathy': 14, 'pulmonary hypertension': 1, "granulomatosis with polyangiitis (wegener's)": 1, 'pompe disease': 1, 'poly/dermatomyositis': 1, 'eosinophilic fasciitis': 3, 'lupus dermatitis': 2, 'overlap syndrome (mixed connective tissue disease)': 1, 'inclusion body myositis': 29, 'juvenile scleroderma': 5, 'gastrointestinal disorders': 1, 'rheumatoid arthritis': 21, 'muscular dystrophy': 3, 'hemolytic uremic syndrome': 1, 'overlap syndrome': 1, 'dermatitis herpetiformis': 2, 'congenital myasthenic syndrome': 4, 'connective tissue disease': 1, 'guillain-barre syndrome': 3, 'scleroderma (systemic sclerosis)': 1, 'mixed connective tissue disease': 16, 'juvenile dermatomyositis': 241, 'infectious causes such as viral myositis': 1, 'esophagitis': 1, 'overlap syndrome (juvenile dermatomyositis and sle)': 1, 'systemic lupus erythematosus (sle)': 131, "sjogren's syndrome": 14, 'scleroderma': 14, 'lupus dermatomyositis overlap': 1, 'autoimmune hepatitis': 1, 'eosinophilic esophagitis': 1}
# 1245

# %%
get_top_five_responses('informal','chatgpt-3.5')
# Out:
# Top five responses
# {'juvenile onset multiple sclerosis': 1, 'dermatomyositis': 105, 'neurological disorder (e.g. brain tumor)': 1, 'juvenile spondyloarthritis': 2, 'kawasaki disease': 507, 'infectious mononucleosis (mono)': 1, 'scarlatina (scarlet fever)': 1, 'asthma': 19, "cushing's syndrome": 6, 'hemophilia': 1, 'cystic fibrosis': 6, 'allergic reaction': 39, 'gastroesophageal reflux disease (gerd)': 22, 'systemic sclerosis': 40, 'streptococcal pharyngitis': 6, 'angioedema': 1, 'congestive heart failure': 7, 'hsp (henoch-schonlein purpura)': 1, 'pharyngitis': 2, "addison's disease": 2, 'viral infection': 4, 'juvenile idiopathic scoliosis': 1, 'viral infection (e.g. coxsackievirus)': 1, 'cutaneous porphyrias': 2, 'neurological disorder (such as guillain-barre syndrome)': 1, 'systemic scleroderma': 12, 'duchenne muscular dystrophy': 6, 'gastrointestinal infection': 1, 'eosinophilic granulomatosis with polyangiitis': 1, 'asthma exacerbation': 9, 'sle-associated vasculitis': 1, 'henoch-schönlein purpura': 19, 'granulomatosis with polyangiitis': 2, 'dermatitis': 2, 'hand-foot-mouth disease': 8, 'allergic contact dermatitis': 3, 'cutaneous leishmaniasis': 1, 'porphyria cutanea tarda': 7, 'malnutrition': 19, 'systemic lupus erythematosus': 282, 'lymphoma': 13, 'food allergy': 5, 'gastrointestinal bleeding': 5, 'infectious mononucleosis': 15, 'coeliac disease': 9, 'hyperthyroidism': 10, "juvenile sjogren's syndrome": 6, 'cellulitis': 1, 'scabies': 2, 'juvenile rheumatoid arthritis': 29, 'heart condition (such as congenital heart defect)': 1, 'erythema multiforme': 2, 'juvenile idiopathic arthritis': 656, 'gingivitis': 1, 'heart failure': 11, 'systemic sclerosis (scleroderma)': 31, 'constipation': 1, 'psoriasis': 6, 'acute myositis': 1, 'thrombocytopenic purpura': 1, 'juvenile sarcoidosis': 2, 'osteochondritis dissecans': 1, 'juvenile idiopathic fibromyalgia': 1, 'idiopathic thrombocytopenic purpura (itp)': 3, 'systemic juvenile idiopathic arthritis (sjia)': 3, 'hand-foot-and-mouth disease': 2, 'dermatologic condition (e.g., allergic reaction, contact dermatitis)': 1, 'spinal muscular atrophy': 1, 'juvenile myasthenia gravis': 5, 'congenital heart defect': 1, 'sarcoidosis': 5, 'polymyositis': 8, 'fifth disease (parvovirus b19)': 1, 'henoch-schönlein purpura (hsp)': 11, 'myasthenia gravis': 14, 'mitochondrial disease': 1, 'idiopathic inflammatory myopathies': 1, 'periodontal disease': 1, 'leukemia': 36, 'lymphadenitis': 4, 'acute osteomyelitis': 1, 'juvenile idiopathic arthritis (jia)': 51, 'juvenile lupus': 4, 'juvenile diabetes (type 1 diabetes)': 1, 'inflammatory bowel disease': 5, 'congenital heart disease': 18, 'streptococcal pharyngitis (strep throat)': 4, 'juvenile idiopathic pulmonary fibrosis': 1, 'lyme disease': 153, 'type 1 diabetes': 3, "sjögren's syndrome": 1, 'vasculitis': 11, 'hand, foot, and mouth disease': 18, 'gingivostomatitis': 1, 'chronic granulomatous disease': 2, 'thyroiditis': 1, 'mitochondrial myopathy': 4, 'influenza': 3, 'chronic fatigue syndrome': 23, 'pneumonia': 3, 'photosensitivity dermatitis': 2, 'juvenile idiopathic lymphadenopathy': 1, 'xeroderma pigmentosum': 6, 'acute cutaneous lupus erythematosus': 1, 'juvenile systemic sclerosis': 10, 'cutaneous t-cell lymphoma': 3, 'gastrointestinal (gi) disorder': 1, 'vitamin deficiency (e.g., vitamin c deficiency)': 1, 'mixed connective tissue disease (mctd)': 1, 'rheumatic fever': 102, 'infection (such as viral illness)': 1, 'stevens-johnson syndrome': 10, 'anemia': 16, "juvenile sjögren's syndrome": 1, 'toxic epidermal necrolysis': 3, 'chronic myofascial pain': 1, "inflammatory bowel disease (crohn's disease or ulcerative colitis)": 2, 'lupus': 39, 'multiple sclerosis': 1, 'vitamin d deficiency': 53, 'neurological disorder': 1, 'epstein-barr virus (ebv) infection': 1, 'chronic kidney disease': 6, 'inflammatory bowel disease (ibd)': 5, 'contact dermatitis': 8, 'impetigo': 1, 'chronic fatigue syndrome (cfs)': 1, 'celiac disease': 56, 'mononucleosis': 25, 'acute rheumatic fever': 1 ...
# 4995

# %%
get_top_five_responses('formal','chatgpt-4o')
# Out:
# Top five responses
# {'inclusion body myositis': 1, 'sjögren’s syndrome': 4, 'viral myositis': 20, 'juvenile dermatomyositis (jdm)': 11, 'juvenile idiopathic arthritis (systemic onset)': 4, 'lipodystrophy syndrome': 1, 'sarcoidosis': 2, 'kawasaki disease': 14, 'polymyositis': 230, "cushing's syndrome": 3, 'henoch-schönlein purpura (hsp)': 1, 'psoriatic arthritis': 4, 'myasthenia gravis': 1, 'juvenile idiopathic arthritis with systemic onset': 1, 'hypothyroidism': 13, 'infectious myositis': 3, 'rheumatoid arthritis': 7, 'muscular dystrophy': 7, 'drug-induced lupus': 1, 'overlap syndrome': 1, 'dermatomyositis-pancreatitis syndrome': 1, 'juvenile idiopathic arthritis (jia)': 33, 'scleroderma (systemic sclerosis)': 5, 'linear scleroderma': 1, 'mixed connective tissue disease': 138, 'juvenile dermatomyositis': 237, 'calcinosis cutis': 1, 'juvenile idiopathic arthritis (jia) with systemic features': 5, "sjögren's syndrome": 16, 'vasculitis': 2, 'systemic lupus erythematosus (sle)': 219, 'dermatomyositis-like drug reaction': 1, 'duchenne muscular dystrophy': 1, 'henoch-schönlein purpura': 4, 'nutritional deficiency (e.g., vitamin c deficiency)': 1, 'scleroderma': 65, 'viral exanthem': 1, 'drug-induced myopathy with rash': 1, 'systemic lupus erythematosus': 28, 'juvenile systemic lupus erythematosus': 1, 'rheumatoid arthritis (juvenile idiopathic arthritis)': 2, 'juvenile idiopathic arthritis (jia) with systemic involvement': 2, 'hyperthyroidism': 1, 'cutaneous lupus erythematosus': 1, 'mixed connective tissue disease (mctd)': 107, 'rheumatic fever': 4, 'juvenile idiopathic arthritis (jia) with dermatitis': 2, 'juvenile idiopathic arthritis (jia) with myositis': 1, 'juvenile idiopathic arthritis': 21, 'systemic sclerosis (scleroderma)': 1, 'juvenile idiopathic arthritis (jia) with systemic onset': 1, 'juvenile idiopathic arthritis with systemic features': 2, 'vitamin d deficiency': 3, 'drug-induced lupus erythematosus': 2}
# 1240

# %%
get_top_five_responses('informal','chatgpt-4o')
# Out:
# Top five responses
# {'chronic inflammatory demyelinating polyneuropathy (cidp)': 1, 'viral exanthem with arthritis': 1, 'atopic dermatitis with secondary infection': 1, 'dermatomyositis': 69, 'rheumatoid arthritis (juvenile form)': 3, "raynaud's phenomenon secondary to autoimmune disorder": 1, 'allergic reaction (such as to medication or environmental factors)': 1, 'viral infection (e.g., epstein-barr virus)': 10, "raynaud's phenomenon secondary to another autoimmune condition": 1, "thyroid dysfunction (e.g., hashimoto's thyroiditis)": 1, 'kawasaki disease': 331, "raynaud's phenomenon with connective tissue disorder": 1, "cushing's syndrome": 22, 'asthma': 1, 'lichen planus': 1, 'allergic reaction': 12, 'guillain-barré syndrome': 1, 'gastroesophageal reflux disease (gerd)': 1, 'systemic sclerosis': 1, 'photosensitivity-related dermatitis': 1, "addison's disease": 3, 'cutaneous porphyria': 1, 'viral infection with autoimmune features': 2, 'nutritional deficiency (such as vitamin c deficiency)': 1, 'scorbutic (vitamin c deficiency)': 1, 'dermatomyositis-like drug reaction': 1, 'duchenne muscular dystrophy': 1, 'photosensitive eczema': 1, 'henoch-schönlein purpura': 86, 'polymorphous light eruption': 2, 'viral exanthem': 29, "raynaud's phenomenon associated with an autoimmune condition": 1, 'malnutrition': 1, 'systemic lupus erythematosus': 59, 'lymphoma': 21, 'eczema with neuromuscular disorder': 1, 'infectious mononucleosis': 24, 'hyperthyroidism': 1, 'vitamin deficiency (e.g., vitamin c or d)': 1, 'juvenile rheumatoid arthritis': 2, 'erythema multiforme': 20, 'juvenile idiopathic arthritis': 81, 'localized scleroderma (morphea)': 1, 'systemic sclerosis (scleroderma)': 1, 'amyopathic dermatomyositis': 1, 'psoriasis': 6, 'juvenile idiopathic arthritis with systemic features': 2, 'pediatric rheumatoid arthritis': 1, 'systemic juvenile idiopathic arthritis (sjia)': 12, "raynaud's phenomenon secondary to autoimmune disease": 2, 'spinal muscular atrophy': 1, 'juvenile myasthenia gravis': 2, 'acute epstein-barr virus infection (mononucleosis)': 1, 'juvenile idiopathic arthritis (systemic onset)': 2, "adrenal insufficiency (addison's disease)": 1, 'sarcoidosis': 5, 'polymyositis': 223, 'rheumatoid arthritis (juvenile)': 4, 'fifth disease (parvovirus b19)': 2, 'henoch-schönlein purpura (hsp)': 119, 'myasthenia gravis': 20, 'scurvy': 5, 'scleroderma (juvenile systemic sclerosis)': 1, 'cyanotic congenital heart disease': 1, 'amyloidosis': 1, 'leukemia': 26, 'parvovirus b19 infection': 1, 'lymphadenitis': 1, 'juvenile idiopathic arthritis (jia)': 126, 'juvenile systemic lupus erythematosus (jsle)': 1, 'lyme disease': 20, 'fifth disease (parvovirus b19 infection)': 8, 'anorexia nervosa': 3, 'paraneoplastic syndrome': 1, "sjögren's syndrome": 54, 'vasculitis': 12, 'pediatric vasculitis': 3, 'hypokalemic periodic paralysis': 1, 'viral infection with complications': 1, 'mitochondrial myopathy': 1, 'chronic fatigue syndrome': 2, 'photosensitivity dermatitis': 2, 'psoriasis or psoriatic arthritis': 1, 'raynaud’s disease': 1, 'viral infection with reactive arthritis': 1, 'esophageal dysphagia': 2, 'parvovirus b19 infection (fifth disease)': 5, 'rheumatoid arthritis (juvenile idiopathic arthritis - jia)': 1, 'juvenile idiopathic arthritis (jia) with systemic involvement': 1, 'mixed connective tissue disease (mctd)': 173, 'rheumatic fever': 116, 'viral exanthem with myositis': 5, 'viral exanthema with myositis': 1, 'anemia': 8, 'photosensitivity due to medication or chemical exposure': 1, 'congenital myopathy': 1, "viral infection with raynaud's phenomenon": 1, 'vitamin d deficiency': 18, 'juvenile idiopathic arthritis (with systemic onset)': 3, 'inflammatory bowel disease (ibd)': 1, 'chronic kidney disease': 1, 'contact dermatitis': 2, 'celiac disease': 45, 'viral myositis': 33, 'mononucleosis': 1, 'acute rheumatic fever': 6, 'pediatric systemic lupus erythematosus (psle)': 1, 'psoriasis with psoriatic arthritis': 1, "raynaud's phenomenon with secondary cause": 1, ' ...
# 4990

# %%
get_top_five_responses('formal','claude-3-opus')
# Out:
# Top five responses
# {'inherited metabolic disorder (e.g., mitochondrial disorder)': 1, 'atopic dermatitis with secondary infection': 1, 'chronic fatigue syndrome (cfs)': 1, 'celiac disease': 1, 'viral myositis': 122, 'viral infection (e.g., epstein-barr virus)': 3, 'juvenile dermatomyositis (jdm)': 116, 'vasculitis (e.g., polyarteritis nodosa)': 1, 'cutaneous t-cell lymphoma (ctcl)': 1, 'polymyositis': 186, 'rheumatoid arthritis (juvenile)': 1, "cushing's syndrome": 1, 'kawasaki disease': 2, 'childhood polymyositis (pm)': 2, 'myasthenia gravis': 10, 'viral infection (e.g., parvovirus b19, coxsackievirus)': 2, "endocrine disorders (e.g., hypothyroidism or cushing's syndrome)": 1, 'hypothyroidism': 1, 'duchenne muscular dystrophy (dmd)': 3, 'rheumatoid arthritis': 2, 'muscular dystrophy': 195, 'overlap syndrome': 4, 'inherited metabolic disorders': 1, 'childhood scleroderma': 1, 'childhood polymyositis': 2, 'congestive heart failure': 1, 'muscular dystrophy (other types)': 1, 'juvenile idiopathic arthritis (jia)': 16, 'inherited muscular dystrophy': 2, 'mixed connective tissue disease': 11, 'viral infection': 1, 'juvenile dermatomyositis': 133, 'metabolic myopathy': 2, 'vasculitis': 2, 'systemic lupus erythematosus (sle)': 237, 'muscular dystrophy (e.g., duchenne muscular dystrophy)': 1, 'duchenne muscular dystrophy': 2, 'severe anemia': 1, 'muscular dystrophy (md)': 2, 'mitochondrial myopathy': 24, 'muscular dystrophy-dystroglycanopathy': 1, 'muscular dystrophy (e.g., duchenne or becker)': 1, 'chronic fatigue syndrome': 1, 'limb-girdle muscular dystrophy (lgmd)': 1, 'vasculitis (e.g., henoch-schönlein purpura)': 1, 'systemic lupus erythematosus': 7, 'mixed connective tissue disease (mctd)': 121, 'lipodystrophy syndromes': 1, 'viral myositis (e.g., influenza or enterovirus)': 1, 'childhood-onset systemic sclerosis (scleroderma)': 1, 'childhood systemic sclerosis': 1, 'viral infection (e.g., coxsackievirus or parvovirus b19)': 1, 'juvenile polymyositis (jpm)': 1, 'juvenile idiopathic arthritis': 2, 'systemic sclerosis (scleroderma)': 2, 'inherited lipodystrophy syndromes': 1, 'vitamin d deficiency': 4}
# 1245

# %%
get_top_five_responses('formal','claude-3.5-sonnet')
# Out:
# Top five responses
# {'viral myositis': 12, 'juvenile idiopathic arthritis (systemic onset)': 35, 'vasculitis (e.g., polyarteritis nodosa)': 3, 'kawasaki disease': 1, 'polymyositis': 231, 'myasthenia gravis': 8, 'hypothyroidism': 1, 'overlap syndrome': 1, 'muscular dystrophy': 38, 'juvenile idiopathic arthritis (jia)': 8, 'scleroderma (systemic sclerosis)': 1, 'mixed connective tissue disease': 231, 'lyme disease': 2, 'juvenile dermatomyositis': 248, 'systemic lupus erythematosus (sle)': 247, 'duchenne muscular dystrophy': 1, 'chronic fatigue syndrome': 1, 'scleroderma': 86, 'systemic lupus erythematosus': 1, 'juvenile idiopathic arthritis': 52, 'systemic sclerosis (scleroderma)': 1, 'juvenile idiopathic arthritis (systemic-onset)': 31}
# 1240

# %%
get_top_five_responses('informal','claude-3.5-sonnet')
# Out:
# Top five responses
# {'dermatomyositis': 22, 'viral infection (e.g., epstein-barr virus)': 16, 'post-streptococcal reactive arthritis': 1, 'allergic reaction/drug reaction': 1, 'viral myositis with vasculitis': 1, 'childhood leukemia': 1, 'allergic reaction/atopic dermatitis': 1, 'kawasaki disease': 98, 'pediatric scleroderma': 1, "cushing's syndrome": 7, 'exercise-induced asthma': 3, 'guillain-barré syndrome': 13, 'systemic sclerosis': 1, 'streptococcal pharyngitis': 1, 'systemic lupus erythematosus (juvenile)': 44, 'vitamin d deficiency myopathy': 1, "addison's disease": 3, 'post-viral syndrome': 1, 'viral infection (coxsackie virus)': 1, 'vasculitis (such as henoch-schönlein purpura)': 2, 'juvenile idiopathic arthritis (systemic)': 1, 'systemic scleroderma': 10, 'duchenne muscular dystrophy': 3, "graves' disease": 2, 'allergic response/atopic dermatitis': 1, 'inflammatory bowel disease with extra-intestinal manifestations': 1, 'henoch-schönlein purpura': 12, 'granulomatosis with polyangiitis': 1, 'viral exanthem': 2, 'allergic contact dermatitis': 4, 'hand-foot-mouth disease': 1, 'juvenile idiopathic arthritis (systemic type)': 1, 'systemic lupus erythematosus': 479, 'lymphoma': 10, 'gastrointestinal bleeding': 1, 'infectious mononucleosis': 22, 'multiple sclerosis (ms)': 1, 'juvenile rheumatoid arthritis': 147, 'viral exanthem with post-viral fatigue': 1, 'erythema multiforme': 1, 'juvenile idiopathic arthritis': 70, 'viral myocarditis': 2, "raynaud's disease with associated autoimmune condition": 1, 'hand-foot-and-mouth disease': 1, 'spinal muscular atrophy': 2, 'viral myositis with rash': 1, 'polymyositis': 685, 'rheumatoid arthritis (juvenile)': 14, 'fifth disease (parvovirus b19)': 3, 'henoch-schönlein purpura (hsp)': 8, 'myasthenia gravis': 15, 'contact dermatitis with concurrent viral myositis': 1, 'epstein-barr virus (mononucleosis)': 1, 'leukemia': 5, "raynaud's disease with secondary autoimmune condition": 1, 'dermatomyositis secondary to malignancy': 1, 'juvenile idiopathic arthritis (jia)': 22, 'viral infection (e.g., epstein-barr)': 2, 'inflammatory bowel disease': 12, 'juvenile systemic lupus erythematosus (jsle)': 34, "raynaud's disease with secondary complications": 1, 'lyme disease': 69, 'allergic reaction/angioedema': 1, 'hand, foot, and mouth disease': 2, 'vasculitis': 3, 'viral exanthem with reactive arthritis': 6, 'contact dermatitis with secondary complications': 1, 'viral exanthem with reactive lymphadenopathy': 1, 'chronic fatigue syndrome': 21, 'streptococcal pharyngitis with post-streptococcal syndrome': 2, "raynaud's phenomenon with scleroderma": 1, 'viral exanthem with lymphadenopathy': 1, 'viral myositis (e.g., coxsackie virus)': 1, 'viral exanthem with myositis': 13, 'rheumatic fever': 33, 'viral exanthem (e.g., coxsackie virus)': 1, 'nutritional deficiency (vitamin c/b12)': 2, 'aplastic anemia': 1, 'multiple sclerosis': 1, 'vitamin d deficiency': 23, 'viral upper respiratory infection with secondary skin manifestations': 1, 'chronic active epstein-barr virus infection': 2, 'contact dermatitis': 1, 'celiac disease': 24, 'viral myositis': 144, 'mononucleosis': 1, 'acute rheumatic fever': 16, 'epstein-barr virus infection': 2, 'viral exanthem with concurrent pharyngitis': 1, "raynaud's phenomenon": 8, 'polyarticular juvenile idiopathic arthritis': 12, "hodgkin's lymphoma": 2, 'hypothyroidism': 22, 'systemic juvenile idiopathic arthritis': 12, 'drug-induced lupus': 1, 'scarlet fever': 1, 'nutritional deficiency (vitamin d/b12)': 1, 'systemic vasculitis': 1, 'eczema with secondary infection': 2, 'viral infection with allergic reaction': 1, 'viral myositis with secondary rash': 2, 'vitamin b12 deficiency': 4, 'growing pains': 1, 'pediatric myasthenia gravis': 1, "raynaud's disease/phenomenon": 2, 'acute lymphoblastic leukemia (all)': 5, 'viral infection with post-viral syndrome': 3, 'scleroderma (juvenile)': 9, 'streptococcal infection with post-streptococcal reactive arthritis': 1, 'post-viral myositis': 1, "raynaud's  ...
# 4990

# %%
get_top_five_responses('informal','claude-3-opus')
# Out:
# Top five responses
# {'dermatomyositis': 169, 'vitamin deficiency': 17, 'kawasaki disease': 287, 'infectious mononucleosis (mono)': 1, 'asthma': 6, "cushing's syndrome": 1, 'lichen planus': 2, 'allergic reaction': 67, 'infectious myositis': 1, 'guillain-barré syndrome': 2, 'gastroesophageal reflux disease (gerd)': 1, 'streptococcal pharyngitis': 4, "crohn's disease": 10, 'sickle cell disease': 2, 'viral exanthem (e.g., measles, rubella)': 6, 'viral infection': 54, 'acute viral infection': 1, 'vitamin deficiency (e.g., vitamin c, iron)': 1, 'henoch-schönlein purpura': 8, 'polymorphous light eruption': 1, 'juvenile fibromyalgia': 1, 'throat infection/strep throat': 1, 'viral exanthem': 27, 'allergic contact dermatitis': 5, 'vitamin deficiency (e.g., vitamin c)': 1, 'malnutrition': 3, 'systemic lupus erythematosus': 38, 'lymphoma': 70, 'infectious mononucleosis': 17, 'viral respiratory infection': 1, 'juvenile rheumatoid arthritis': 35, 'malignancy (leukemia or lymphoma)': 1, 'erythema multiforme': 12, 'juvenile idiopathic arthritis': 367, 'guillain-barré syndrome (gbs)': 1, 'juvenile sarcoidosis': 1, 'photosensitive dermatitis': 4, 'esophageal dysmotility disorder': 1, 'sarcoidosis': 20, 'polymyositis': 17, 'myositis': 1, 'henoch-schönlein purpura (hsp)': 37, 'myasthenia gravis': 1, 'leukemia': 134, 'infectious disease': 1, 'juvenile idiopathic arthritis (jia)': 602, 'inflammatory bowel disease': 5, 'lyme disease': 110, 'esophageal stricture or achalasia': 1, "sjögren's syndrome": 2, 'vasculitis': 235, 'influenza': 1, 'chronic fatigue syndrome': 6, 'esophageal dysphagia': 1, 'acute cutaneous lupus erythematosus': 2, 'juvenile systemic sclerosis': 1, 'malnutrition or eating disorder': 1, 'mixed connective tissue disease (mctd)': 92, 'rheumatic fever': 10, 'anemia': 27, 'drug hypersensitivity reaction': 1, 'lupus': 19, 'septic arthritis': 2, 'electrolyte imbalance': 1, 'photosensitive disorder': 1, 'vitamin d deficiency': 37, 'neurological disorder': 1, 'inflammatory bowel disease (ibd)': 41, 'celiac disease': 105, 'malignancy (e.g., leukemia, lymphoma)': 2, 'mononucleosis': 1, 'acute rheumatic fever': 35, 'juvenile myositis': 2, 'malignancy (e.g., lymphoma)': 2, 'viral myositis': 3, 'juvenile dermatomyositis (jdm)': 1, "raynaud's phenomenon": 29, 'juvenile polymyositis': 45, 'psoriatic arthritis': 2, 'hypothyroidism': 21, 'viral infection (e.g., epstein-barr virus, influenza)': 1, 'sepsis': 1, 'serum sickness': 4, 'lupus erythematosus': 23, 'malignancy (e.g., leukemia or lymphoma)': 2, 'viral infection (e.g., influenza, epstein-barr virus)': 1, 'acute lymphoblastic leukemia (all)': 2, 'thalassemia': 1, 'meningitis': 1, 'juvenile psoriasis': 3, 'lupus (systemic lupus erythematosus)': 4, 'viral exanthem (e.g., parvovirus b19)': 2, 'ehlers-danlos syndrome': 1, 'meningococcal meningitis': 2, 'deconditioning': 1, 'juvenile dermatomyositis with vasculitis': 1, 'thyroid disorder (e.g., hypothyroidism)': 1, 'malignancy': 37, 'juvenile scleroderma': 69, 'juvenile rheumatoid arthritis (jra)': 35, 'reactive arthritis': 2, 'lupus erythematosus (systemic lupus erythematosus or sle)': 1, 'iron deficiency anemia': 39, 'muscular dystrophy': 3, 'respiratory infection': 10, 'tuberculosis': 1, 'juvenile dermatomyositis with overlap syndrome': 2, 'mixed connective tissue disease': 36, 'juvenile dermatomyositis': 841, 'ehlers-danlos syndrome (eds)': 1, 'trauma/abuse': 1, 'systemic lupus erythematosus (sle)': 869, "sjogren's syndrome": 1, 'viral infection (e.g., epstein-barr virus, cytomegalovirus)': 5, 'scleroderma': 61, 'nutritional deficiency': 4, 'eczema': 1, "inflammatory bowel disease (crohn's or ulcerative colitis)": 1, 'vitamin c deficiency (scurvy)': 2, 'eosinophilic esophagitis': 7, 'polyarteritis nodosa': 1, 'acute lymphoblastic leukemia': 6, 'thyroid disorder': 11, 'juvenile ankylosing spondylitis': 2, 'photosensitive drug reaction': 1, 'streptococcal infection': 1, 'juvenile psoriatic arthritis': 8}
# 4995

# %% [markdown]
# # Master list of all the diagnoses

# %%
# generate a list of all diseases involved in the diagnosis


all_diagnoses = set()

for dis in all_diseases:
    for typ in all_types:
        for mdl in all_models:
            fname = f'{dis}-{typ}-{mdl}.txt'
            all_patients = utils.process_file(fname)
            top_five_tmp = [resp.get_top_three_symptoms(5) for resp in all_patients]
            top_five_responses = [cleanup_diagnosis_name(x) for lst in top_five_tmp for x in lst] 
            for r in top_five_responses:
                all_diagnoses.add(r)

out_filename = './results/top-five-responses-spreadsheet/all_diagnoses.csv'
out_file = open(out_filename, 'w')
print("diagnosis, type code for the diagnosis ", file=out_file)
for diag in sorted(all_diagnoses):
    print(f'\"{diag}\"', file=out_file)
out_file.close()

# %% [markdown]
# ## Cohen's Kappa Table
#
# We will compute Cohen's Kappa agreement between various models for the following proposition:
#
# ` The ground truth diagnosis belongs to the top three/five diagnosis`.
#
#  The comparison is now being performed jointly for all the diseases but separately for formal and informal symptom types.

# %%
from sklearn.metrics import cohen_kappa_score
def perform_cohens_kappa_comparison(dis_list, symp_type, keywords_list, mdl1, mdl2, k=3):
    y1 = []
    y2 = []
    for (dis, keywords) in zip(dis_list, keywords_list):
        all_patients_1 = utils.process_file(f'{dis}-{symp_type}-{mdl1}.txt')
        all_patients_2 = utils.process_file(f'{dis}-{symp_type}-{mdl2}.txt')
        for p in all_patients_1:
            v = 1 if utils.approx_matches(keywords, p.get_top_three_symptoms(k)) else 0
            y1.append(v)
        for p in all_patients_2:
            v = 1 if utils.approx_matches(keywords, p.get_top_three_symptoms(k)) else 0
            y2.append(v)
    n = min(len(y1), len(y2))
    y1 = y1[1:n]
    y2 = y2[1:n]
    return float(cohen_kappa_score(y1, y2))

# %%
def build_cohens_table(dis_list, symp_type, keywords_list, all_models, k=3):
    n = len(all_models)
    scores = []
    for i in range(n-1):
        comps_i = ['x']*(i+1) 
        for j in range(i+1, n):
            mdl1 = all_models[i]
            mdl2 = all_models[j]
            comps_i.append(str(perform_cohens_kappa_comparison(dis_list, symp_type, keywords_list, mdl1, mdl2, k)))
        scores.append(comps_i)
    return scores

def pretty_print_table(all_models, scores, out_file_name):
    ofile = open(out_file_name,'w')
    header = ',' + ','.join(all_models)
    print(header, file = ofile)
    lines = [header]
    for (mdl, sc_list) in zip(all_models, scores):
        line =  mdl + ',' + ','.join(sc_list)
        print(line, file=ofile)
        lines.append(line)
    ofile.close()
    return '\n'.join(lines)

# %%
scores = build_cohens_table(all_diseases, 'formal', all_keywords, all_models)
pretty_print_table(model_names, scores, f'results/cohens-kappa/all-formal-comparison.csv')
# Out:
# ',chatgpt-3.5,chatgpt-4o,claude-3-opus,claude-3.5-sonnet\nchatgpt-3.5,x,0.019971893612117042,0.14261094355881088,0.0228633600676984\nchatgpt-4o,x,x,0.11793502447708049,0.7169380177092259\nclaude-3-opus,x,x,x,0.15081405312767782'

# %%
scores = build_cohens_table(all_diseases, 'informal', all_keywords, all_models)
pretty_print_table(model_names, scores, f'results/cohens-kappa/all-informal-comparison.csv')
# Out:
# ',chatgpt-3.5,chatgpt-4o,claude-3-opus,claude-3.5-sonnet\nchatgpt-3.5,x,0.24292487879587876,0.4377620157193832,0.33102592714107504\nchatgpt-4o,x,x,0.15479643700585266,0.5450748021006047\nclaude-3-opus,x,x,x,0.18139902708787448'

# %% [markdown]
# ## Diagnosis Categories

# %%
# 1. Process the input spreadsheet with all diagnosis codes

df_diag_codes = pandas.read_csv('inputs/all_diagnoses_coded.csv')
display(df_diag_codes)
df_diag_codes.set_index('diagnosis', inplace=True)  # Set 'id' as the index
# Out:
#                   diagnosis  type code for the diagnosis
# 0        Abdominal migraine              Gastrointestinal
# 1            Abdominal pain             Gastrointestinal
# 2                   Abscess                    Infectious
# 3      Acanthosis Nigricans                Dermatological
# 4                 Achalasia              Gastrointestinal
# ...                     ...                           ...
# 2084          Xanthomatosis                Dermatological
# 2085  Xeroderma Pigmentosum                Dermatological
# 2086  Xeroderma pigmentosum                Dermatological
# 2087             Xerostomia                Dermatological
# 2088        Zinc deficiency                     Metabolic
#
# [2089 rows x 2 columns]

# %%
def lookup_code(diag, df_diag_codes):
    try:
        row = df_diag_codes.loc[diag]
        return row.item()
    except:
        print(f"Warning: unknown diagnosis code for {diag}") 
        return "Unknown"
        

def compute_diagnosis_code_for_top_k(disease, symp_type, model, df_diag_codes, k=5):
    fname = f'{disease}-{symp_type}-{model}.txt'
    all_patients = utils.process_file(fname)
    top_five_tmp = [resp.get_top_three_symptoms(k) for resp in all_patients]
    top_five_responses = [cleanup_diagnosis_name(x) for lst in top_five_tmp for x in lst] 
    top_five_responses_coded = [lookup_code(diag, df_diag_codes) for diag in top_five_responses]
    return top_five_responses_coded

# %%
def generate_charts_of_diagnosis_types(disease_list, symp_type, model, df_diag_codes, k=5, eps=0.02):
    all_responses_lst = [ compute_diagnosis_code_for_top_k(dis, symp_type, model, df_diag_codes, k) for dis in disease_list ]
    all_responses = [ x for lst in all_responses_lst for x in lst ] # flatten
    freqs = get_frequencies(all_responses, lower=False)
    print(freqs)
    N = len(all_responses)
    threshold = int(eps * N)
    # Filter out small values
    filtered_data = {k: v for k, v in freqs.items() if v >= threshold}
    total_filtered = sum([v for k, v in freqs.items() if v < threshold])
    filtered_data['Other'] = total_filtered
    plt.figure(1)
    
    labels = filtered_data.keys()
    values = filtered_data.values()
    # Create the pie chart
    n = len(labels)
    gray_codes = np.linspace(0.35, 0.95, n)
    # Convert the NumPy array to a list of strings (required by plt.pie for colors)
    gray_colors = [str(g) for g in gray_codes]

    
    plt.pie(values, labels=labels, colors=gray_colors, autopct='%1.1f%%')
    plt.title(f'Top Five Diagnoses Categories: {symp_type} {model}')
    plt.savefig(f'results/diagnosis_codes/top-five-categories-pie-{symp_type}-{model}.pdf', bbox_inches='tight', dpi=500)
    plt.show()

    # BAR CHART 
    # Extract keys and values from the dictionary
    labels = freqs.keys()
    values = freqs.values()
    values_pct = [v/N*100.0 for v in values]

    # 1. Combine labels and values into pairs
    # This creates a list of tuples like [('A', 20), ('B', 50), ...]
    combined_list = zip(labels, values_pct)
    # 2. Sort the combined list in descending order
    # The 'key=lambda x: x[1]' tells Python to sort based on the second item in each pair (the value)
    # 'reverse=True' ensures the order is from highest to lowest
    sorted_list = sorted(combined_list, key=lambda x: x[1], reverse=True)

    # 3. Unzip the sorted list back into two separate lists
    sorted_labels, sorted_values_pct = zip(*sorted_list)

    
    plt.figure(2)
    # Rotate x-axis labels by 45 degrees
    fig, (ax2, ax1) = plt.subplots(2, 1, sharex=True, figsize=(8, 6))
    #ax2.bar(categories, values, color='gray')
    
    
    fig.suptitle(f'Top Five Diagnoses Categories: {symp_type} {model}')
    ax2.set_ylim(70, 100) # Upper range
    
    
    # Plot data on the bottom subplot (ax1)
    #ax1.bar(categories, values, color='gray')
    ax1.set_ylim(0, 10) # Lower range
    plt.xticks(rotation=45, ha='right')  
      
    ax1.bar(sorted_labels, sorted_values_pct, color='gray')
    ax2.bar(sorted_labels, sorted_values_pct, color='gray')
    
    
    
    # Hide spines and adjust ticks
    ax2.spines['bottom'].set_visible(False)
    ax1.spines['top'].set_visible(False)
    ax2.xaxis.tick_top()
    ax2.tick_params(labeltop=False)
    ax1.xaxis.tick_bottom()
    
    # Add "Break" Indicators (Optional but Recommended)
    d = .04 # How big to make the diagonal lines in axes coordinates
    kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
                  linestyle="none", color='k', mec='k', mew=1, clip_on=False)
    ax2.plot([0, 1], [0, 0], transform=ax2.transAxes, **kwargs)
    ax1.plot([0, 1], [1, 1], transform=ax1.transAxes, **kwargs)
    
    
    # Adjust Layout and Show Plot
    fig.subplots_adjust(hspace=0.05)
    plt.ylabel('Percentage')

    
    # Rotate x-axis labels by 45 degrees
    
    plt.xticks(rotation=45, ha='right')  
    plt.savefig(f'results/diagnosis_codes/top-five-categories-bar-{symp_type}-{model}.pdf', bbox_inches='tight',dpi=500)
    
    plt.show()

# %%
generate_charts_of_diagnosis_types(all_diseases, 'formal', 'chatgpt-4o', df_diag_codes)
# Out:
# {'Dermatological': 23, 'Oncological': 23, 'Infectious': 297, 'Iatrogenic': 8, 'Neurological': 14, 'Endocrine': 21, 'Cardiovascular': 2, 'Gastrointestinal': 25, 'Metabolic': 7, 'Nephrology': 9, 'Hematological': 7, 'Genetic': 124, 'Psychiatric': 1, 'Musculoskeletal': 4, 'Rheumatological': 4380, 'Pulmonology': 6, 'Allergy': 1, 'Gastrointestinal ': 3}

# %%
generate_charts_of_diagnosis_types(all_diseases, 'informal', 'chatgpt-4o', df_diag_codes)
# Out:
# {'Oncological': 278, 'Infectious': 1513, 'Neurological': 151, 'Endocrine': 618, 'Musculoskeletal': 24, 'Pulmonology': 52, 'Allergy': 38, 'Dermatological': 356, 'Vascular': 4, 'Immunological': 1, 'Psychiatric': 18, 'Gastrointestinal ': 81, 'Iatrogenic': 8, 'Cardiovascular': 213, 'Gastrointestinal': 314, 'Metabolic': 105, 'Nephrology': 111, 'Hematological': 153, 'Genetic': 395, 'Rheumatological': 15472}

# %%
for mdl in all_models:
    for t in all_types:
        generate_charts_of_diagnosis_types(all_diseases, t, mdl, df_diag_codes)
# Out:
# {'Oncological': 34, 'Infectious': 231, 'Neurological': 57, 'Endocrine': 94, 'Musculoskeletal': 3, 'Dental': 2, 'Pulmonology': 49, 'Allergy': 1, 'Dermatological': 15, 'Immunological': 2, 'Gastrointestinal ': 45, 'Iatrogenic': 1, 'Cardiovascular': 53, 'Gastrointestinal': 100, 'Metabolic': 21, 'Nephrology': 15, 'Hematological': 10, 'Genetic': 126, 'Rheumatological': 4105}
# {'Oncological': 304, 'Infectious': 1466, 'Neurological': 217, 'Endocrine': 1025, 'Musculoskeletal': 15, 'Dental': 2, 'Gynecological': 3, 'Pulmonology': 270, 'Allergy': 59, 'Dermatological': 208, 'Vascular': 1, 'Immunological': 8, 'Psychiatric': 40, 'Gastrointestinal ': 245, 'Iatrogenic': 5, 'Cardiovascular': 333, 'Gastrointestinal': 821, 'Metabolic': 176, 'Nephrology': 168, 'Hematological': 270, 'Genetic': 235, 'Rheumatological': 13989}
# {'Dermatological': 23, 'Oncological': 23, 'Infectious': 297, 'Iatrogenic': 8, 'Neurological': 14, 'Endocrine': 21, 'Cardiovascular': 2, 'Gastrointestinal': 25, 'Metabolic': 7, 'Nephrology': 9, 'Hematological': 7, 'Genetic': 124, 'Psychiatric': 1, 'Musculoskeletal': 4, 'Rheumatological': 4380, 'Pulmonology': 6, 'Allergy': 1, 'Gastrointestinal ': 3}
# {'Oncological': 278, 'Infectious': 1513, 'Neurological': 151, 'Endocrine': 618, 'Musculoskeletal': 24, 'Pulmonology': 52, 'Allergy': 38, 'Dermatological': 356, 'Vascular': 4, 'Immunological': 1, 'Psychiatric': 18, 'Gastrointestinal ': 81, 'Iatrogenic': 8, 'Cardiovascular': 213, 'Gastrointestinal': 314, 'Metabolic': 105, 'Nephrology': 111, 'Hematological': 153, 'Genetic': 395, 'Rheumatological': 15472}
# {'Oncological': 130, 'Infectious': 199, 'Neurological': 25, 'Endocrine': 3, 'Musculoskeletal': 3, 'Pulmonology': 15, 'Allergy': 2, 'Dermatological': 14, 'Immunological': 2, 'Psychiatric': 1, 'Gastrointestinal ': 4, 'Iatrogenic': 2, 'Cardiovascular': 9, 'Gastrointestinal': 94, 'Metabolic': 34, 'Nephrology': 40, 'Hematological': 7, 'Genetic': 220, 'Rheumatological': 4176}
# {'Oncological': 858, 'Infectious': 783, 'Neurological': 136, 'Endocrine': 234, 'Musculoskeletal': 38, 'Pulmonology': 129, 'Allergy': 82, 'Dermatological': 605, 'Immunological': 9, 'Psychiatric': 17, 'Gastrointestinal ': 183, 'Iatrogenic': 4, 'Cardiovascular': 347, 'Gastrointestinal': 589, 'Metabolic': 199, 'Nephrology': 175, 'Hematological': 172, 'Trauma': 12, 'Genetic': 92, 'Rheumatological': 15316}
# {'Oncological': 45, 'Iatrogenic': 21, 'Infectious': 243, 'Dermatological': 3, 'Neurological': 25, 'Endocrine': 14, 'Cardiovascular': 18, 'Gastrointestinal': 14, 'Metabolic': 6, 'Immunological': 44, 'Nephrology': 21, 'Hematological': 30, 'Genetic': 54, 'Psychiatric': 1, 'Musculoskeletal': 6, 'Rheumatological': 4413, 'Pulmonology': 2}
# {'Oncological': 438, 'Infectious': 1619, 'Neurological': 136, 'Endocrine': 225, 'Musculoskeletal': 41, 'Pulmonology': 37, 'Allergy': 8, 'Dermatological': 249, 'Immunological': 95, 'Psychiatric': 48, 'Gastrointestinal ': 74, 'Iatrogenic': 55, 'Cardiovascular': 173, 'Gastrointestinal': 247, 'Metabolic': 197, 'Nephrology': 62, 'Hematological': 115, 'Genetic': 57, 'Rheumatological': 16084}

# %%
all_responses = compute_diagnosis_code_for_top_k(disease, 'formal', 'chatgpt-4o', df_diag_codes)
freqs = get_frequencies(all_responses, lower=False)
print(freqs)
N = len(all_responses)
# Set a threshold for small values
threshold = int(0.02 * N)
# Filter out small values
filtered_data = {k: v for k, v in freqs.items() if v >= threshold}
total_filtered = sum([v for k, v in freqs.items() if v < threshold])
filtered_data['Other'] = total_filtered
# Out:
# {'Iatrogenic': 4, 'Infectious': 28, 'Dermatological': 1, 'Neurological': 1, 'Endocrine': 17, 'Metabolic': 5, 'Genetic': 8, 'Rheumatological': 1175, 'Allergy': 1}

# %%
# Extract keys and values from the dictionary
labels = filtered_data.keys()
values = filtered_data.values()
n = len(labels)
gray_codes = np.linspace(0.3, 0.7, n)
    # Convert the NumPy array to a list of strings (required by plt.pie for colors)
gray_colors = [str(g) for g in gray_codes]

plt.pie(values, labels=labels, colors=gray_colors, autopct='%1.1f%%')
# Create the pie chart
#plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.title(f'Distribution of Top Five Diagnoses Categories: {disease} Formal ChatGPT-4o')
plt.savefig('results/top-five-categories-pie-SAMPLE.pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
# Create the pie chart

# Extract keys and values from the dictionary
labels = freqs.keys()
values = freqs.values()
values_pct = [v/N*100.0 for v in values]

# 1. Combine labels and values into pairs
# This creates a list of tuples like [('A', 20), ('B', 50), ...]
combined_list = zip(labels, values_pct)
# 2. Sort the combined list in descending order
# The 'key=lambda x: x[1]' tells Python to sort based on the second item in each pair (the value)
# 'reverse=True' ensures the order is from highest to lowest
sorted_list = sorted(combined_list, key=lambda x: x[1], reverse=True)

# 3. Unzip the sorted list back into two separate lists
sorted_labels, sorted_values_pct = zip(*sorted_list)


# Rotate x-axis labels by 45 degrees
fig, (ax2, ax1) = plt.subplots(2, 1, sharex=True, figsize=(8, 6))
#ax2.bar(categories, values, color='gray')
fig.suptitle(f'Distribution of Top Five Diagnoses Categories: {disease} Formal ChatGPT-4o')
ax2.set_ylim(90, 100) # Upper range


# Plot data on the bottom subplot (ax1)
#ax1.bar(categories, values, color='gray')
ax1.set_ylim(0, 3) # Lower range
plt.xticks(rotation=45, ha='right')  
  
ax1.bar(sorted_labels, sorted_values_pct, color='gray')
ax2.bar(sorted_labels, sorted_values_pct, color='gray')



# Hide spines and adjust ticks
ax2.spines['bottom'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax2.xaxis.tick_top()
ax2.tick_params(labeltop=False)
ax1.xaxis.tick_bottom()

# Add "Break" Indicators (Optional but Recommended)
d = .04 # How big to make the diagonal lines in axes coordinates
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax2.plot([0, 1], [0, 0], transform=ax2.transAxes, **kwargs)
ax1.plot([0, 1], [1, 1], transform=ax1.transAxes, **kwargs)


# Adjust Layout and Show Plot
fig.subplots_adjust(hspace=0.05)
plt.ylabel('Percentage')

plt.savefig('results/top-five-categories-bar-SAMPLE.pdf', dpi=500, bbox_inches='tight')

plt.show()

# %% [markdown]
# # Print a spreadsheet for the "Biostats" people

# %%
def print_results_spreadsheet(disease,symp_type, model):
    # load the file
    fname = f'{disease}-{symp_type}-{model}.txt'
    print(f'{disease}-{symp_type}-{model}')
    all_patients = utils.process_file(fname)
    #print(len(all_patients))
    res_sheet = f'results/csv_sheets/{disease}-{symp_type}-{model}.csv'
    #print(res_sheet)
    outfile = open(res_sheet,'w')
    print('id, symptoms, diagnosis1, diagnosis2, diagnosis3, diagnosis4, diagnosis5', file=outfile)
    for (j,p) in enumerate(all_patients):
        #print(p.responses)
        print(f'{j},', file=outfile, end='')
        print(f'\"{';'.join(p.symptom_list)}\", ', file=outfile, end='')
        for l in range(1,6):
            if l in p.responses:
                (d, _, _) = p.responses[l]
                d_hat = d.replace(",",";")
                print(f'\"{d_hat}\", ', file=outfile, end='')
        print('', file=outfile)
    outfile.close()

# %%
print_results_spreadsheet('MCTD','formal','chatgpt-4o')
# Out:
# MCTD-formal-chatgpt-4o

# %%
for dis in all_diseases:
    for typ in all_types:
        for mdl in all_models:
            print_results_spreadsheet(dis, typ, mdl)
# Out:
# SLE-formal-chatgpt-3.5
# SLE-formal-chatgpt-4o
# SLE-formal-claude-3-opus
# SLE-formal-claude-3.5-sonnet
# SLE-informal-chatgpt-3.5
# SLE-informal-chatgpt-4o
# SLE-informal-claude-3-opus
# SLE-informal-claude-3.5-sonnet
# SystemicSclerosis-formal-chatgpt-3.5
# SystemicSclerosis-formal-chatgpt-4o
# SystemicSclerosis-formal-claude-3-opus
# SystemicSclerosis-formal-claude-3.5-sonnet
# SystemicSclerosis-informal-chatgpt-3.5
# SystemicSclerosis-informal-chatgpt-4o
# SystemicSclerosis-informal-claude-3-opus
# SystemicSclerosis-informal-claude-3.5-sonnet
# JDM-formal-chatgpt-3.5
# JDM-formal-chatgpt-4o
# JDM-formal-claude-3-opus
# JDM-formal-claude-3.5-sonnet
# JDM-informal-chatgpt-3.5
# JDM-informal-chatgpt-4o
# JDM-informal-claude-3-opus
# JDM-informal-claude-3.5-sonnet
# MCTD-formal-chatgpt-3.5
# MCTD-formal-chatgpt-4o
# MCTD-formal-claude-3-opus
# MCTD-formal-claude-3.5-sonnet
# MCTD-informal-chatgpt-3.5
# MCTD-informal-chatgpt-4o
# MCTD-informal-claude-3-opus
# MCTD-informal-claude-3.5-sonnet

# %% [markdown]
# # Accuracy by Number of Symptoms

# %%
def compute_accuracy_by_number_of_symptoms(disease,symp_type, model, keywords_list):
    fname = f'{disease}-{symp_type}-{model}.txt'
    print(f'{disease}-{symp_type}-{model}')
    all_patients = utils.process_file(fname)
    # return a table/dictionary key == number of symptomes --> value (# cases, # top diagnosis correct, # top 3 correct, # top 5 correct)
    dic = {}
    for p in all_patients:
        k = len(p.symptom_list)+1
        top_symp_accurate = 1 if utils.approx_matches(keywords_list, p.get_top_three_symptoms(1)) else 0
        top3_symp_accurate = 1 if utils.approx_matches(keywords_list, p.get_top_three_symptoms(3)) else 0
        top5_symp_accurate = 1 if utils.approx_matches(keywords_list, p.get_top_three_symptoms(5)) else 0
        if k in dic.keys():
            (n_cases, t, t3, t5) = dic[k]
            dic[k] = (n_cases +1, t + top_symp_accurate, t3 + top3_symp_accurate, t5 +top5_symp_accurate)
        else:
            dic[k] = (1, top_symp_accurate, top3_symp_accurate, top5_symp_accurate)
    outfilename = f'results/{disease}-{symp_type}-{model}-accuracy-by-num-symptoms.csv'
    f = open(outfilename, 'w')
    print(f'# Symptoms, # cases, Pct. Top Diagnosis Accurate, Pct. Top 3 Diagnosis Accurate, Pct. Top 5 Diagnosis Accurate', file=f)
    for k in sorted(dic.keys()):
        (n_cases, top, top3, top5) = dic[k]
        assert n_cases >= 1
        print(f'{k}, {n_cases}, {top/n_cases*100.0}, {top3/n_cases*100.0}, {top5/n_cases*100.0}', file=f)
    f.close()
    return dic

# %%
compute_accuracy_by_number_of_symptoms(disease, 'formal', 'chatgpt-3.5', keywords_list)
# Out:
# JDM-formal-chatgpt-3.5
# {12: (45, 45, 45, 45),
#  15: (8, 8, 8, 8),
#  9: (34, 34, 34, 34),
#  13: (27, 27, 27, 27),
#  6: (5, 5, 5, 5),
#  11: (50, 50, 50, 50),
#  16: (3, 3, 3, 3),
#  10: (35, 35, 35, 35),
#  8: (16, 16, 16, 16),
#  7: (5, 5, 5, 5),
#  14: (20, 20, 20, 20),
#  5: (1, 1, 1, 1)}

# %%
from matplotlib import pyplot as plt

for (dis, keywords) in zip(all_diseases, all_keywords):
    for typ in all_types:
        f = plt.figure()
        for mdl in all_models:
            dic = compute_accuracy_by_number_of_symptoms(dis, typ, mdl, keywords)
            k_list = []
            t3_list = []
            for k in sorted(dic.keys()):
                (n_cases, _, t3, _) = dic[k]
                k_list.append(k)
                t3_list.append(t3/n_cases*100.0)
            plt.plot(k_list, t3_list, label=f'{mdl}')
        plt.title(f'Accuracy (in top-3 diagnosis) vs. number of symptoms ({dis} - {typ})')
        plt.xlabel('# Symptoms')
        plt.ylabel('Accuracy  (%)')
        plt.legend()
        plt.savefig(f'results/{dis}-{typ}-accuracy-by-num-symptoms.pdf', bbox_inches='tight', dpi=500)
# Out:
# SLE-formal-chatgpt-3.5
# SLE-formal-chatgpt-4o
# SLE-formal-claude-3-opus
# SLE-formal-claude-3.5-sonnet
# SLE-informal-chatgpt-3.5
# SLE-informal-chatgpt-4o
# SLE-informal-claude-3-opus
# SLE-informal-claude-3.5-sonnet
# SystemicSclerosis-formal-chatgpt-3.5
# SystemicSclerosis-formal-chatgpt-4o
# SystemicSclerosis-formal-claude-3-opus
# SystemicSclerosis-formal-claude-3.5-sonnet
# SystemicSclerosis-informal-chatgpt-3.5
# SystemicSclerosis-informal-chatgpt-4o
# SystemicSclerosis-informal-claude-3-opus
# SystemicSclerosis-informal-claude-3.5-sonnet
# JDM-formal-chatgpt-3.5
# JDM-formal-chatgpt-4o
# JDM-formal-claude-3-opus
# JDM-formal-claude-3.5-sonnet
# JDM-informal-chatgpt-3.5
# JDM-informal-chatgpt-4o
# JDM-informal-claude-3-opus
# JDM-informal-claude-3.5-sonnet
# MCTD-formal-chatgpt-3.5
# MCTD-formal-chatgpt-4o
# MCTD-formal-claude-3-opus
# MCTD-formal-claude-3.5-sonnet
# MCTD-informal-chatgpt-3.5
# MCTD-informal-chatgpt-4o
# MCTD-informal-claude-3-opus
# MCTD-informal-claude-3.5-sonnet

# %% [markdown]
# # Detect possible hallucinations in the symptom list
